# %%
import pandas as pd
import numpy as np
import json
import os
import calendar
from datetime import datetime, date

# =============================================================
# ██████╗  █████╗ ██████╗  █████╗ ███╗   ███╗███████╗
# ██╔══██╗██╔══██╗██╔══██╗██╔══██╗████╗ ████║██╔════╝
# ██████╔╝███████║██████╔╝███████║██╔████╔██║███████╗
# ██╔═══╝ ██╔══██║██╔══██╗██╔══██║██║╚██╔╝██║╚════██║
# ██║     ██║  ██║██║  ██║██║  ██║██║ ╚═╝ ██║███████║
# ╚═╝     ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝
#
#  Smart APS V6  —  VT-Only Indent-Based Planning
#
#  Planning logic:
#    daily_indent  = monthly_indent / working_days
#    today_target  = max(0, daily_indent − inventory)
#    working_days  = calendar days in month − number of Sundays
#
#  Skip rules (part excluded from planning entirely):
#    • monthly_indent < 100
#    • monthly_indent / rate  ≤ 2 hours  (whole indent is trivial)
#
#  Zero-inventory rule:
#    If inventory = 0, part is FORCED into plan regardless of
#    skip rules. Parts sorted by highest daily_indent first
#    (greedy fill) so most critical parts always get time.
# =============================================================

# =============================================================
# SECTION 1 — DAILY SETTINGS  (change these every morning)
# -------------------------------------------------------------
# Only two lines to update each day:
#   PLANNING_DATE  : today
#   INDENT_MONTH   : only change when the month rolls over
# =============================================================

PLANNING_DATE = date(2026, 3, 18)   # ← change daily
INDENT_MONTH  = date(2026, 3,  1)   # ← change when month rolls over

# =============================================================
# SECTION 2 — PARAMETERS
# =============================================================

AVAILABLE_HOURS    = 22        # machine hours available per shift
MIN_RUN_HOURS      = 4         # minimum run block per part
TARGET_DAYS_INV    = 3         # ideal inventory buffer (days)
MACHINE_STATE_FILE = "machine_state.json"

# Skip thresholds
MIN_MONTHLY_INDENT = 150       # skip if monthly indent < this
MIN_INDENT_HOURS   = 4.0       # skip if whole monthly indent takes ≤ this many hours
                               # (monthly_indent / rate ≤ MIN_INDENT_HOURS)
                               # EXCEPTION: zero-inventory parts are never skipped

# Priority: parts are sorted purely by daily_indent descending.
# Highest daily indent = most critical = planned first.
# Within same daily_indent, zero-inventory parts rank above others.

# =============================================================
# SECTION 3 — FILE PATHS
# =============================================================

book_path       = "C:/Users/Ex0164/Book1.xlsx"
matrix_path     = "C:/Users/Ex0164/Important codes/compatibility_matrix.xlsx"
changeover_path = "D:/Tushar/TOOL FIX/Unique_Machines_vt.xlsx"
output_path     = f"Smart_APS_Plan_{PLANNING_DATE.strftime('%Y%m%d')}Indent.xlsx"

# =============================================================
# SECTION 4 — WORKING DAYS CALCULATION
# -------------------------------------------------------------
# working_days = calendar days in INDENT_MONTH − Sundays
# Example: March 2026 → 31 days, 5 Sundays → 26 working days
# =============================================================

def compute_working_days(ref_date):
    year  = ref_date.year
    month = ref_date.month
    total = calendar.monthrange(year, month)[1]
    sundays = sum(
        1 for d in range(1, total + 1)
        if date(year, month, d).weekday() == 6
    )
    return total - sundays, total, sundays

WORKING_DAYS, TOTAL_DAYS, SUNDAY_COUNT = compute_working_days(INDENT_MONTH)

print(f"\n{'='*62}")
print(f"  Smart APS V6  —  VT-Only Indent-Based Planning")
print(f"  Planning date  : {PLANNING_DATE}")
print(f"  Indent month   : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Total days     : {TOTAL_DAYS}")
print(f"  Sundays        : {SUNDAY_COUNT}")
print(f"  Working days   : {WORKING_DAYS}  (used as divisor)")
print(f"  Daily target   : monthly_indent / {WORKING_DAYS}")
print(f"  Today target   : max(0, daily_indent - inventory)")
print(f"  Skip rule 1    : monthly_indent < {MIN_MONTHLY_INDENT} qty")
print(f"  Skip rule 2    : monthly_indent / rate  ≤ {MIN_INDENT_HOURS}h (trivial run)")
print(f"  Zero-inv rule  : inventory=0 parts always forced into plan")
print(f"{'='*62}\n")

# =============================================================
# SECTION 5 — LOAD DATA  (VT only)
# =============================================================

print("Loading data...")
stats        = pd.read_excel(book_path,       sheet_name="Sheet2")
vt_parts_raw = pd.read_excel(book_path,       sheet_name="VT")
vt_matrix    = pd.read_excel(matrix_path,     sheet_name="VT_Matrix")
vt_co_raw    = pd.read_excel(changeover_path, sheet_name="VT_Changeover")

# =============================================================
# SECTION 6 — MERGE & PRODUCTION RATE
# -------------------------------------------------------------
# Merge VT parts sheet with stats (cycle time, cavity, inventory).
# Rate (units/hour) = (3600 / cycle_time_seconds) × cavity_count
# =============================================================

def find_col(df, name, sheet):
    """Case-insensitive column finder. Raises clear error if missing."""
    match = next((c for c in df.columns if str(c).strip().lower() == name.lower()), None)
    if match is None:
        raise ValueError(
            f"Column '{name}' not found in sheet '{sheet}'. "
            f"Available columns: {list(df.columns)}"
        )
    return match

stats_part_col = find_col(stats, "Part", "Sheet2")
vt_part_col    = find_col(vt_parts_raw, "Part", "VT")

data = stats.merge(
    vt_parts_raw.rename(columns={vt_part_col: "Material"}),
    left_on=stats_part_col,
    right_on="Material",
    how="inner"
).drop_duplicates(subset="Material").copy()

data["Rate"] = (3600 / data["Cycle time "].replace(0, np.nan)) * data["cavity"]
data = data[data["Rate"].notna()].copy()

print(f"  VT parts after merge with stats: {len(data)}")

# =============================================================
# SECTION 7 — BUILD LOOKUP DICTIONARIES
# =============================================================

def safe_dict(df, key_col, val_col, default=0.0):
    return {
        k: (default if pd.isna(v) else float(v))
        for k, v in zip(df[key_col], df[val_col])
    }

inventory = safe_dict(data, "Material", "Inventory on 24th")
rate      = safe_dict(data, "Material", "Rate")

# =============================================================
# SECTION 7A — READ INDENT FROM VT SHEET
# -------------------------------------------------------------
# VT sheet must have:
#   • "Part"   column  (case-insensitive)
#   • "Indent" column  (case-insensitive)
#
# Derived dicts:
#   indent_monthly   : {part → monthly qty}
#   indent_daily     : {part → monthly / working_days}
#   today_target_qty : {part → max(0, daily_indent − inventory)}
#
# Skip flags (computed here, enforced in scheduler):
#   skip_low_indent  : monthly < MIN_MONTHLY_INDENT
#   skip_trivial_run : monthly / rate ≤ MIN_INDENT_HOURS
#   EXCEPTION        : both skips are ignored if inventory == 0
# =============================================================

def read_indent_from_sheet(df, sheet_name):
    result   = {}
    part_col = next((c for c in df.columns if str(c).strip().lower() == "part"),   None)
    ind_col  = next((c for c in df.columns if str(c).strip().lower() == "indent"), None)
    if part_col is None:
        print(f"  WARNING: 'Part' column not found in '{sheet_name}'. "
              f"Available: {list(df.columns)}")
        return result
    if ind_col is None:
        print(f"  WARNING: 'Indent' column not found in '{sheet_name}'. "
              f"Available: {list(df.columns)}")
        return result
    print(f"  Book1 '{sheet_name}' — Part col: '{part_col}'  Indent col: '{ind_col}'")
    for _, row in df.iterrows():
        part = row[part_col]
        val  = row[ind_col]
        if pd.isna(part) or str(part).strip() == "":
            continue
        result[str(part).strip()] = float(val) if pd.notna(val) else 0.0
    return result

print("\nReading indent data from VT sheet...")
indent_monthly = read_indent_from_sheet(vt_parts_raw, "VT")

indent_daily = {
    p: round(qty / WORKING_DAYS, 4)
    for p, qty in indent_monthly.items()
}

today_target_qty = {
    p: max(0.0, indent_daily.get(p, 0.0) - inventory.get(p, 0.0))
    for p in indent_monthly
}

# ── Skip flags ───────────────────────────────────────────────
# A part is skipped ONLY when BOTH conditions below are true:
#   condition met  AND  inventory > 0
# If inventory == 0, part is NEVER skipped — it must be made.

def should_skip(part):
    """
    Returns (skip: bool, reason: str).
    Zero-inventory parts are never skipped.
    """
    inv     = inventory.get(part, 0.0)
    monthly = indent_monthly.get(part, 0.0)
    r       = rate.get(part, 1.0)

    # Zero inventory → always force into plan
    if inv == 0.0 and monthly > 0:
        return False, ""

    if monthly < MIN_MONTHLY_INDENT:
        return True, (f"Monthly indent {monthly:.0f} < {MIN_MONTHLY_INDENT} "
                      f"(threshold)")

    indent_hrs = monthly / r if r > 0 else 0.0
    if indent_hrs <= MIN_INDENT_HOURS:
        return True, (f"Whole monthly indent takes only {indent_hrs:.2f}h "
                      f"≤ {MIN_INDENT_HOURS}h threshold")

    return False, ""

# Print skip summary
skipped_parts = {p: should_skip(p) for p in indent_monthly}
n_skip  = sum(1 for skip, _ in skipped_parts.values() if skip)
n_force = sum(1 for p in indent_monthly
              if inventory.get(p, 0) == 0 and indent_monthly.get(p, 0) > 0)
print(f"\n  Indent summary:")
print(f"    Total VT parts with indent data : {len(indent_monthly)}")
print(f"    Parts skipped (low/trivial)     : {n_skip}")
print(f"    Parts with zero inventory       : {n_force}  (forced into plan regardless)")

for p, (skip, reason) in skipped_parts.items():
    if skip:
        print(f"    SKIP  {p:30s}  {reason}")

# =============================================================
# SECTION 7B — CHANGEOVER TIMES  (VT only)
# =============================================================

def build_changeover_dict(co_df):
    co_dict = {}
    for _, row in co_df.iterrows():
        machine = str(row["Unique Machines"]).strip()
        minutes = row["Changeover time"]
        if pd.notna(minutes) and machine:
            co_dict[machine] = float(minutes) / 60.0
    return co_dict

vt_changeover = build_changeover_dict(vt_co_raw)
DEFAULT_CHANGEOVER_HRS = 40 / 60.0

print(f"\n  VT changeover times loaded: {len(vt_changeover)} machines")
for m, h in vt_changeover.items():
    print(f"    {m:25s} → {h*60:.0f} min ({h:.3f} h)")

# =============================================================
# SECTION 7C — PART CATEGORY  (Runner / Repeater / Stranger)
# =============================================================

def build_category_from_sheet(df, sheet_name):
    cat      = {}
    part_col = next((c for c in df.columns if str(c).strip().lower() == "part"),     None)
    cat_col  = next((c for c in df.columns if str(c).strip().lower() == "category"), None)
    if part_col is None:
        print(f"  WARNING: 'Part' column not found in '{sheet_name}'")
        return cat
    if cat_col is None:
        print(f"  WARNING: 'Category' column not found in '{sheet_name}'")
        return cat
    print(f"  Book1 '{sheet_name}' — Part col: '{part_col}'  Category col: '{cat_col}'")
    for _, row in df.iterrows():
        part = row[part_col]
        val  = str(row[cat_col]).strip() if pd.notna(row[cat_col]) else "Stranger"
        if pd.isna(part) or str(part).strip() == "":
            continue
        if val.lower() in ("runner", "repeater", "stranger"):
            val = val.capitalize()
        cat[str(part).strip()] = val
    return cat

part_category  = build_category_from_sheet(vt_parts_raw, "VT")
runner_count   = sum(1 for v in part_category.values() if v == "Runner")
repeater_count = sum(1 for v in part_category.values() if v == "Repeater")
stranger_count = sum(1 for v in part_category.values() if v == "Stranger")
print(f"  Part categories — Runner: {runner_count}  "
      f"Repeater: {repeater_count}  Stranger: {stranger_count}")

# =============================================================
# SECTION 8 — MACHINE STATE
# =============================================================

def load_machine_state():
    if os.path.exists(MACHINE_STATE_FILE):
        with open(MACHINE_STATE_FILE) as f:
            state = json.load(f)
        print(f"\n  Machine state loaded:")
        for m, p in state.items():
            print(f"    {m:25s} last ran → {p}")
        return state
    print("\n  Machine state: FIRST RUN — no previous state. "
          f"State will be saved to '{MACHINE_STATE_FILE}' after this run.")
    return {}

def save_machine_state(vt_state):
    combined = {m: p for m, p in vt_state.items() if p is not None}
    with open(MACHINE_STATE_FILE, "w") as f:
        json.dump(combined, f, indent=2)
    print(f"\n  Machine state saved → {MACHINE_STATE_FILE}")
    for m, p in combined.items():
        print(f"    {m:25s} last ran → {p}")

machine_state = load_machine_state()

# =============================================================
# SECTION 9 — COMPATIBILITY MATRIX  (VT only)
# =============================================================

def build_compatibility(matrix):
    machines = matrix.columns[1:].tolist()
    compat   = {}
    for _, row in matrix.iterrows():
        part = row["Part"]
        for m in machines:
            if row[m] == 1:
                compat.setdefault(part, []).append(m)
    return compat, machines

vt_compat, vt_machines = build_compatibility(vt_matrix)

# =============================================================
# SECTION 10 — INDENT HORIZON TABLE
# -------------------------------------------------------------
# Shows per-part planning numbers and skip/force status.
# =============================================================

def compute_indent_horizon(parts):
    rows = []
    for p in parts:
        inv     = inventory.get(p, 0.0)
        monthly = indent_monthly.get(p, 0.0)
        daily   = indent_daily.get(p, 0.0)
        target  = today_target_qty.get(p, 0.0)
        r       = rate.get(p, 1.0)
        skip, skip_reason = should_skip(p)
        indent_hrs = monthly / r if r > 0 else 0.0

        if inv == 0.0 and monthly > 0:
            status = "ZERO INV — FORCED"
        elif skip:
            status = "SKIPPED"
        elif target > 0:
            status = "PRODUCTION NEEDED"
        elif monthly == 0:
            status = "NO INDENT"
        else:
            status = "INV SUFFICIENT"

        rows.append({
            "Part":              p,
            "Monthly_Indent":    round(monthly, 0),
            "Indent_Hrs_Total":  round(indent_hrs, 2),
            "Working_Days":      WORKING_DAYS,
            "Daily_Indent":      round(daily, 2),
            "Inventory_Now":     round(inv, 0),
            "Today_Target_Qty":  round(target, 0),
            "Today_Target_Hrs":  round(target / r if r > 0 else 0, 2),
            "Rate_Per_Hr":       round(r, 2),
            "Indent_Status":     status,
            "Skip_Reason":       skip_reason,
        })
    return pd.DataFrame(rows)

# =============================================================
# SECTION 11 — SCENARIO CLASSIFIER
# =============================================================

def classify_scenario(parts):
    coverage = []
    for p in parts:
        inv   = inventory.get(p, 0)
        daily = indent_daily.get(p, 0)
        skip, _ = should_skip(p)
        if skip:
            continue
        if daily == 0:
            continue
        coverage.append(inv / daily)

    if not coverage:
        return 3, "SCENARIO 3 — All active parts have zero indent today"

    n        = len(coverage)
    critical = sum(1 for c in coverage if c < 1)
    low      = sum(1 for c in coverage if c < TARGET_DAYS_INV)

    if critical == n:
        return 0, "SCENARIO 0 — ALL parts critical (inv < 1 day indent)"
    elif critical > 0:
        return 1, f"SCENARIO 1 — {critical}/{n} parts critical (inv < 1 day indent)"
    elif low > 0:
        return 2, f"SCENARIO 2 — {low}/{n} parts below {TARGET_DAYS_INV}-day buffer"
    else:
        return 3, f"SCENARIO 3 — All parts healthy (≥{TARGET_DAYS_INV} days inv)"

# =============================================================
# SECTION 12 — PRIORITY ORDERING
# -------------------------------------------------------------
# Parts are ranked purely by daily_indent descending.
# Highest daily indent = largest requirement = planned first.
# This ensures big parts always get machine time before small ones.
#
# Tie-break: zero-inventory parts rank above parts with some stock
# at the same daily_indent level (inv=0 → sort key slightly higher).
#
# "Inventory sufficient" parts (inv >= daily_indent) are excluded
# from the active list before this function is called.
# =============================================================

def compute_priority(parts, horizon_df):
    horizon = horizon_df.set_index("Part")
    rows    = []
    for p in parts:
        inv      = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        days_cov = inv / daily if daily > 0 else 999
        target   = horizon.loc[p, "Today_Target_Qty"] if p in horizon.index else 0

        # Sort key: daily_indent descending.
        # Zero-inventory parts get a tiny tie-break boost (+0.0001)
        # so they edge out same-daily_indent parts that have some stock.
        sort_key = daily + (0.0001 if inv == 0 else 0.0)

        rows.append({
            "Part":           p,
            "Days_Coverage":  round(days_cov, 2),
            "Inv_Now":        round(inv, 0),
            "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
            "Daily_Indent":   round(daily, 2),
            "Today_Target":   round(target, 0),
            "Sort_Key":       sort_key,
            "Zero_Inv":       "YES" if inv == 0 else "No",
        })

    return (pd.DataFrame(rows)
              .sort_values("Sort_Key", ascending=False)
              .drop(columns=["Sort_Key"])
              .reset_index(drop=True))

# =============================================================
# SECTION 13 — MACHINE RANKER
# =============================================================

def rank_machines(part, machines, compatibility, machine_hours,
                  machine_last_part, changeover_dict, inv_days):
    category    = part_category.get(part, "Stranger")
    is_runner   = (category == "Runner")
    runner_lock = is_runner and inv_days <= 1.0

    ranked = []
    for m in machines:
        if m not in compatibility.get(part, []):
            continue
        used = machine_hours.get(m, 0)
        free = AVAILABLE_HOURS - used
        if free < MIN_RUN_HOURS:
            continue
        last   = machine_last_part.get(m)
        if runner_lock and last != part:
            continue
        co_hrs = 0.0 if last == part else changeover_dict.get(m, DEFAULT_CHANGEOVER_HRS)
        effective_free = free - co_hrs
        if effective_free < MIN_RUN_HOURS:
            continue
        cost = co_hrs / AVAILABLE_HOURS + (used / AVAILABLE_HOURS)
        ranked.append((m, cost, effective_free, co_hrs))

    ranked.sort(key=lambda x: x[1])
    return ranked, runner_lock

# =============================================================
# SECTION 14 — TOOL-CHANGER STAGGER
# =============================================================

def stagger_changeovers(plan, machines, changeover_dict):
    print(f"\n  Tool-changer stagger:")

    def get_co_events(plan, machines):
        events = []
        for m in machines:
            m_rows = [r for r in plan if r["Machine"] == m]
            if len(m_rows) < 2:
                continue
            cursor = 0.0
            for i, row in enumerate(m_rows):
                co_h  = float(row.get("Changeover_Hrs") or 0.0)
                run_h = float(row.get("Run_Hours")       or 0.0)
                if co_h > 0:
                    events.append({
                        "machine":     m,
                        "part_before": m_rows[i-1]["Part"] if i > 0 else "—",
                        "part_after":  row["Part"],
                        "co_start":    cursor,
                        "co_duration": co_h,
                        "co_end":      cursor + co_h,
                        "row_before":  m_rows[i-1],
                        "row_after":   row,
                    })
                cursor += co_h + run_h
        events.sort(key=lambda e: e["co_start"])
        return events

    for _ in range(20):
        events = get_co_events(plan, machines)
        if not events:
            print("    No changeovers in plan — nothing to stagger")
            return

        conflict_found = False
        for i in range(1, len(events)):
            prev = events[i - 1]
            curr = events[i]
            if curr["co_start"] >= prev["co_end"]:
                continue

            conflict_found = True
            overlap = prev["co_end"] - curr["co_start"]

            row_bc   = curr["row_before"]
            run_h_bc = float(row_bc.get("Run_Hours") or 0.0)
            feasible_A = (run_h_bc - overlap) >= MIN_RUN_HOURS

            row_bp   = prev["row_before"]
            m_prev   = prev["machine"]
            used_p   = sum(
                float(r.get("Changeover_Hrs") or 0) + float(r.get("Run_Hours") or 0)
                for r in plan if r["Machine"] == m_prev
            )
            spare_p  = AVAILABLE_HOURS - used_p
            shift_B  = min(overlap, spare_p)
            feasible_B = shift_B > 0

            if feasible_A and feasible_B:
                use_A = (overlap * rate.get(row_bc["Part"], 1)) <= (0 if spare_p >= overlap else
                          (overlap - spare_p) * rate.get(row_bp["Part"], 1))
            elif feasible_A:
                use_A = True
            elif feasible_B:
                use_A = False
            else:
                print("    ⚠ Cannot resolve conflict — insufficient capacity to shift")
                continue

            if use_A:
                new_h = round(run_h_bc - overlap, 3)
                row_bc["Run_Hours"]      = new_h
                row_bc["Production_Qty"] = round(
                    row_bc["Production_Qty"] - overlap * rate.get(row_bc["Part"], 1), 0)
                row_bc["Total_Hrs_Used"] = round(
                    float(row_bc.get("Changeover_Hrs") or 0) + new_h, 3)
                row_bc["Stagger_Adjusted"] = f"Reduced {round(overlap*60,1)}min (Option A)"
                print(f"    ✓ {curr['machine']:15s} conflict resolved (Option A)")
            else:
                new_h = round(float(row_bp.get("Run_Hours") or 0) + shift_B, 3)
                row_bp["Run_Hours"]      = new_h
                row_bp["Production_Qty"] = round(
                    row_bp["Production_Qty"] + shift_B * rate.get(row_bp["Part"], 1), 0)
                row_bp["Total_Hrs_Used"] = round(
                    float(row_bp.get("Changeover_Hrs") or 0) + new_h, 3)
                row_bp["Stagger_Adjusted"] = f"Extended {round(shift_B*60,1)}min (Option B)"
                print(f"    ✓ {prev['machine']:15s} conflict resolved (Option B)")
            break

        if not conflict_found:
            print("    All changeovers staggered — no conflicts  ✓")
            return

    print(f"  ⚠ Stagger did not fully resolve in 20 passes — check manually")

# =============================================================
# SECTION 14B — 22-HOUR FILLER
# =============================================================

def fill_remaining_hours(plan, machine_hours, machine_last_part,
                         parts, compatibility, machines,
                         current_inventory, horizon_df):
    already_planned = {row["Part"] for row in plan}

    for m in machines:
        remaining = round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
        if remaining <= 0:
            continue

        on_machine = [row["Part"] for row in plan if row["Machine"] == m]

        # Option A — extend existing part: pick the one with highest daily_indent
        # (most critical part on this machine gets the extra time)
        best_part, best_daily = None, -1
        for p in on_machine:
            d = indent_daily.get(p, 0)
            if d > best_daily:
                best_daily, best_part = d, p

        if best_part and best_daily > 0:
            p         = best_part
            r_val     = rate.get(p, 1)
            extra_qty = round(remaining * r_val, 0)
            for row in plan:
                if row["Part"] == p and row["Machine"] == m:
                    row["Run_Hours"]      = round(row["Run_Hours"] + remaining, 2)
                    row["Production_Qty"] = round(row["Production_Qty"] + extra_qty, 0)
                    row["Total_Hrs_Used"] = round(
                        row.get("Total_Hrs_Used", row["Run_Hours"]) + remaining, 2)
                    row["Type"] = "Primary+Extended"
                    break
            machine_hours[m]    += remaining
            current_inventory[p] = current_inventory.get(p, 0) + extra_qty
            print(f"    ↑ {p:30s} → {m:15s}  +{remaining:.2f}h merged  "
                  f"qty+={extra_qty:.0f}  [EXTEND]")
            continue

        # Option B — add a new part (≥ MIN_RUN_HOURS required)
        if remaining < MIN_RUN_HOURS:
            continue

        candidates = []
        for p in parts:
            if p in already_planned:
                continue
            if m not in compatibility.get(p, []):
                continue
            daily   = indent_daily.get(p, 0)
            inv_now  = current_inventory.get(p, 0)
            # Skip if inventory already sufficient
            if inv_now >= daily > 0:
                continue
            candidates.append((p, daily))

        # Sort by daily_indent descending — biggest parts fill first
        candidates.sort(key=lambda x: -x[1])

        for p, daily_val in candidates:
            last    = machine_last_part.get(m)
            co_hrs  = 0.0 if last == p else vt_changeover.get(m, DEFAULT_CHANGEOVER_HRS)
            eff_run = remaining - co_hrs
            if eff_run < MIN_RUN_HOURS:
                continue
            r_val = rate.get(p, 1)
            qty   = round(eff_run * r_val, 0)
            machine_hours[m]    += (co_hrs + eff_run)
            current_inventory[p] = current_inventory.get(p, 0) + qty
            machine_last_part[m] = p
            already_planned.add(p)
            plan.append({
                "Part":             p,
                "Category":         part_category.get(p, "Stranger"),
                "Machine":          m,
                "Run_Hours":        round(eff_run, 2),
                "Changeover_Hrs":   round(co_hrs, 3),
                "Total_Hrs_Used":   round(co_hrs + eff_run, 2),
                "Rate_Per_Hour":    round(r_val, 2),
                "Production_Qty":   qty,
                "Monthly_Indent":   round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":     round(indent_daily.get(p, 0), 2),
                "Today_Target":     round(today_target_qty.get(p, 0), 0),
                "Changeover":       "No" if co_hrs == 0 else "Yes",
                "Type":             "New — filler",
                "Runner_Lock":      "No",
                "Priority_Score":   0,
                "Stagger_Adjusted": "No",
            })
            print(f"    + {p:30s} → {m:15s}  {eff_run:.2f}h  qty={qty:.0f}  "
                  f"[Filler]  CO={'Yes' if co_hrs > 0 else 'No'}")
            break

# =============================================================
# SECTION 15 — MAIN SCHEDULER
# =============================================================

def schedule(parts, compatibility, machines, changeover_dict, label=""):

    print(f"\n{'─'*62}")
    print(f"  {label}  |  {len(parts)} parts  |  {len(machines)} machines")
    print(f"{'─'*62}")

    scenario, scenario_desc = classify_scenario(parts)
    print(f"  {scenario_desc}")

    horizon_df = compute_indent_horizon(parts)

    # Print what needs production
    prod_needed = horizon_df[
        horizon_df["Indent_Status"].isin(["PRODUCTION NEEDED", "ZERO INV — FORCED"])
    ]
    if not prod_needed.empty:
        print(f"\n  Parts requiring production today ({len(prod_needed)}):")
        print(f"  {'Part':<30}  {'Monthly':>8}  {'Daily':>7}  {'Inv':>8}  "
              f"{'Target':>8}  {'Status'}")
        print(f"  {'─'*30}  {'─'*8}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*20}")
        for _, r in prod_needed.iterrows():
            print(f"  {r['Part']:<30}  "
                  f"{r['Monthly_Indent']:>8.0f}  "
                  f"{r['Daily_Indent']:>7.2f}  "
                  f"{r['Inventory_Now']:>8.0f}  "
                  f"{r['Today_Target_Qty']:>8.0f}  "
                  f"{r['Indent_Status']}")
    else:
        print("  No production needed — inventory covers all active parts today")

    machine_hours     = {m: 0.0 for m in machines}
    machine_last_part = {m: machine_state.get(m) for m in machines}
    current_inventory = inventory.copy()

    plan, deferred, not_planned, skipped_log = [], [], [], []

    # Active parts = not skipped OR zero-inventory (always forced)
    # Inventory-sufficient parts are excluded here — not in priority list at all.
    active_parts = [
        p for p in parts
        if (not should_skip(p)[0] or inventory.get(p, 0) == 0)
        and indent_monthly.get(p, 0) > 0
        and not (inventory.get(p, 0) >= indent_daily.get(p, 0) > 0)
    ]

    priority_df = compute_priority(active_parts, horizon_df)

    print(f"\n  Priority order — sorted by daily_indent descending "
          f"({len(priority_df)} active parts):")
    print(f"  {'Part':<30}  {'Daily':>7}  {'Inv':>8}  {'Target':>8}  {'Zero_Inv':>8}")
    print(f"  {'─'*30}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*8}")
    for _, r in priority_df.iterrows():
        print(f"  {r['Part']:<30}  "
              f"{r['Daily_Indent']:>7.2f}  "
              f"{r['Inv_Now']:>8.0f}  "
              f"{r['Today_Target']:>8.0f}  "
              f"{r['Zero_Inv']:>8}")

    runner_dedicated_machines = set()

    # ── Log skipped parts (not zero-inv) ─────────────────────
    for p in parts:
        skip, reason = should_skip(p)
        inv_now = inventory.get(p, 0)
        if skip and inv_now > 0:
            skipped_log.append({
                "Part":           p,
                "Category":       part_category.get(p, "Stranger"),
                "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":   round(indent_daily.get(p, 0), 2),
                "Inventory_Now":  round(inv_now, 0),
                "Skip_Reason":    reason,
            })

    def run_assignment(parts_subset, pass_label, exclude_machines=None):
        if exclude_machines is None:
            exclude_machines = set()
        print(f"\n  {pass_label}:")

        for _, row in priority_df[priority_df["Part"].isin(parts_subset)].iterrows():
            part     = row["Part"]

            if any(r["Part"] == part for r in plan):
                print(f"    ~ {part:30s}  ALREADY PLANNED — skipped")
                continue

            inv_now  = current_inventory.get(part, 0)
            daily    = indent_daily.get(part, 0)
            monthly  = indent_monthly.get(part, 0)
            r_val    = rate.get(part, 1)
            category = part_category.get(part, "Stranger")
            inv_days = inv_now / daily if daily > 0 else 999
            target   = today_target_qty.get(part, 0)

            compatible_mch = compatibility.get(part, [])

            # ── Zero indent ───────────────────────────────────
            if monthly == 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": 0,
                    "Daily_Indent":   0,
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Monthly indent is zero",
                    "Next_Action":    "Re-evaluate when indent is set",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED — indent = 0")
                continue

            # ── Inventory sufficient (and not zero-inv forced) ─
            if target == 0 and inv_now > 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": round(monthly, 0),
                    "Daily_Indent":   round(daily, 2),
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Inventory covers daily indent — no production needed",
                    "Next_Action":    "Re-evaluate tomorrow",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED  "
                      f"inv={inv_now:.0f} ≥ daily={daily:.2f}")
                continue

            # ── Target hours ──────────────────────────────────
            # For zero-inventory forced parts: use daily_indent as minimum
            # run target so we at least build one day's worth.
            effective_target = max(target, daily) if inv_now == 0 else target

            if category == "Runner":
                target_hrs = min(
                    (effective_target / r_val if r_val > 0 else MIN_RUN_HOURS)
                    + (daily / r_val if r_val > 0 else 0),
                    AVAILABLE_HOURS
                )
                target_hrs = max(target_hrs, MIN_RUN_HOURS)
            else:
                target_hrs = max(
                    MIN_RUN_HOURS,
                    effective_target / r_val if r_val > 0 else MIN_RUN_HOURS
                )

            # ── No compatible machines ────────────────────────
            if not compatible_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": "NONE DEFINED",
                    "Reason":              "Part has no compatible machines in VT matrix",
                    "Action_Needed":       "Add part to VT_Matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — not in matrix")
                continue

            available_mch = [m for m in compatible_mch if m not in exclude_machines]
            if not available_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              "All compatible machines dedicated to Runners",
                    "Action_Needed":       "Add more compatible machines in matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — machines Runner-dedicated")
                continue

            ranked, runner_lock = rank_machines(
                part, available_mch, compatibility,
                machine_hours, machine_last_part,
                changeover_dict, inv_days
            )

            if not ranked:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                if runner_lock:
                    last_m = next(
                        (m for m in available_mch if machine_last_part.get(m) == part), None)
                    free_l = round(AVAILABLE_HOURS - machine_hours.get(last_m, 0), 2) if last_m else 0
                    reason = (f"RUNNER (inv≤1d) — must stay on {last_m}, "
                              f"only {free_l}h free") if last_m else \
                             "RUNNER — no machine state (first run)"
                    action = f"Free capacity on {last_m}" if last_m else \
                             "Machine state saves after this run"
                elif all(h < MIN_RUN_HOURS for h in free_map.values()):
                    reason = ("All compatible machines full. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Reduce lower-priority part hours or plan tomorrow"
                else:
                    reason = ("Remaining hrs < MIN after changeover. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Check Inventory_Health sheet"

                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              reason,
                    "Action_Needed":       action,
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — {reason[:60]}")
                continue

            # ── Assign ────────────────────────────────────────
            assigned = False
            for m, cost, effective_free, co_hrs in ranked:
                run_h = min(target_hrs, effective_free)
                run_h = max(run_h, MIN_RUN_HOURS)
                run_h = min(run_h, effective_free)
                qty   = round(run_h * r_val, 0)

                machine_hours[m]        += (co_hrs + run_h)
                current_inventory[part]  = current_inventory.get(part, 0) + qty
                machine_last_part[m]     = part

                if category == "Runner":
                    runner_dedicated_machines.add(m)

                forced_tag = "ZERO-INV-FORCED" if inv_now == 0 else "Primary"
                plan.append({
                    "Part":              part,
                    "Category":          category,
                    "Machine":           m,
                    "Run_Hours":         round(run_h, 2),
                    "Changeover_Hrs":    round(co_hrs, 3),
                    "Total_Hrs_Used":    round(co_hrs + run_h, 2),
                    "Rate_Per_Hour":     round(r_val, 2),
                    "Production_Qty":    qty,
                    "Monthly_Indent":    round(monthly, 0),
                    "Daily_Indent":      round(daily, 2),
                    "Today_Target":      round(target, 0),
                    "Changeover":        "No" if co_hrs == 0 else "Yes",
                    "Type":              forced_tag,
                    "Runner_Lock":       "YES" if runner_lock else "No",
                    "Priority_Score":    round(indent_daily.get(part, 0), 2),
                    "Stagger_Adjusted":  "No",
                })
                co_str = "No" if co_hrs == 0 else f"Yes ({co_hrs*60:.0f}min)"
                tag    = "  [DEDICATED]" if category == "Runner" else \
                         "  [ZERO-INV FORCED]" if inv_now == 0 else ""
                print(f"    ✓ {part:30s} [{category:8s}] → {m:15s}  "
                      f"{run_h:.2f}h  qty={qty:>8.0f}  CO={co_str}{tag}")
                assigned = True
                break

            if not assigned:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              (
                        f"No single machine has {round(target_hrs,2)}h free after CO. "
                        + "Free: " + ", ".join(f"{m}={h}h" for m, h in free_map.items())
                    ),
                    "Action_Needed": "Reduce lower-priority hours or verify inventory covers gap",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — "
                      f"no machine has {round(target_hrs,2)}h free")

    # PASS 1 — Runners
    runner_parts     = [p for p in parts
                        if part_category.get(p, "Stranger") == "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]
    non_runner_parts = [p for p in parts
                        if part_category.get(p, "Stranger") != "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]

    run_assignment(runner_parts,
                   "PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer)")
    print(f"\n  Runner-dedicated machines: "
          f"{sorted(runner_dedicated_machines) if runner_dedicated_machines else 'none'}")

    # PASS 2 — Repeaters + Strangers
    run_assignment(non_runner_parts,
                   "PASS 2 — Repeaters + Strangers (Runner machines excluded)",
                   exclude_machines=runner_dedicated_machines)

    # 22-hour filler
    print(f"\n  22-hour filler:")
    fill_remaining_hours(
        plan, machine_hours, machine_last_part,
        list(parts), compatibility, machines,
        current_inventory, horizon_df
    )

    # Duplicate check
    part_counts = {}
    for row in plan:
        part_counts[row["Part"]] = part_counts.get(row["Part"], 0) + 1
    dupes = {p: c for p, c in part_counts.items() if c > 1}
    if dupes:
        print(f"  WARNING: duplicate parts: {dupes}")
    else:
        print(f"    No duplicate parts — each part appears exactly once  ✓")

    # Stagger
    stagger_changeovers(plan, machines, changeover_dict)

    # ── Inventory health ──────────────────────────────────────
    inv_rows = []
    for p in parts:
        inv_b    = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        monthly  = indent_monthly.get(p, 0)
        produced = sum(r["Production_Qty"] for r in plan if r["Part"] == p)
        inv_after = inv_b + produced
        days_cov  = inv_after / daily if daily > 0 else 0
        inv_rows.append({
            "Part":            p,
            "Monthly_Indent":  round(monthly, 0),
            "Daily_Indent":    round(daily, 2),
            "Inv_Before":      round(inv_b, 0),
            "Produced_Today":  round(produced, 0),
            "Inv_After_Today": round(inv_after, 0),
            "Days_Coverage":   round(days_cov, 2),
            "Status":          ("OK"       if days_cov >= TARGET_DAYS_INV
                                else "LOW"      if days_cov >= 1
                                else "CRITICAL"),
        })

    # ── Machine utilization ───────────────────────────────────
    mach_rows = []
    for m in machines:
        used      = machine_hours.get(m, 0)
        parts_run = [r["Part"] for r in plan if r["Machine"] == m]
        co_count  = sum(1 for r in plan if r["Machine"] == m and r.get("Changeover") == "Yes")
        util_pct  = round(used / AVAILABLE_HOURS * 100, 1)
        util_status = ("FULL"     if used >= AVAILABLE_HOURS - 0.5 else
                       "GOOD"     if used >= AVAILABLE_HOURS * 0.85 else
                       "PARTIAL"  if used >= AVAILABLE_HOURS * 0.5 else
                       "UNDERUSED")
        mach_rows.append({
            "Machine":              m,
            "Total_Available_Hrs":  AVAILABLE_HOURS,
            "Used_Hours":           round(used, 2),
            "Unused_Hours":         round(AVAILABLE_HOURS - used, 2),
            "Utilization_%":        util_pct,
            "Status":               util_status,
            "Parts_Planned":        len(parts_run),
            "Changeovers":          co_count,
            "Last_Part_Run":        machine_last_part.get(m) or "—",
            "All_Parts_On_Machine": ", ".join(parts_run) if parts_run else "— idle —",
        })

    plan_df     = pd.DataFrame(plan)         if plan         else pd.DataFrame()
    def_df      = pd.DataFrame(deferred)     if deferred     else pd.DataFrame()
    not_df      = pd.DataFrame(not_planned)  if not_planned  else pd.DataFrame()
    skip_df     = pd.DataFrame(skipped_log)  if skipped_log  else pd.DataFrame()
    mach_df     = pd.DataFrame(mach_rows)
    inv_df      = pd.DataFrame(inv_rows)

    if not plan_df.empty:
        plan_df["Category"] = plan_df["Part"].map(
            lambda p: part_category.get(p, "Stranger"))
        plan_df.insert(0, "Planning_Date", str(PLANNING_DATE))
        plan_df.insert(1, "Scenario",      scenario_desc)
        plan_df.insert(2, "Working_Days",  WORKING_DAYS)

    return plan_df, def_df, not_df, skip_df, mach_df, inv_df, machine_last_part, horizon_df

# =============================================================
# SECTION 16 — RUN VT SCHEDULER
# =============================================================

vt_parts = data[data["Material"].isin(vt_matrix["Part"])]["Material"].unique()

(vt_plan, vt_def, vt_not, vt_skip,
 vt_mach, vt_inv, vt_state, vt_horizon) = schedule(
    vt_parts, vt_compat, vt_machines, vt_changeover, "VT Machines"
)

save_machine_state(vt_state)

# =============================================================
# SECTION 17 — SAVE OUTPUT
# =============================================================

from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment
from openpyxl.utils import get_column_letter

HEADER_COLORS = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
}

STATUS_FILLS = {
    "FULL":               PatternFill("solid", fgColor="C6EFCE"),
    "GOOD":               PatternFill("solid", fgColor="DDEBF7"),
    "PARTIAL":            PatternFill("solid", fgColor="FFEB9C"),
    "UNDERUSED":          PatternFill("solid", fgColor="FFC7CE"),
    "OK":                 PatternFill("solid", fgColor="C6EFCE"),
    "LOW":                PatternFill("solid", fgColor="FFEB9C"),
    "CRITICAL":           PatternFill("solid", fgColor="FFC7CE"),
    "PRODUCTION NEEDED":  PatternFill("solid", fgColor="FFC7CE"),
    "ZERO INV — FORCED":  PatternFill("solid", fgColor="FFD7D7"),
    "INV SUFFICIENT":     PatternFill("solid", fgColor="C6EFCE"),
    "SKIPPED":            PatternFill("solid", fgColor="EDEDED"),
    "NO INDENT":          PatternFill("solid", fgColor="EDEDED"),
}

def style_sheet(ws, header_hex):
    hf = PatternFill("solid", fgColor=header_hex)
    for cell in ws[1]:
        cell.fill      = PatternFill("solid", fgColor=header_hex)
        cell.font      = Font(bold=True, color="FFFFFF", size=11)
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 32
    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value is not None), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(50, max_len + 3))
    headers = [cell.value for cell in ws[1]]
    for col_idx, col_name in enumerate(headers, start=1):
        if col_name and ("Status" in str(col_name) or "Indent_Status" in str(col_name)):
            for row in ws.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
                for cell in row:
                    fill = STATUS_FILLS.get(str(cell.value))
                    if fill:
                        cell.fill = fill
    ws.freeze_panes = "A2"


def build_machine_wise_plan(plan_df, machines):
    """
    Build the machine-wise sequenced plan with Rate_Per_Hour column included.
    One row per part per machine, plus a summary footer row per machine.
    """
    if plan_df.empty:
        return pd.DataFrame()

    def safe_float(val, default=0.0):
        try:
            v = float(val)
            return v if not np.isnan(v) else default
        except (TypeError, ValueError):
            return default

    def fmt_time(h):
        try:
            total_min = int(round(safe_float(h, 0.0) * 60))
            return f"{total_min // 60:02d}:{total_min % 60:02d}"
        except Exception:
            return "??"

    rows = []
    for m in machines:
        machine_rows = plan_df[plan_df["Machine"] == m].copy()
        if machine_rows.empty:
            continue

        cumulative_hrs = 0.0
        seq            = 1

        for _, pr in machine_rows.iterrows():
            part    = pr.get("Part", "—")
            run_h   = safe_float(pr.get("Run_Hours", 0))
            co_h    = safe_float(pr.get("Changeover_Hrs", 0))
            r_val   = safe_float(pr.get("Rate_Per_Hour", 0))
            co_mins = round(co_h * 60, 1)
            start_h = cumulative_hrs + co_h
            end_h   = start_h + run_h

            rows.append({
                "Machine":                m,
                "Seq":                    seq,
                "Part":                   part,
                "Category":               part_category.get(part, "Stranger"),
                "Rate_Per_Hour":          round(r_val, 2),          # ← added
                "Changeover_Before_Mins": co_mins,
                "Run_Hours":              round(run_h, 2),
                "Start_Time":             fmt_time(cumulative_hrs),
                "Start_After_CO":         fmt_time(start_h),
                "End_Time":               fmt_time(end_h),
                "Cumulative_Hrs":         round(end_h, 2),
                "Production_Qty":         safe_float(pr.get("Production_Qty", 0)),
                "Monthly_Indent":         safe_float(pr.get("Monthly_Indent", 0)),
                "Daily_Indent":           safe_float(pr.get("Daily_Indent", 0)),
                "Today_Target":           safe_float(pr.get("Today_Target", 0)),
                "Changeover":             pr.get("Changeover", "No") or "No",
                "Type":                   pr.get("Type", "Primary") or "Primary",
                "Runner_Lock":            pr.get("Runner_Lock", "No") or "No",
                "Row_Type":               "Part",
            })
            cumulative_hrs = end_h
            seq           += 1

        # Summary footer
        total_used     = round(cumulative_hrs, 2)
        co_hrs_series  = machine_rows["Changeover_Hrs"].apply(lambda x: safe_float(x, 0))
        total_co_mins  = round(co_hrs_series.sum() * 60, 1)
        total_prod_hrs = round(total_used - co_hrs_series.sum(), 2)
        total_qty      = machine_rows["Production_Qty"].apply(lambda x: safe_float(x, 0)).sum()
        co_count       = int(machine_rows["Changeover"].eq("Yes").sum())

        rows.append({
            "Machine":                m,
            "Seq":                    "—",
            "Part":                   f"TOTAL — {m}",
            "Category":               "—",
            "Rate_Per_Hour":          "—",
            "Changeover_Before_Mins": total_co_mins,
            "Run_Hours":              total_prod_hrs,
            "Start_Time":             "00:00",
            "Start_After_CO":         "—",
            "End_Time":               fmt_time(total_used),
            "Cumulative_Hrs":         total_used,
            "Production_Qty":         round(total_qty, 0),
            "Monthly_Indent":         "—",
            "Daily_Indent":           "—",
            "Today_Target":           "—",
            "Changeover":             f"{co_count} changeovers",
            "Type":                   f"Used {total_used}h / {AVAILABLE_HOURS}h  |  Unused {round(AVAILABLE_HOURS-total_used,2)}h",
            "Runner_Lock":            "—",
            "Row_Type":               "Summary",
        })
        rows.append({k: "" for k in rows[-1].keys()})

    return pd.DataFrame(rows)


def style_machine_wise_sheet(ws):
    header_fill  = PatternFill("solid", fgColor="1F4E79")
    header_font  = Font(bold=True, color="FFFFFF", size=11)
    summary_fill = PatternFill("solid", fgColor="0D9488")
    summary_font = Font(bold=True, color="FFFFFF", size=11)
    part_fills   = [
        PatternFill("solid", fgColor="EFF6FF"),
        PatternFill("solid", fgColor="F0FDF4"),
    ]
    co_fill = PatternFill("solid", fgColor="FEF9C3")

    for cell in ws[1]:
        cell.fill      = header_fill
        cell.font      = header_font
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 30

    headers      = [cell.value for cell in ws[1]]
    row_type_col = headers.index("Row_Type")  + 1 if "Row_Type"  in headers else None
    co_col       = headers.index("Changeover") + 1 if "Changeover" in headers else None
    machine_col  = headers.index("Machine")   + 1 if "Machine"   in headers else None

    machine_color_idx = 0
    current_machine   = None

    for row in ws.iter_rows(min_row=2):
        row_type = row[row_type_col - 1].value if row_type_col else ""
        machine  = row[machine_col  - 1].value if machine_col  else ""
        if machine and machine != current_machine:
            current_machine   = machine
            machine_color_idx = (machine_color_idx + 1) % 2
        if row_type == "Summary":
            for cell in row:
                cell.fill = summary_fill
                cell.font = summary_font
                cell.alignment = Alignment(horizontal="center", vertical="center")
        elif row_type == "Part":
            bg = part_fills[machine_color_idx]
            for cell in row:
                cell.fill      = bg
                cell.alignment = Alignment(vertical="center")
            if co_col and row[co_col - 1].value == "Yes":
                row[co_col - 1].fill = co_fill

    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(40, max_len + 3))
    ws.freeze_panes = "C2"


# =============================================================
# SECTION 17A — WRITE EXCEL
# =============================================================

print(f"\nWriting → {output_path}")

vt_mw = build_machine_wise_plan(vt_plan, vt_machines)

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    vt_mw.to_excel(writer,      sheet_name="VT_Plan_By_Machine",    index=False)
    vt_plan.to_excel(writer,    sheet_name="VT_Plan",               index=False)
    vt_mach.to_excel(writer,    sheet_name="VT_Machine_Util",       index=False)
    vt_not.to_excel(writer,     sheet_name="VT_Not_Planned",        index=False)
    vt_def.to_excel(writer,     sheet_name="VT_Not_Required_Today", index=False)
    vt_skip.to_excel(writer,    sheet_name="VT_Skipped_Parts",      index=False)
    vt_inv.to_excel(writer,     sheet_name="VT_Inventory_Health",   index=False)
    vt_horizon.to_excel(writer, sheet_name="VT_Indent_Horizon",     index=False)

wb = load_workbook(output_path)

if "VT_Plan_By_Machine" in wb.sheetnames:
    style_machine_wise_sheet(wb["VT_Plan_By_Machine"])

for sheet_name, header_hex in HEADER_COLORS.items():
    if sheet_name in wb.sheetnames and sheet_name != "VT_Plan_By_Machine":
        style_sheet(wb[sheet_name], header_hex)

tab_colors = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
}
for name, color in tab_colors.items():
    if name in wb.sheetnames:
        wb[name].sheet_properties.tabColor = color

wb.save(output_path)
print(f"  Formatting applied  ✓")

# =============================================================
# SECTION 18 — SUMMARY PRINT
# =============================================================

print(f"\n{'='*62}")
print(f"  Smart APS V6 Complete  —  VT Only  —  {PLANNING_DATE}")
print(f"  Indent month  : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Working days  : {WORKING_DAYS}  ({TOTAL_DAYS} days − {SUNDAY_COUNT} Sundays)")
print(f"{'='*62}")
print(f"  planned            = {len(vt_plan):>4}")
print(f"  not_required_today = {len(vt_def):>4}  (inv covers daily indent)")
print(f"  skipped            = {len(vt_skip):>4}  (indent < {MIN_MONTHLY_INDENT} qty  OR  whole indent ≤ {MIN_INDENT_HOURS}h)")
print(f"  not_planned        = {len(vt_not):>4}  (needed but no machine capacity)")
print(f"\n  Output  → {output_path}")
print(f"  State   → {MACHINE_STATE_FILE}")
print(f"\n  NOTE: Update SECTION 1 each morning:")
print(f"        PLANNING_DATE = date(2026, 3, 15)")
print(f"        INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over")
# Out:
# ==============================================================
#   Smart APS V6  —  VT-Only Indent-Based Planning
#   Planning date  : 2026-03-18
#   Indent month   : March 2026
#   Total days     : 31
#   Sundays        : 5
#   Working days   : 26  (used as divisor)
#   Daily target   : monthly_indent / 26
#   Today target   : max(0, daily_indent - inventory)
#   Skip rule 1    : monthly_indent < 150 qty
#   Skip rule 2    : monthly_indent / rate  ≤ 4.0h (trivial run)
#   Zero-inv rule  : inventory=0 parts always forced into plan
# ==============================================================
#
# Loading data...
#   VT parts after merge with stats: 103
#
# Reading indent data from VT sheet...
#   Book1 'VT' — Part col: 'Part'  Indent col: 'Indent'
#
#   Indent summary:
#     Total VT parts with indent data : 142
#     Parts skipped (low/trivial)     : 30
#     Parts with zero inventory       : 71  (forced into plan regardless)
#     SKIP  S31740-008A0X                   Whole monthly indent takes only 2.09h ≤ 4.0h threshold
#     SKIP  S31838-004A0X                   Whole monthly indent takes only 4.00h ≤ 4.0h threshold
#     SKIP  S31135-011A0X                   Whole monthly indent takes only 0.89h ≤ 4.0h threshold
#     SKIP  S31868-005A0X                   Whole monthly indent takes only 1.40h ≤ 4.0h threshold
#     SKIP  S12113-001A0X                   Monthly indent 46 < 150 (threshold)
#     SKIP  S12094-001A0X                   Monthly indent 30 < 150 (threshold)
#     SKIP  S13081-004A0X                   Monthly indent 6 < 150 (threshold)
#     SKIP  S41356-017A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S41222-022                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22085-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22063-003A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250068-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S01100-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250069-001                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21175-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S12087-004                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11436-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11340-008A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11122-015A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S13092-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S310966-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21021-021A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11358-028A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S21009-009A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S311010-03                      Monthly indent 0 < 150 (threshold)
#     SKIP  S31605-002A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S120197-005                     Monthly indent 0 < 150 (threshold)
#     SKIP  S110432-007                     Monthly indent 0 < 150 (threshold)
#     SKIP  14SW250069-00002X1              Monthly indent 0 < 150 (threshold)
#     SKIP  S03062-001A0X                   Monthly indent 0 < 150 (threshold)
#
#   VT changeover times loaded: 26 machines
#     JSW 1ST                   → 50 min (0.833 h)
#     M.P-01                    → 40 min (0.667 h)
#     M.P-03                    → 30 min (0.500 h)
#     M.P-04                    → 30 min (0.500 h)
#     M.P-05                    → 40 min (0.667 h)
#     M.P-07                    → 30 min (0.500 h)
#     M.P-08                    → 30 min (0.500 h)
#     M.P-09                    → 30 min (0.500 h)
#     M.P-10                    → 40 min (0.667 h)
#     M.P-11                    → 40 min (0.667 h)
#     M.P-12                    → 30 min (0.500 h)
#     M.P-13                    → 30 min (0.500 h)
#     M.P-14                    → 30 min (0.500 h)
#     M.P-15                    → 40 min (0.667 h)
#     M.P-16                    → 30 min (0.500 h)
#     M.P-17                    → 40 min (0.667 h)
#     TOYO 1ST                  → 50 min (0.833 h)
#     TOYO 2ND                  → 50 min (0.833 h)
#     TOYO 3RD                  → 50 min (0.833 h)
#     TOYO 4TH                  → 50 min (0.833 h)
#     TOYO 5TH                  → 50 min (0.833 h)
#     TOYO 6TH                  → 50 min (0.833 h)
#     TOYO 7TH                  → 50 min (0.833 h)
#     TOYO 80T 1ST              → 60 min (1.000 h)
#     TOYO 80T 2ND              → 60 min (1.000 h)
#     YUDEK 1ST                 → 30 min (0.500 h)
#   Book1 'VT' — Part col: 'Part'  Category col: 'Category'
#   Part categories — Runner: 17  Repeater: 3  Stranger: 122
#
#   Machine state loaded:
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S12106-001A0X
#     M.P-12                    last ran → S31842-004A0X
#     M.P-05                    last ran → S13116-011A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S31064-006A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S31068-005A0X
#     M.P-07                    last ran → S03044-005A0X
#     TOYO 6TH                  last ran → S01100-004A9X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13120-001A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S13114-003A0X
#     M.P-01                    last ran → S13080-004A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S11398-018A0X
#     M.P-13                    last ran → S33045-010A0X
#     M.P-15                    last ran → 14SW030082-00001X0
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#
# ──────────────────────────────────────────────────────────────
#   VT Machines  |  103 parts  |  26 machines
# ──────────────────────────────────────────────────────────────
#   SCENARIO 1 — 76/95 parts critical (inv < 1 day indent)
#
#   Parts requiring production today (76):
#   Part                             Monthly    Daily       Inv    Target  Status
#   ──────────────────────────────  ────────  ───────  ────────  ────────  ────────────────────
#   14SW030081-00001X0                  8992   345.85         0       346  ZERO INV — FORCED
#   14SW030082-00001X0                  3167   121.81         0       122  ZERO INV — FORCED
#   14SW110487-00002X0                  1980    76.15         0        76  ZERO INV — FORCED
#   14SW210274-00008X0                260427  10016.42      6904      3112  PRODUCTION NEEDED
#   14SW210274-00013X0                115909  4458.04      2896      1562  PRODUCTION NEEDED
#   14SW210274-00016X0                115909  4458.04        30      4428  PRODUCTION NEEDED
#   14SW220197-00005X0                 22890   880.38         0       880  ZERO INV — FORCED
#   14SW220197-00010X0                 22890   880.38         8       872  PRODUCTION NEEDED
#   14SW220201-00005X0                  9959   383.04         0       383  ZERO INV — FORCED
#   14SW220201-00010X0                111888  4303.38         0      4303  ZERO INV — FORCED
#   14SW311082-00006X0                 68972  2652.77         2      2651  PRODUCTION NEEDED
#   14SW311082-00010X0                  5952   228.92       107       122  PRODUCTION NEEDED
#   14SW311083-00005X0                  5237   201.42       108        93  PRODUCTION NEEDED
#   14SW330127-00008X0                  8895   342.12        22       320  PRODUCTION NEEDED
#   14SW410464-00009X0                 19627   754.88         0       755  ZERO INV — FORCED
#   S01100-004A9X                      41737  1605.27         0      1605  ZERO INV — FORCED
#   S02020-010A0X                       3066   117.92         0       118  ZERO INV — FORCED
#   S03044-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S03046-005A0X                      20860   802.31         0       802  ZERO INV — FORCED
#   S03066-001A0X                       1622    62.38        14        48  PRODUCTION NEEDED
#   S11160-006A0X                         26     1.00         0         1  ZERO INV — FORCED
#   S11332-002A0X                         12     0.46         0         0  ZERO INV — FORCED
#   S11398-017A0X                       8036   309.08        92       217  PRODUCTION NEEDED
#   S11398-018A0X                       1707    65.65        10        56  PRODUCTION NEEDED
#   S11398-030A0X                       5696   219.08        36       183  PRODUCTION NEEDED
#   S12042-004A9X                      11806   454.08         0       454  ZERO INV — FORCED
#   S12052-003A0X                       7398   284.54         0       285  ZERO INV — FORCED
#   S12071-001A0X                        138     5.31         0         5  ZERO INV — FORCED
#   S12087-004A0X                      17336   666.77         0       667  ZERO INV — FORCED
#   S12089-001A0X                       6557   252.19         0       252  ZERO INV — FORCED
#   S12091-001A0X                       5697   219.12         0       219  ZERO INV — FORCED
#   S12094-003A0X                        246     9.46         0         9  ZERO INV — FORCED
#   S12095-003A0X                      25351   975.04       189       786  PRODUCTION NEEDED
#   S12095-004A0X                      17910   688.85         0       689  ZERO INV — FORCED
#   S12095-011A0X                      20941   805.42       443       362  PRODUCTION NEEDED
#   S12100-003A0X                      87393  3361.27         0      3361  ZERO INV — FORCED
#   S12102-001A0X                       2250    86.54         0        87  ZERO INV — FORCED
#   S12104-006A0X                      35975  1383.65         0      1384  ZERO INV — FORCED
#   S12106-001A0X                        216     8.31         0         8  ZERO INV — FORCED
#   S13071-012A0X                          6     0.23         0         0  ZERO INV — FORCED
#   S13080-004A0X                       1320    50.77         0        51  ZERO INV — FORCED
#   S13083-003A0X                      35277  1356.81       429       928  PRODUCTION NEEDED
#   S13083-011A0X                      21068   810.31         0       810  ZERO INV — FORCED
#   S13098-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S13108-002A0X                     173611  6677.35      1045      5632  PRODUCTION NEEDED
#   S13110-005A0X                      15629   601.12         0       601  ZERO INV — FORCED
#   S13112-006A0X                      29608  1138.77         0      1139  ZERO INV — FORCED
#   S13114-003A0X                        240     9.23         0         9  ZERO INV — FORCED
#   S13116-011A0X                       5322   204.69         0       205  ZERO INV — FORCED
#   S13120-001A0X                       2481    95.42         0        95  ZERO INV — FORCED
#   S13123-002A0X                       6760   260.00         0       260  ZERO INV — FORCED
#   S21021-012A0X                       7490   288.08         0       288  ZERO INV — FORCED
#   S21021-016A0X                       6710   258.08       217        41  PRODUCTION NEEDED
#   S21174-012A0X                     313865  12071.73         0     12072  ZERO INV — FORCED
#   S22127-003A0X                     295580  11368.46         0     11368  ZERO INV — FORCED
#   S25026-003A0X                        750    28.85         0        29  ZERO INV — FORCED
#   S25038-001A0X                      79058  3040.69       935      2106  PRODUCTION NEEDED
#   S31064-006A0X                        324    12.46         0        12  ZERO INV — FORCED
#   S31068-005A0X                        180     6.92         0         7  ZERO INV — FORCED
#   S31121-012A0X                      92130  3543.46         0      3543  ZERO INV — FORCED
#   S31123-005A0X                       1884    72.46         8        64  PRODUCTION NEEDED
#   S31437-004A0X                      68309  2627.27         0      2627  ZERO INV — FORCED
#   S31741-005A0X                      63205  2430.96         0      2431  ZERO INV — FORCED
#   S31839-004A0X                        867    33.35         0        33  ZERO INV — FORCED
#   S31842-004A0X                        360    13.85         0        14  ZERO INV — FORCED
#   S31851-002A0X                         36     1.38         0         1  ZERO INV — FORCED
#   S31867-002A0X                       8208   315.69         0       316  ZERO INV — FORCED
#   S32168-007A0X                      13608   523.38       207       316  PRODUCTION NEEDED
#   S32197-006A0X                     183056  7040.62         0      7041  ZERO INV — FORCED
#   S33045-010A0X                         58     2.23         0         2  ZERO INV — FORCED
#   S33105-016A0X                      15120   581.54         0       582  ZERO INV — FORCED
#   S33105-017A0X                      24089   926.50       185       742  PRODUCTION NEEDED
#   S33106-009A0X                          2     0.08         0         0  ZERO INV — FORCED
#   S33107-005A0X                         36     1.38         0         1  ZERO INV — FORCED
#   S41354-011A0X                      18713   719.73         0       720  ZERO INV — FORCED
#   S41356-021A0X                       3570   137.31       116        21  PRODUCTION NEEDED
#
#   Priority order — sorted by daily_indent descending (76 active parts):
#   Part                              Daily       Inv    Target  Zero_Inv
#   ──────────────────────────────  ───────  ────────  ────────  ────────
#   S21174-012A0X                   12071.73         0     12072       YES
#   S22127-003A0X                   11368.46         0     11368       YES
#   14SW210274-00008X0              10016.42      6904      3112        No
#   S32197-006A0X                   7040.62         0      7041       YES
#   S13108-002A0X                   6677.35      1045      5632        No
#   14SW210274-00013X0              4458.04      2896      1562        No
#   14SW210274-00016X0              4458.04        30      4428        No
#   14SW220201-00010X0              4303.38         0      4303       YES
#   S31121-012A0X                   3543.46         0      3543       YES
#   S12100-003A0X                   3361.27         0      3361       YES
#   S25038-001A0X                   3040.69       935      2106        No
#   14SW311082-00006X0              2652.77         2      2651        No
#   S31437-004A0X                   2627.27         0      2627       YES
#   S31741-005A0X                   2430.96         0      2431       YES
#   S01100-004A9X                   1605.27         0      1605       YES
#   S12104-006A0X                   1383.65         0      1384       YES
#   S13083-003A0X                   1356.81       429       928        No
#   S13112-006A0X                   1138.77         0      1139       YES
#   S12095-003A0X                    975.04       189       786        No
#   S33105-017A0X                    926.50       185       742        No
#   14SW220197-00005X0               880.38         0       880       YES
#   14SW220197-00010X0               880.38         8       872        No
#   S13083-011A0X                    810.31         0       810       YES
#   S12095-011A0X                    805.42       443       362        No
#   S03046-005A0X                    802.31         0       802       YES
#   14SW410464-00009X0               754.88         0       755       YES
#   S41354-011A0X                    719.73         0       720       YES
#   S12095-004A0X                    688.85         0       689       YES
#   S12087-004A0X                    666.77         0       667       YES
#   S13110-005A0X                    601.12         0       601       YES
#   S33105-016A0X                    581.54         0       582       YES
#   S32168-007A0X                    523.38       207       316        No
#   S12042-004A9X                    454.08         0       454       YES
#   14SW220201-00005X0               383.04         0       383       YES
#   14SW030081-00001X0               345.85         0       346       YES
#   14SW330127-00008X0               342.12        22       320        No
#   S31867-002A0X                    315.69         0       316       YES
#   S11398-017A0X                    309.08        92       217        No
#   S21021-012A0X                    288.08         0       288       YES
#   S12052-003A0X                    284.54         0       285       YES
#   S13123-002A0X                    260.00         0       260       YES
#   S21021-016A0X                    258.08       217        41        No
#   S12089-001A0X                    252.19         0       252       YES
#   14SW311082-00010X0               228.92       107       122        No
#   S12091-001A0X                    219.12         0       219       YES
#   S11398-030A0X                    219.08        36       183        No
#   S13116-011A0X                    204.69         0       205       YES
#   14SW311083-00005X0               201.42       108        93        No
#   S41356-021A0X                    137.31       116        21        No
#   14SW030082-00001X0               121.81         0       122       YES
#   S02020-010A0X                    117.92         0       118       YES
#   S13120-001A0X                     95.42         0        95       YES
#   S12102-001A0X                     86.54         0        87       YES
#   14SW110487-00002X0                76.15         0        76       YES
#   S31123-005A0X                     72.46         8        64        No
#   S11398-018A0X                     65.65        10        56        No
#   S03066-001A0X                     62.38        14        48        No
#   S13080-004A0X                     50.77         0        51       YES
#   S31839-004A0X                     33.35         0        33       YES
#   S25026-003A0X                     28.85         0        29       YES
#   S31842-004A0X                     13.85         0        14       YES
#   S31064-006A0X                     12.46         0        12       YES
#   S12094-003A0X                      9.46         0         9       YES
#   S13114-003A0X                      9.23         0         9       YES
#   S12106-001A0X                      8.31         0         8       YES
#   S31068-005A0X                      6.92         0         7       YES
#   S12071-001A0X                      5.31         0         5       YES
#   S03044-005A0X                      2.31         0         2       YES
#   S13098-005A0X                      2.31         0         2       YES
#   S33045-010A0X                      2.23         0         2       YES
#   S31851-002A0X                      1.38         0         1       YES
#   S33107-005A0X                      1.38         0         1       YES
#   S11160-006A0X                      1.00         0         1       YES
#   S11332-002A0X                      0.46         0         0       YES
#   S13071-012A0X                      0.23         0         0       YES
#   S33106-009A0X                      0.08         0         0       YES
#
#   PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer):
#     ✓ S21174-012A0X                  [Runner  ] → JSW 1ST          22.00h  qty=   13200  CO=No  [DEDICATED]
#     ✓ S22127-003A0X                  [Runner  ] → TOYO 3RD         22.00h  qty=   12185  CO=No  [DEDICATED]
#     ✓ 14SW210274-00008X0             [Runner  ] → TOYO 1ST         22.00h  qty=   11314  CO=No  [DEDICATED]
#     ✗ S32197-006A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ S13108-002A0X                  [Runner  ] → M.P-17           22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ 14SW210274-00013X0             [Runner  ] → M.P-09           5.02h  qty=    6020  CO=No  [DEDICATED]
#     ✗ 14SW210274-00016X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ 14SW220201-00010X0             [Runner  ] → M.P-04           22.00h  qty=    6336  CO=No  [DEDICATED]
#     ✓ S31121-012A0X                  [Runner  ] → M.P-16           22.00h  qty=    2829  CO=No  [DEDICATED]
#     ✓ S12100-003A0X                  [Runner  ] → TOYO 80T 2ND     22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ S25038-001A0X                  [Runner  ] → TOYO 4TH         20.73h  qty=    5146  CO=No  [DEDICATED]
#     ✗ 14SW311082-00006X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31437-004A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31741-005A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ S01100-004A9X                  [Runner  ] → TOYO 6TH         7.13h  qty=    3211  CO=No  [DEDICATED]
#
#   Runner-dedicated machines: ['JSW 1ST', 'M.P-04', 'M.P-09', 'M.P-16', 'M.P-17', 'TOYO 1ST', 'TOYO 3RD', 'TOYO 4TH', 'TOYO 6TH', 'TOYO 80T 2ND']
#
#   PASS 2 — Repeaters + Strangers (Runner machines excluded):
#     ✓ S12104-006A0X                  [Repeater] → M.P-05           17.30h  qty=    1384  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S13083-003A0X                  [Repeater] → M.P-11           7.73h  qty=     928  CO=Yes (40min)
#     ✓ S13112-006A0X                  [Repeater] → YUDEK 1ST        4.74h  qty=    1139  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12095-003A0X                  [Stranger] → M.P-12           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S33105-017A0X                  [Stranger] → M.P-14           4.00h  qty=    6400  CO=Yes (30min)
#     ✓ 14SW220197-00005X0             [Stranger] → M.P-01           4.00h  qty=    1152  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW220197-00010X0             [Stranger] → M.P-03           4.00h  qty=    1516  CO=Yes (30min)
#     ✓ S13083-011A0X                  [Stranger] → M.P-07           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12095-011A0X                  [Stranger] → M.P-08           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S03046-005A0X                  [Stranger] → TOYO 5TH         4.00h  qty=    2400  CO=No  [ZERO-INV FORCED]
#     ✓ 14SW410464-00009X0             [Stranger] → M.P-13           4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S41354-011A0X                  [Stranger] → M.P-10           9.60h  qty=     720  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12095-004A0X                  [Stranger] → M.P-15           8.61h  qty=     689  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12087-004A0X                  [Stranger] → TOYO 80T 1ST     7.04h  qty=     667  CO=Yes (60min)  [ZERO-INV FORCED]
#     ✓ S13110-005A0X                  [Stranger] → TOYO 2ND         4.00h  qty=    2400  CO=No  [ZERO-INV FORCED]
#     ✓ S33105-016A0X                  [Stranger] → TOYO 80T 1ST     4.00h  qty=     960  CO=Yes (60min)  [ZERO-INV FORCED]
#     ✓ S32168-007A0X                  [Stranger] → M.P-12           4.00h  qty=    1920  CO=Yes (30min)
#     ✓ S12042-004A9X                  [Stranger] → M.P-14           4.00h  qty=    2057  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW220201-00005X0             [Stranger] → M.P-01           4.00h  qty=     800  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW030081-00001X0             [Stranger] → M.P-11           4.00h  qty=     640  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW330127-00008X0             [Stranger] → TOYO 80T 1ST     4.00h  qty=     720  CO=Yes (60min)
#     ✓ S31867-002A0X                  [Stranger] → M.P-03           4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11398-017A0X                  [Stranger] → M.P-07           4.00h  qty=    1920  CO=Yes (30min)
#     ✓ S21021-012A0X                  [Stranger] → M.P-15           4.00h  qty=     360  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12052-003A0X                  [Stranger] → M.P-08           4.00h  qty=     514  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S13123-002A0X                  [Stranger] → M.P-13           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S21021-016A0X                  [Stranger] → M.P-01           4.00h  qty=    1152  CO=Yes (40min)
#     ✓ S12089-001A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW311082-00010X0             [Stranger] → M.P-12           4.00h  qty=     720  CO=Yes (30min)
#     ✓ S12091-001A0X                  [Stranger] → M.P-14           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11398-030A0X                  [Stranger] → M.P-10           4.00h  qty=     480  CO=Yes (40min)
#     ✓ S13116-011A0X                  [Stranger] → M.P-11           4.00h  qty=     450  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW311083-00005X0             [Stranger] → M.P-03           4.00h  qty=    1029  CO=Yes (30min)
#     ✓ S41356-021A0X                  [Stranger] → M.P-07           4.00h  qty=     180  CO=Yes (30min)
#     ✓ 14SW030082-00001X0             [Stranger] → M.P-15           4.00h  qty=     640  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S02020-010A0X                  [Stranger] → M.P-08           4.00h  qty=    1600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S13120-001A0X                  [Stranger] → M.P-01           4.00h  qty=     480  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12102-001A0X                  [Stranger] → M.P-13           4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW110487-00002X0             [Stranger] → YUDEK 1ST        4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31123-005A0X                  [Stranger] → M.P-12           4.00h  qty=    1440  CO=Yes (30min)
#     ✓ S11398-018A0X                  [Stranger] → M.P-10           4.00h  qty=     640  CO=Yes (40min)
#     ✓ S03066-001A0X                  [Stranger] → M.P-14           4.00h  qty=    1309  CO=Yes (30min)
#     ✗ S13080-004A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=4.04h, M.
#     ✓ S31839-004A0X                  [Stranger] → M.P-03           4.00h  qty=     800  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S25026-003A0X                  [Stranger] → TOYO 7TH         4.00h  qty=     670  CO=No  [ZERO-INV FORCED]
#     ✓ S31842-004A0X                  [Stranger] → M.P-07           4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31064-006A0X                  [Stranger] → M.P-08           4.00h  qty=     600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S12094-003A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=4.04h, M.
#     ✓ S13114-003A0X                  [Stranger] → M.P-13           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12106-001A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S31068-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S12071-001A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=4.04h, M.
#     ✗ S03044-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S13098-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=4.04h, M.
#     ✗ S33045-010A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S31851-002A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S33107-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=4.04h, M.
#     ✗ S11160-006A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S11332-002A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S13071-012A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S33106-009A0X                  [Stranger]  NOT PLANNED — All compatible machines full. Free: TOYO 80T 1ST=3.96h
#
#   22-hour filler:
#     ↑ S13112-006A0X                  → YUDEK 1ST        +3.26h merged  qty+=782  [EXTEND]
#     ↑ S12095-003A0X                  → M.P-12           +4.00h merged  qty+=960  [EXTEND]
#     ↑ S12104-006A0X                  → M.P-05           +4.04h merged  qty+=323  [EXTEND]
#     ↑ S33105-017A0X                  → M.P-14           +4.00h merged  qty+=6400  [EXTEND]
#     ↑ S12087-004A0X                  → TOYO 80T 1ST     +3.96h merged  qty+=375  [EXTEND]
#     ↑ S13110-005A0X                  → TOYO 2ND         +18.00h merged  qty+=10800  [EXTEND]
#     ↑ 14SW220197-00010X0             → M.P-03           +4.00h merged  qty+=1516  [EXTEND]
#     ↑ S13083-011A0X                  → M.P-07           +4.00h merged  qty+=1440  [EXTEND]
#     ↑ S01100-004A9X                  → TOYO 6TH         +14.87h merged  qty+=6692  [EXTEND]
#     ↑ S25026-003A0X                  → TOYO 7TH         +18.00h merged  qty+=3014  [EXTEND]
#     ↑ S13083-003A0X                  → M.P-11           +4.27h merged  qty+=512  [EXTEND]
#     ↑ 14SW210274-00013X0             → M.P-09           +16.98h merged  qty+=20376  [EXTEND]
#     ↑ S12095-011A0X                  → M.P-08           +4.00h merged  qty+=960  [EXTEND]
#     ↑ 14SW220197-00005X0             → M.P-01           +3.33h merged  qty+=959  [EXTEND]
#     ↑ S41354-011A0X                  → M.P-10           +2.40h merged  qty+=180  [EXTEND]
#     ↑ 14SW410464-00009X0             → M.P-13           +4.00h merged  qty+=1920  [EXTEND]
#     ↑ S12095-004A0X                  → M.P-15           +3.39h merged  qty+=271  [EXTEND]
#     ↑ S25038-001A0X                  → TOYO 4TH         +1.27h merged  qty+=315  [EXTEND]
#     ↑ S03046-005A0X                  → TOYO 5TH         +18.00h merged  qty+=10800  [EXTEND]
#     No duplicate parts — each part appears exactly once  ✓
#
#   Tool-changer stagger:
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-01          conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ YUDEK 1ST       conflict resolved (Option A)
#     ✓ YUDEK 1ST       conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ YUDEK 1ST       conflict resolved (Option A)
#     ✓ YUDEK 1ST       conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ YUDEK 1ST       conflict resolved (Option A)
#     ✓ YUDEK 1ST       conflict resolved (Option B)
#     ✓ YUDEK 1ST       conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#     ✓ M.P-12          conflict resolved (Option A)
#     ⚠ Cannot resolve conflict — insufficient capacity to shift
#     ✓ M.P-12          conflict resolved (Option B)
#   ⚠ Stagger did not fully resolve in 20 passes — check manually
#
#   Machine state saved → machine_state.json
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S12106-001A0X
#     M.P-12                    last ran → S31123-005A0X
#     M.P-05                    last ran → S12104-006A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S03066-001A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S31839-004A0X
#     M.P-07                    last ran → S31842-004A0X
#     TOYO 6TH                  last ran → S01100-004A9X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13116-011A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S31064-006A0X
#     M.P-01                    last ran → S13120-001A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S11398-018A0X
#     M.P-13                    last ran → S13114-003A0X
#     M.P-15                    last ran → 14SW030082-00001X0
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#
# Writing → Smart_APS_Plan_20260318Indent.xlsx
#   Formatting applied  ✓
#
# ==============================================================
#   Smart APS V6 Complete  —  VT Only  —  2026-03-18
#   Indent month  : March 2026
#   Working days  : 26  (31 days − 5 Sundays)
# ==============================================================
#   planned            =   58
#   not_required_today =    0  (inv covers daily indent)
#   skipped            =    7  (indent < 150 qty  OR  whole indent ≤ 4.0h)
#   not_planned        =   18  (needed but no machine capacity)
#
#   Output  → Smart_APS_Plan_20260318Indent.xlsx
#   State   → machine_state.json
#
#   NOTE: Update SECTION 1 each morning:
#         PLANNING_DATE = date(2026, 3, 15)
#         INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over

# %%
import pandas as pd
import numpy as np
import json
import os
import calendar
from datetime import datetime, date

# =============================================================
# ██████╗  █████╗ ██████╗  █████╗ ███╗   ███╗███████╗
# ██╔══██╗██╔══██╗██╔══██╗██╔══██╗████╗ ████║██╔════╝
# ██████╔╝███████║██████╔╝███████║██╔████╔██║███████╗
# ██╔═══╝ ██╔══██║██╔══██╗██╔══██║██║╚██╔╝██║╚════██║
# ██║     ██║  ██║██║  ██║██║  ██║██║ ╚═╝ ██║███████║
# ╚═╝     ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝
#
#  Smart APS V6  —  VT-Only Indent-Based Planning
#
#  Planning logic:
#    daily_indent  = monthly_indent / working_days
#    today_target  = max(0, daily_indent − inventory)
#    working_days  = calendar days in month − number of Sundays
#
#  Skip rules (part excluded from planning entirely):
#    • monthly_indent < 100
#    • monthly_indent / rate  ≤ 2 hours  (whole indent is trivial)
#
#  Zero-inventory rule:
#    If inventory = 0, part is FORCED into plan regardless of
#    skip rules. Parts sorted by highest daily_indent first
#    (greedy fill) so most critical parts always get time.
# =============================================================

# =============================================================
# SECTION 1 — DAILY SETTINGS  (change these every morning)
# -------------------------------------------------------------
# Only two lines to update each day:
#   PLANNING_DATE  : today
#   INDENT_MONTH   : only change when the month rolls over
# =============================================================

PLANNING_DATE = date(2026, 3, 18)   # ← change daily
INDENT_MONTH  = date(2026, 3,  1)   # ← change when month rolls over

# =============================================================
# SECTION 2 — PARAMETERS
# =============================================================

AVAILABLE_HOURS    = 22        # machine hours available per shift
MIN_RUN_HOURS      = 4         # minimum run block per part
TARGET_DAYS_INV    = 3         # ideal inventory buffer (days)
MACHINE_STATE_FILE = "machine_state.json"

# Skip thresholds
MIN_MONTHLY_INDENT = 150       # skip if monthly indent < this
MIN_INDENT_HOURS   = 4.0       # skip if whole monthly indent takes ≤ this many hours
                               # (monthly_indent / rate ≤ MIN_INDENT_HOURS)
                               # EXCEPTION: zero-inventory parts are never skipped

# Priority: parts are sorted purely by daily_indent descending.
# Highest daily indent = most critical = planned first.
# Within same daily_indent, zero-inventory parts rank above others.

# =============================================================
# SECTION 3 — FILE PATHS
# =============================================================

book_path       = "C:/Users/Ex0164/Book1.xlsx"
matrix_path     = "C:/Users/Ex0164/Important codes/compatibility_matrix.xlsx"
changeover_path = "D:/Tushar/TOOL FIX/Unique_Machines_vt.xlsx"
output_path     = f"1Smart_APS_Plan_{PLANNING_DATE.strftime('%Y%m%d')}Indent.xlsx"

# =============================================================
# SECTION 4 — WORKING DAYS CALCULATION
# -------------------------------------------------------------
# working_days = calendar days in INDENT_MONTH − Sundays
# Example: March 2026 → 31 days, 5 Sundays → 26 working days
# =============================================================

def compute_working_days(ref_date):
    year  = ref_date.year
    month = ref_date.month
    total = calendar.monthrange(year, month)[1]
    sundays = sum(
        1 for d in range(1, total + 1)
        if date(year, month, d).weekday() == 6
    )
    return total - sundays, total, sundays

WORKING_DAYS, TOTAL_DAYS, SUNDAY_COUNT = compute_working_days(INDENT_MONTH)

print(f"\n{'='*62}")
print(f"  Smart APS V6  —  VT-Only Indent-Based Planning")
print(f"  Planning date  : {PLANNING_DATE}")
print(f"  Indent month   : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Total days     : {TOTAL_DAYS}")
print(f"  Sundays        : {SUNDAY_COUNT}")
print(f"  Working days   : {WORKING_DAYS}  (used as divisor)")
print(f"  Daily target   : monthly_indent / {WORKING_DAYS}")
print(f"  Today target   : max(0, daily_indent - inventory)")
print(f"  Skip rule 1    : monthly_indent < {MIN_MONTHLY_INDENT} qty")
print(f"  Skip rule 2    : monthly_indent / rate  ≤ {MIN_INDENT_HOURS}h (trivial run)")
print(f"  Zero-inv rule  : inventory=0 parts always forced into plan")
print(f"{'='*62}\n")

# =============================================================
# SECTION 5 — LOAD DATA  (VT only)
# =============================================================

print("Loading data...")
stats        = pd.read_excel(book_path,       sheet_name="Sheet2")
vt_parts_raw = pd.read_excel(book_path,       sheet_name="VT")
vt_matrix    = pd.read_excel(matrix_path,     sheet_name="VT_Matrix")
vt_co_raw    = pd.read_excel(changeover_path, sheet_name="VT_Changeover")

# =============================================================
# SECTION 6 — MERGE & PRODUCTION RATE
# -------------------------------------------------------------
# Merge VT parts sheet with stats (cycle time, cavity, inventory).
# Rate (units/hour) = (3600 / cycle_time_seconds) × cavity_count
# =============================================================

def find_col(df, name, sheet):
    """Case-insensitive column finder. Raises clear error if missing."""
    match = next((c for c in df.columns if str(c).strip().lower() == name.lower()), None)
    if match is None:
        raise ValueError(
            f"Column '{name}' not found in sheet '{sheet}'. "
            f"Available columns: {list(df.columns)}"
        )
    return match

stats_part_col = find_col(stats, "Part", "Sheet2")
vt_part_col    = find_col(vt_parts_raw, "Part", "VT")

data = stats.merge(
    vt_parts_raw.rename(columns={vt_part_col: "Material"}),
    left_on=stats_part_col,
    right_on="Material",
    how="inner"
).drop_duplicates(subset="Material").copy()

data["Rate"] = (3600 / data["Cycle time "].replace(0, np.nan)) * data["cavity"]
data = data[data["Rate"].notna()].copy()

print(f"  VT parts after merge with stats: {len(data)}")

# =============================================================
# SECTION 7 — BUILD LOOKUP DICTIONARIES
# =============================================================

def safe_dict(df, key_col, val_col, default=0.0):
    return {
        k: (default if pd.isna(v) else float(v))
        for k, v in zip(df[key_col], df[val_col])
    }

inventory = safe_dict(data, "Material", "Inventory on 24th")
rate      = safe_dict(data, "Material", "Rate")

# =============================================================
# SECTION 7A — READ INDENT FROM VT SHEET
# -------------------------------------------------------------
# VT sheet must have:
#   • "Part"   column  (case-insensitive)
#   • "Indent" column  (case-insensitive)
#
# Derived dicts:
#   indent_monthly   : {part → monthly qty}
#   indent_daily     : {part → monthly / working_days}
#   today_target_qty : {part → max(0, daily_indent − inventory)}
#
# Skip flags (computed here, enforced in scheduler):
#   skip_low_indent  : monthly < MIN_MONTHLY_INDENT
#   skip_trivial_run : monthly / rate ≤ MIN_INDENT_HOURS
#   EXCEPTION        : both skips are ignored if inventory == 0
# =============================================================

def read_indent_from_sheet(df, sheet_name):
    result   = {}
    part_col = next((c for c in df.columns if str(c).strip().lower() == "part"),   None)
    ind_col  = next((c for c in df.columns if str(c).strip().lower() == "indent"), None)
    if part_col is None:
        print(f"  WARNING: 'Part' column not found in '{sheet_name}'. "
              f"Available: {list(df.columns)}")
        return result
    if ind_col is None:
        print(f"  WARNING: 'Indent' column not found in '{sheet_name}'. "
              f"Available: {list(df.columns)}")
        return result
    print(f"  Book1 '{sheet_name}' — Part col: '{part_col}'  Indent col: '{ind_col}'")
    for _, row in df.iterrows():
        part = row[part_col]
        val  = row[ind_col]
        if pd.isna(part) or str(part).strip() == "":
            continue
        result[str(part).strip()] = float(val) if pd.notna(val) else 0.0
    return result

print("\nReading indent data from VT sheet...")
indent_monthly = read_indent_from_sheet(vt_parts_raw, "VT")

indent_daily = {
    p: round(qty / WORKING_DAYS, 4)
    for p, qty in indent_monthly.items()
}

today_target_qty = {
    p: max(0.0, indent_daily.get(p, 0.0) - inventory.get(p, 0.0))
    for p in indent_monthly
}

# ── Skip flags ───────────────────────────────────────────────
# A part is skipped ONLY when BOTH conditions below are true:
#   condition met  AND  inventory > 0
# If inventory == 0, part is NEVER skipped — it must be made.

def should_skip(part):
    """
    Returns (skip: bool, reason: str).
    Zero-inventory parts are never skipped.
    """
    inv     = inventory.get(part, 0.0)
    monthly = indent_monthly.get(part, 0.0)
    r       = rate.get(part, 1.0)

    # Zero inventory → always force into plan
    if inv == 0.0 and monthly > 0:
        return False, ""

    if monthly < MIN_MONTHLY_INDENT:
        return True, (f"Monthly indent {monthly:.0f} < {MIN_MONTHLY_INDENT} "
                      f"(threshold)")

    indent_hrs = monthly / r if r > 0 else 0.0
    if indent_hrs <= MIN_INDENT_HOURS:
        return True, (f"Whole monthly indent takes only {indent_hrs:.2f}h "
                      f"≤ {MIN_INDENT_HOURS}h threshold")

    return False, ""

# Print skip summary
skipped_parts = {p: should_skip(p) for p in indent_monthly}
n_skip  = sum(1 for skip, _ in skipped_parts.values() if skip)
n_force = sum(1 for p in indent_monthly
              if inventory.get(p, 0) == 0 and indent_monthly.get(p, 0) > 0)
print(f"\n  Indent summary:")
print(f"    Total VT parts with indent data : {len(indent_monthly)}")
print(f"    Parts skipped (low/trivial)     : {n_skip}")
print(f"    Parts with zero inventory       : {n_force}  (forced into plan regardless)")

for p, (skip, reason) in skipped_parts.items():
    if skip:
        print(f"    SKIP  {p:30s}  {reason}")

# =============================================================
# SECTION 7B — CHANGEOVER TIMES  (VT only)
# =============================================================

def build_changeover_dict(co_df):
    co_dict = {}
    for _, row in co_df.iterrows():
        machine = str(row["Unique Machines"]).strip()
        minutes = row["Changeover time"]
        if pd.notna(minutes) and machine:
            co_dict[machine] = float(minutes) / 60.0
    return co_dict

vt_changeover = build_changeover_dict(vt_co_raw)
DEFAULT_CHANGEOVER_HRS = 40 / 60.0

print(f"\n  VT changeover times loaded: {len(vt_changeover)} machines")
for m, h in vt_changeover.items():
    print(f"    {m:25s} → {h*60:.0f} min ({h:.3f} h)")

# =============================================================
# SECTION 7C — PART CATEGORY  (Runner / Repeater / Stranger)
# =============================================================

def build_category_from_sheet(df, sheet_name):
    cat      = {}
    part_col = next((c for c in df.columns if str(c).strip().lower() == "part"),     None)
    cat_col  = next((c for c in df.columns if str(c).strip().lower() == "category"), None)
    if part_col is None:
        print(f"  WARNING: 'Part' column not found in '{sheet_name}'")
        return cat
    if cat_col is None:
        print(f"  WARNING: 'Category' column not found in '{sheet_name}'")
        return cat
    print(f"  Book1 '{sheet_name}' — Part col: '{part_col}'  Category col: '{cat_col}'")
    for _, row in df.iterrows():
        part = row[part_col]
        val  = str(row[cat_col]).strip() if pd.notna(row[cat_col]) else "Stranger"
        if pd.isna(part) or str(part).strip() == "":
            continue
        if val.lower() in ("runner", "repeater", "stranger"):
            val = val.capitalize()
        cat[str(part).strip()] = val
    return cat

part_category  = build_category_from_sheet(vt_parts_raw, "VT")
runner_count   = sum(1 for v in part_category.values() if v == "Runner")
repeater_count = sum(1 for v in part_category.values() if v == "Repeater")
stranger_count = sum(1 for v in part_category.values() if v == "Stranger")
print(f"  Part categories — Runner: {runner_count}  "
      f"Repeater: {repeater_count}  Stranger: {stranger_count}")

# =============================================================
# SECTION 8 — MACHINE STATE
# =============================================================

def load_machine_state():
    if os.path.exists(MACHINE_STATE_FILE):
        with open(MACHINE_STATE_FILE) as f:
            state = json.load(f)
        print(f"\n  Machine state loaded:")
        for m, p in state.items():
            print(f"    {m:25s} last ran → {p}")
        return state
    print("\n  Machine state: FIRST RUN — no previous state. "
          f"State will be saved to '{MACHINE_STATE_FILE}' after this run.")
    return {}

def save_machine_state(vt_state):
    combined = {m: p for m, p in vt_state.items() if p is not None}
    with open(MACHINE_STATE_FILE, "w") as f:
        json.dump(combined, f, indent=2)
    print(f"\n  Machine state saved → {MACHINE_STATE_FILE}")
    for m, p in combined.items():
        print(f"    {m:25s} last ran → {p}")

machine_state = load_machine_state()

# =============================================================
# SECTION 9 — COMPATIBILITY MATRIX  (VT only)
# =============================================================

def build_compatibility(matrix):
    machines = matrix.columns[1:].tolist()
    compat   = {}
    for _, row in matrix.iterrows():
        part = row["Part"]
        for m in machines:
            if row[m] == 1:
                compat.setdefault(part, []).append(m)
    return compat, machines

vt_compat, vt_machines = build_compatibility(vt_matrix)

# =============================================================
# SECTION 10 — INDENT HORIZON TABLE
# -------------------------------------------------------------
# Shows per-part planning numbers and skip/force status.
# =============================================================

def compute_indent_horizon(parts):
    rows = []
    for p in parts:
        inv     = inventory.get(p, 0.0)
        monthly = indent_monthly.get(p, 0.0)
        daily   = indent_daily.get(p, 0.0)
        target  = today_target_qty.get(p, 0.0)
        r       = rate.get(p, 1.0)
        skip, skip_reason = should_skip(p)
        indent_hrs = monthly / r if r > 0 else 0.0

        if inv == 0.0 and monthly > 0:
            status = "ZERO INV — FORCED"
        elif skip:
            status = "SKIPPED"
        elif target > 0:
            status = "PRODUCTION NEEDED"
        elif monthly == 0:
            status = "NO INDENT"
        else:
            status = "INV SUFFICIENT"

        rows.append({
            "Part":              p,
            "Monthly_Indent":    round(monthly, 0),
            "Indent_Hrs_Total":  round(indent_hrs, 2),
            "Working_Days":      WORKING_DAYS,
            "Daily_Indent":      round(daily, 2),
            "Inventory_Now":     round(inv, 0),
            "Today_Target_Qty":  round(target, 0),
            "Today_Target_Hrs":  round(target / r if r > 0 else 0, 2),
            "Rate_Per_Hr":       round(r, 2),
            "Indent_Status":     status,
            "Skip_Reason":       skip_reason,
        })
    return pd.DataFrame(rows)

# =============================================================
# SECTION 11 — SCENARIO CLASSIFIER
# =============================================================

def classify_scenario(parts):
    coverage = []
    for p in parts:
        inv   = inventory.get(p, 0)
        daily = indent_daily.get(p, 0)
        skip, _ = should_skip(p)
        if skip:
            continue
        if daily == 0:
            continue
        coverage.append(inv / daily)

    if not coverage:
        return 3, "SCENARIO 3 — All active parts have zero indent today"

    n        = len(coverage)
    critical = sum(1 for c in coverage if c < 1)
    low      = sum(1 for c in coverage if c < TARGET_DAYS_INV)

    if critical == n:
        return 0, "SCENARIO 0 — ALL parts critical (inv < 1 day indent)"
    elif critical > 0:
        return 1, f"SCENARIO 1 — {critical}/{n} parts critical (inv < 1 day indent)"
    elif low > 0:
        return 2, f"SCENARIO 2 — {low}/{n} parts below {TARGET_DAYS_INV}-day buffer"
    else:
        return 3, f"SCENARIO 3 — All parts healthy (≥{TARGET_DAYS_INV} days inv)"

# =============================================================
# SECTION 12 — PRIORITY ORDERING
# -------------------------------------------------------------
# Parts are ranked purely by daily_indent descending.
# Highest daily indent = largest requirement = planned first.
# This ensures big parts always get machine time before small ones.
#
# Tie-break: zero-inventory parts rank above parts with some stock
# at the same daily_indent level (inv=0 → sort key slightly higher).
#
# "Inventory sufficient" parts (inv >= daily_indent) are excluded
# from the active list before this function is called.
# =============================================================

def compute_priority(parts, horizon_df):
    horizon = horizon_df.set_index("Part")
    rows    = []
    for p in parts:
        inv      = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        days_cov = inv / daily if daily > 0 else 999
        target   = horizon.loc[p, "Today_Target_Qty"] if p in horizon.index else 0

        # Sort key: daily_indent descending.
        # Zero-inventory parts get a tiny tie-break boost (+0.0001)
        # so they edge out same-daily_indent parts that have some stock.
        sort_key = daily + (0.0001 if inv == 0 else 0.0)

        rows.append({
            "Part":           p,
            "Days_Coverage":  round(days_cov, 2),
            "Inv_Now":        round(inv, 0),
            "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
            "Daily_Indent":   round(daily, 2),
            "Today_Target":   round(target, 0),
            "Sort_Key":       sort_key,
            "Zero_Inv":       "YES" if inv == 0 else "No",
        })

    return (pd.DataFrame(rows)
              .sort_values("Sort_Key", ascending=False)
              .drop(columns=["Sort_Key"])
              .reset_index(drop=True))

# =============================================================
# SECTION 13 — MACHINE RANKER
# =============================================================

def rank_machines(part, machines, compatibility, machine_hours,
                  machine_last_part, changeover_dict, inv_days):
    category    = part_category.get(part, "Stranger")
    is_runner   = (category == "Runner")
    runner_lock = is_runner and inv_days <= 1.0

    ranked = []
    for m in machines:
        if m not in compatibility.get(part, []):
            continue
        used = machine_hours.get(m, 0)
        free = AVAILABLE_HOURS - used
        if free < MIN_RUN_HOURS:
            continue
        last   = machine_last_part.get(m)
        if runner_lock and last != part:
            continue
        co_hrs = 0.0 if last == part else changeover_dict.get(m, DEFAULT_CHANGEOVER_HRS)
        effective_free = free - co_hrs
        if effective_free < MIN_RUN_HOURS:
            continue
        cost = co_hrs / AVAILABLE_HOURS + (used / AVAILABLE_HOURS)
        ranked.append((m, cost, effective_free, co_hrs))

    ranked.sort(key=lambda x: x[1])
    return ranked, runner_lock

# =============================================================
# SECTION 14 — SINGLE TOOL-CHANGER GLOBAL STAGGER
# -------------------------------------------------------------
# There is ONE tool changer shared across ALL VT machines.
# No two changeovers can overlap anywhere in the VT section.
#
# Algorithm — runs in a single deterministic pass:
#
#   STEP 1 — COLLECT
#     Walk every machine's plan rows in sequence, computing each
#     CO's natural start time (= cumulative hrs before that row).
#     Build a flat list of all CO events across all 30 machines,
#     each carrying a reference to the plan row it belongs to.
#
#   STEP 2 — SORT & SERIALIZE (single pass, no iteration needed)
#     Sort all CO events by their natural start time.
#     Walk the sorted list and maintain tool_changer_free_at.
#     For each event:
#       • If natural_start >= tool_changer_free_at → no conflict,
#         accept as-is, update tool_changer_free_at.
#       • If natural_start < tool_changer_free_at → CONFLICT.
#         The CO must be DELAYED to tool_changer_free_at.
#         delay = tool_changer_free_at - natural_start
#         To push this CO later we extend the run of the part
#         BEFORE this CO on that machine by `delay` hours.
#         → extra_qty  = delay × rate   (free production gained)
#         → If machine has insufficient spare capacity for the
#           full delay, use only the available spare and flag
#           the remainder as unresolvable (rare edge case).
#
#   STEP 3 — PROPAGATE
#     After delaying a CO on machine M, all SUBSEQUENT COs on M
#     are also pushed by the same delay (their start times
#     shift forward too). The tool_changer_free_at advances
#     correctly because we process events in time order.
#
#   WHY EXTEND (not reduce)?
#     Delaying a CO means the part before it runs LONGER — we
#     gain production, never lose it. Reducing would lose qty.
#     The only constraint is the machine's 22h ceiling.
#
#   OUTPUT
#     - Plan rows updated in-place (Run_Hours, Production_Qty,
#       Total_Hrs_Used, Stagger_Adjusted).
#     - Printed log shows every CO event, its machine, natural
#       start, actual start, and delay applied.
#     - A summary table is printed at the end showing the final
#       serialized tool-changer queue.
# =============================================================

def stagger_changeovers(plan, machines, changeover_dict):
    print(f"\n  {'='*58}")
    print(f"  TOOL-CHANGER GLOBAL STAGGER  (single tool changer — all VT)")
    print(f"  {'='*58}")

    # ── STEP 1: collect all CO events across every machine ───
    def collect_co_events(plan, machines):
        """
        Build flat list of all CO events across all machines.
        Each event carries the plan row reference so we can
        modify Run_Hours / Production_Qty in-place.
        natural_start = cumulative hours on that machine before
                        the CO begins (ignoring any previous delays).
        """
        events = []
        for m in machines:
            m_rows = [r for r in plan if r["Machine"] == m]
            if len(m_rows) < 2:
                continue   # only one part on this machine → no CO
            cursor = 0.0
            for i, row in enumerate(m_rows):
                co_h  = float(row.get("Changeover_Hrs") or 0.0)
                run_h = float(row.get("Run_Hours")       or 0.0)
                if co_h > 0 and i > 0:
                    events.append({
                        "machine":       m,
                        "seq_on_machine": i,          # position in machine sequence
                        "part_before":   m_rows[i-1]["Part"],
                        "part_after":    row["Part"],
                        "co_duration":   co_h,
                        "natural_start": cursor,      # when CO would start without stagger
                        "actual_start":  cursor,      # will be updated in Step 2
                        "delay_applied": 0.0,         # hours of delay pushed onto prev run
                        "row_before":    m_rows[i-1], # plan row to extend if delayed
                        "row_after":     row,
                    })
                cursor += co_h + run_h
        # Sort by natural start time so the tool changer handles
        # earliest requests first — fair and deterministic.
        events.sort(key=lambda e: (e["natural_start"], e["machine"]))
        return events

    events = collect_co_events(plan, machines)

    if not events:
        print("  No changeovers found in plan — tool changer is idle all shift  ✓")
        return

    print(f"  Total CO events across all VT machines: {len(events)}")
    print(f"\n  {'Machine':<18} {'Part Before':<22} {'Part After':<22} "
          f"{'CO Dur':>7} {'Natural':>8} {'Actual':>8} {'Delay':>7} {'Spare Used':>10}")
    print(f"  {'─'*18} {'─'*22} {'─'*22} {'─'*7} {'─'*8} {'─'*8} {'─'*7} {'─'*10}")

    # ── STEP 2: serialize — one pass, no iteration ───────────
    tool_changer_free_at = 0.0   # when the tool changer finishes its current job
    # Track cumulative delay per machine so subsequent COs on
    # the same machine are pushed forward correctly.
    machine_delay = {m: 0.0 for m in machines}

    for ev in events:
        m             = ev["machine"]
        co_h          = ev["co_duration"]
        row_before    = ev["row_before"]
        row_after     = ev["row_after"]

        # Natural start already accounts for previous delays on
        # this machine because we stored the row references and
        # updated Run_Hours in-place during previous iterations.
        # Recompute actual natural start from the (possibly already
        # extended) row_before run hours.
        # natural_start = sum of all (co_h + run_h) before this CO on m
        m_rows  = [r for r in plan if r["Machine"] == m]
        cursor  = 0.0
        for r in m_rows:
            if r is row_after:
                break
            cursor += float(r.get("Changeover_Hrs") or 0) + float(r.get("Run_Hours") or 0)
        natural_start = cursor   # time at which this CO would start right now

        if natural_start >= tool_changer_free_at:
            # ── No conflict — tool changer is free ───────────
            actual_start  = natural_start
            delay_applied = 0.0
        else:
            # ── Conflict — must delay this CO ────────────────
            # Extend the run of the part BEFORE this CO so the
            # CO shifts to tool_changer_free_at.
            delay_applied = tool_changer_free_at - natural_start

            # How much spare capacity does this machine have?
            total_used_now = sum(
                float(r.get("Changeover_Hrs") or 0) + float(r.get("Run_Hours") or 0)
                for r in m_rows
            )
            spare = AVAILABLE_HOURS - total_used_now

            if spare >= delay_applied - 0.001:
                # Full delay fits within 22h — extend row_before
                r_val     = rate.get(row_before["Part"], 1.0)
                extra_qty = round(delay_applied * r_val, 0)

                row_before["Run_Hours"]      = round(
                    float(row_before.get("Run_Hours") or 0) + delay_applied, 3)
                row_before["Production_Qty"] = round(
                    float(row_before.get("Production_Qty") or 0) + extra_qty, 0)
                row_before["Total_Hrs_Used"] = round(
                    float(row_before.get("Changeover_Hrs") or 0)
                    + float(row_before["Run_Hours"]), 3)
                row_before["Stagger_Adjusted"] = (
                    f"Extended +{round(delay_applied*60,1)}min "
                    f"(TC queue: tool changer busy until "
                    f"{round(tool_changer_free_at,3):.3f}h)")

                actual_start = tool_changer_free_at

            else:
                # ── Partial fit — machine at ceiling ─────────
                # Extend only as much as spare allows; flag remainder.
                usable_delay = max(spare, 0.0)
                shortfall    = delay_applied - usable_delay

                if usable_delay > 0:
                    r_val     = rate.get(row_before["Part"], 1.0)
                    extra_qty = round(usable_delay * r_val, 0)
                    row_before["Run_Hours"]      = round(
                        float(row_before.get("Run_Hours") or 0) + usable_delay, 3)
                    row_before["Production_Qty"] = round(
                        float(row_before.get("Production_Qty") or 0) + extra_qty, 0)
                    row_before["Total_Hrs_Used"] = round(
                        float(row_before.get("Changeover_Hrs") or 0)
                        + float(row_before["Run_Hours"]), 3)

                actual_start = natural_start + usable_delay
                row_before["Stagger_Adjusted"] = (
                    f"Extended +{round(usable_delay*60,1)}min  "
                    f"⚠ {round(shortfall*60,1)}min unresolvable "
                    f"(machine at 22h ceiling)")
                delay_applied = usable_delay   # actual delay achieved

        ev["actual_start"]  = actual_start
        ev["delay_applied"] = delay_applied

        # Advance tool changer free time
        tool_changer_free_at = actual_start + co_h

        # ── Print this event ──────────────────────────────────
        delay_str = (f"+{round(delay_applied*60,1)}min"
                     if delay_applied > 0.001 else "none")
        spare_str = (f"+{round(delay_applied * rate.get(ev['part_before'],1),0):.0f} pcs"
                     if delay_applied > 0.001 else "—")
        print(f"  {m:<18} {ev['part_before']:<22} {ev['part_after']:<22} "
              f"{round(co_h*60,1):>6.1f}m "
              f"{_fmt_h(natural_start):>8} "
              f"{_fmt_h(actual_start):>8} "
              f"{delay_str:>7} "
              f"{spare_str:>10}")

    # ── STEP 3: summary ───────────────────────────────────────
    total_delays   = sum(1 for e in events if e["delay_applied"] > 0.001)
    total_delay_h  = sum(e["delay_applied"] for e in events)
    unresolvable   = sum(1 for e in events
                         if "unresolvable" in str(e["row_before"].get("Stagger_Adjusted", "")))

    print(f"\n  {'─'*58}")
    print(f"  Tool-changer queue complete:")
    print(f"    Total CO events    : {len(events)}")
    print(f"    Events delayed     : {total_delays}")
    print(f"    Total delay time   : {round(total_delay_h*60,1)} min")
    print(f"    Unresolvable (22h) : {unresolvable}"
          + ("  ← review manually" if unresolvable else "  ✓"))
    print(f"    Tool changer free  : {_fmt_h(tool_changer_free_at)}  "
          f"(last CO ends at {_fmt_h(tool_changer_free_at)})")

    # Final serialized CO queue
    print(f"\n  Serialized tool-changer queue (final):")
    print(f"  {'#':<4} {'Machine':<18} {'Start':>8} {'End':>8} {'Part After':<22}")
    print(f"  {'─'*4} {'─'*18} {'─'*8} {'─'*8} {'─'*22}")
    for idx, ev in enumerate(events, 1):
        print(f"  {idx:<4} {ev['machine']:<18} "
              f"{_fmt_h(ev['actual_start']):>8} "
              f"{_fmt_h(ev['actual_start'] + ev['co_duration']):>8} "
              f"{ev['part_after']:<22}")
    print(f"  {'='*58}")


def _fmt_h(h):
    """Convert decimal hours to HH:MM string."""
    try:
        total_min = int(round(float(h) * 60))
        return f"{total_min // 60:02d}:{total_min % 60:02d}"
    except Exception:
        return "??"

# =============================================================
# SECTION 14B — 22-HOUR FILLER
# =============================================================

def fill_remaining_hours(plan, machine_hours, machine_last_part,
                         parts, compatibility, machines,
                         current_inventory, horizon_df):
    already_planned = {row["Part"] for row in plan}

    for m in machines:
        remaining = round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
        if remaining <= 0:
            continue

        on_machine = [row["Part"] for row in plan if row["Machine"] == m]

        # Option A — extend existing part: pick the one with highest daily_indent
        # (most critical part on this machine gets the extra time)
        best_part, best_daily = None, -1
        for p in on_machine:
            d = indent_daily.get(p, 0)
            if d > best_daily:
                best_daily, best_part = d, p

        if best_part and best_daily > 0:
            p         = best_part
            r_val     = rate.get(p, 1)
            extra_qty = round(remaining * r_val, 0)
            for row in plan:
                if row["Part"] == p and row["Machine"] == m:
                    row["Run_Hours"]      = round(row["Run_Hours"] + remaining, 2)
                    row["Production_Qty"] = round(row["Production_Qty"] + extra_qty, 0)
                    row["Total_Hrs_Used"] = round(
                        row.get("Total_Hrs_Used", row["Run_Hours"]) + remaining, 2)
                    row["Type"] = "Primary+Extended"
                    break
            machine_hours[m]    += remaining
            current_inventory[p] = current_inventory.get(p, 0) + extra_qty
            print(f"    ↑ {p:30s} → {m:15s}  +{remaining:.2f}h merged  "
                  f"qty+={extra_qty:.0f}  [EXTEND]")
            continue

        # Option B — add a new part (≥ MIN_RUN_HOURS required)
        if remaining < MIN_RUN_HOURS:
            continue

        candidates = []
        for p in parts:
            if p in already_planned:
                continue
            if m not in compatibility.get(p, []):
                continue
            daily   = indent_daily.get(p, 0)
            inv_now  = current_inventory.get(p, 0)
            # Skip if inventory already sufficient
            if inv_now >= daily > 0:
                continue
            candidates.append((p, daily))

        # Sort by daily_indent descending — biggest parts fill first
        candidates.sort(key=lambda x: -x[1])

        for p, daily_val in candidates:
            last    = machine_last_part.get(m)
            co_hrs  = 0.0 if last == p else vt_changeover.get(m, DEFAULT_CHANGEOVER_HRS)
            eff_run = remaining - co_hrs
            if eff_run < MIN_RUN_HOURS:
                continue
            r_val = rate.get(p, 1)
            qty   = round(eff_run * r_val, 0)
            machine_hours[m]    += (co_hrs + eff_run)
            current_inventory[p] = current_inventory.get(p, 0) + qty
            machine_last_part[m] = p
            already_planned.add(p)
            plan.append({
                "Part":             p,
                "Category":         part_category.get(p, "Stranger"),
                "Machine":          m,
                "Run_Hours":        round(eff_run, 2),
                "Changeover_Hrs":   round(co_hrs, 3),
                "Total_Hrs_Used":   round(co_hrs + eff_run, 2),
                "Rate_Per_Hour":    round(r_val, 2),
                "Production_Qty":   qty,
                "Monthly_Indent":   round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":     round(indent_daily.get(p, 0), 2),
                "Today_Target":     round(today_target_qty.get(p, 0), 0),
                "Changeover":       "No" if co_hrs == 0 else "Yes",
                "Type":             "New — filler",
                "Runner_Lock":      "No",
                "Priority_Score":   0,
                "Stagger_Adjusted": "No",
            })
            print(f"    + {p:30s} → {m:15s}  {eff_run:.2f}h  qty={qty:.0f}  "
                  f"[Filler]  CO={'Yes' if co_hrs > 0 else 'No'}")
            break

# =============================================================
# SECTION 15 — MAIN SCHEDULER
# =============================================================

def schedule(parts, compatibility, machines, changeover_dict, label=""):

    print(f"\n{'─'*62}")
    print(f"  {label}  |  {len(parts)} parts  |  {len(machines)} machines")
    print(f"{'─'*62}")

    scenario, scenario_desc = classify_scenario(parts)
    print(f"  {scenario_desc}")

    horizon_df = compute_indent_horizon(parts)

    # Print what needs production
    prod_needed = horizon_df[
        horizon_df["Indent_Status"].isin(["PRODUCTION NEEDED", "ZERO INV — FORCED"])
    ]
    if not prod_needed.empty:
        print(f"\n  Parts requiring production today ({len(prod_needed)}):")
        print(f"  {'Part':<30}  {'Monthly':>8}  {'Daily':>7}  {'Inv':>8}  "
              f"{'Target':>8}  {'Status'}")
        print(f"  {'─'*30}  {'─'*8}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*20}")
        for _, r in prod_needed.iterrows():
            print(f"  {r['Part']:<30}  "
                  f"{r['Monthly_Indent']:>8.0f}  "
                  f"{r['Daily_Indent']:>7.2f}  "
                  f"{r['Inventory_Now']:>8.0f}  "
                  f"{r['Today_Target_Qty']:>8.0f}  "
                  f"{r['Indent_Status']}")
    else:
        print("  No production needed — inventory covers all active parts today")

    machine_hours     = {m: 0.0 for m in machines}
    machine_last_part = {m: machine_state.get(m) for m in machines}
    current_inventory = inventory.copy()

    plan, deferred, not_planned, skipped_log = [], [], [], []

    # Active parts = not skipped OR zero-inventory (always forced)
    # Inventory-sufficient parts are excluded here — not in priority list at all.
    active_parts = [
        p for p in parts
        if (not should_skip(p)[0] or inventory.get(p, 0) == 0)
        and indent_monthly.get(p, 0) > 0
        and not (inventory.get(p, 0) >= indent_daily.get(p, 0) > 0)
    ]

    priority_df = compute_priority(active_parts, horizon_df)

    print(f"\n  Priority order — sorted by daily_indent descending "
          f"({len(priority_df)} active parts):")
    print(f"  {'Part':<30}  {'Daily':>7}  {'Inv':>8}  {'Target':>8}  {'Zero_Inv':>8}")
    print(f"  {'─'*30}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*8}")
    for _, r in priority_df.iterrows():
        print(f"  {r['Part']:<30}  "
              f"{r['Daily_Indent']:>7.2f}  "
              f"{r['Inv_Now']:>8.0f}  "
              f"{r['Today_Target']:>8.0f}  "
              f"{r['Zero_Inv']:>8}")

    runner_dedicated_machines = set()

    # ── Log skipped parts (not zero-inv) ─────────────────────
    for p in parts:
        skip, reason = should_skip(p)
        inv_now = inventory.get(p, 0)
        if skip and inv_now > 0:
            skipped_log.append({
                "Part":           p,
                "Category":       part_category.get(p, "Stranger"),
                "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":   round(indent_daily.get(p, 0), 2),
                "Inventory_Now":  round(inv_now, 0),
                "Skip_Reason":    reason,
            })

    def run_assignment(parts_subset, pass_label, exclude_machines=None):
        if exclude_machines is None:
            exclude_machines = set()
        print(f"\n  {pass_label}:")

        for _, row in priority_df[priority_df["Part"].isin(parts_subset)].iterrows():
            part     = row["Part"]

            if any(r["Part"] == part for r in plan):
                print(f"    ~ {part:30s}  ALREADY PLANNED — skipped")
                continue

            inv_now  = current_inventory.get(part, 0)
            daily    = indent_daily.get(part, 0)
            monthly  = indent_monthly.get(part, 0)
            r_val    = rate.get(part, 1)
            category = part_category.get(part, "Stranger")
            inv_days = inv_now / daily if daily > 0 else 999
            target   = today_target_qty.get(part, 0)

            compatible_mch = compatibility.get(part, [])

            # ── Zero indent ───────────────────────────────────
            if monthly == 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": 0,
                    "Daily_Indent":   0,
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Monthly indent is zero",
                    "Next_Action":    "Re-evaluate when indent is set",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED — indent = 0")
                continue

            # ── Inventory sufficient (and not zero-inv forced) ─
            if target == 0 and inv_now > 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": round(monthly, 0),
                    "Daily_Indent":   round(daily, 2),
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Inventory covers daily indent — no production needed",
                    "Next_Action":    "Re-evaluate tomorrow",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED  "
                      f"inv={inv_now:.0f} ≥ daily={daily:.2f}")
                continue

            # ── Target hours ──────────────────────────────────
            # For zero-inventory forced parts: use daily_indent as minimum
            # run target so we at least build one day's worth.
            effective_target = max(target, daily) if inv_now == 0 else target

            if category == "Runner":
                target_hrs = min(
                    (effective_target / r_val if r_val > 0 else MIN_RUN_HOURS)
                    + (daily / r_val if r_val > 0 else 0),
                    AVAILABLE_HOURS
                )
                target_hrs = max(target_hrs, MIN_RUN_HOURS)
            else:
                target_hrs = max(
                    MIN_RUN_HOURS,
                    effective_target / r_val if r_val > 0 else MIN_RUN_HOURS
                )

            # ── No compatible machines ────────────────────────
            if not compatible_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": "NONE DEFINED",
                    "Reason":              "Part has no compatible machines in VT matrix",
                    "Action_Needed":       "Add part to VT_Matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — not in matrix")
                continue

            available_mch = [m for m in compatible_mch if m not in exclude_machines]
            if not available_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              "All compatible machines dedicated to Runners",
                    "Action_Needed":       "Add more compatible machines in matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — machines Runner-dedicated")
                continue

            ranked, runner_lock = rank_machines(
                part, available_mch, compatibility,
                machine_hours, machine_last_part,
                changeover_dict, inv_days
            )

            if not ranked:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                if runner_lock:
                    last_m = next(
                        (m for m in available_mch if machine_last_part.get(m) == part), None)
                    free_l = round(AVAILABLE_HOURS - machine_hours.get(last_m, 0), 2) if last_m else 0
                    reason = (f"RUNNER (inv≤1d) — must stay on {last_m}, "
                              f"only {free_l}h free") if last_m else \
                             "RUNNER — no machine state (first run)"
                    action = f"Free capacity on {last_m}" if last_m else \
                             "Machine state saves after this run"
                elif all(h < MIN_RUN_HOURS for h in free_map.values()):
                    reason = ("All compatible machines full. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Reduce lower-priority part hours or plan tomorrow"
                else:
                    reason = ("Remaining hrs < MIN after changeover. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Check Inventory_Health sheet"

                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              reason,
                    "Action_Needed":       action,
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — {reason[:60]}")
                continue

            # ── Assign ────────────────────────────────────────
            assigned = False
            for m, cost, effective_free, co_hrs in ranked:
                run_h = min(target_hrs, effective_free)
                run_h = max(run_h, MIN_RUN_HOURS)
                run_h = min(run_h, effective_free)
                qty   = round(run_h * r_val, 0)

                machine_hours[m]        += (co_hrs + run_h)
                current_inventory[part]  = current_inventory.get(part, 0) + qty
                machine_last_part[m]     = part

                if category == "Runner":
                    runner_dedicated_machines.add(m)

                forced_tag = "ZERO-INV-FORCED" if inv_now == 0 else "Primary"
                plan.append({
                    "Part":              part,
                    "Category":          category,
                    "Machine":           m,
                    "Run_Hours":         round(run_h, 2),
                    "Changeover_Hrs":    round(co_hrs, 3),
                    "Total_Hrs_Used":    round(co_hrs + run_h, 2),
                    "Rate_Per_Hour":     round(r_val, 2),
                    "Production_Qty":    qty,
                    "Monthly_Indent":    round(monthly, 0),
                    "Daily_Indent":      round(daily, 2),
                    "Today_Target":      round(target, 0),
                    "Changeover":        "No" if co_hrs == 0 else "Yes",
                    "Type":              forced_tag,
                    "Runner_Lock":       "YES" if runner_lock else "No",
                    "Priority_Score":    round(indent_daily.get(part, 0), 2),
                    "Stagger_Adjusted":  "No",
                })
                co_str = "No" if co_hrs == 0 else f"Yes ({co_hrs*60:.0f}min)"
                tag    = "  [DEDICATED]" if category == "Runner" else \
                         "  [ZERO-INV FORCED]" if inv_now == 0 else ""
                print(f"    ✓ {part:30s} [{category:8s}] → {m:15s}  "
                      f"{run_h:.2f}h  qty={qty:>8.0f}  CO={co_str}{tag}")
                assigned = True
                break

            if not assigned:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              (
                        f"No single machine has {round(target_hrs,2)}h free after CO. "
                        + "Free: " + ", ".join(f"{m}={h}h" for m, h in free_map.items())
                    ),
                    "Action_Needed": "Reduce lower-priority hours or verify inventory covers gap",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — "
                      f"no machine has {round(target_hrs,2)}h free")

    # PASS 1 — Runners
    runner_parts     = [p for p in parts
                        if part_category.get(p, "Stranger") == "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]
    non_runner_parts = [p for p in parts
                        if part_category.get(p, "Stranger") != "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]

    run_assignment(runner_parts,
                   "PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer)")
    print(f"\n  Runner-dedicated machines: "
          f"{sorted(runner_dedicated_machines) if runner_dedicated_machines else 'none'}")

    # PASS 2 — Repeaters + Strangers
    run_assignment(non_runner_parts,
                   "PASS 2 — Repeaters + Strangers (Runner machines excluded)",
                   exclude_machines=runner_dedicated_machines)

    # 22-hour filler
    print(f"\n  22-hour filler:")
    fill_remaining_hours(
        plan, machine_hours, machine_last_part,
        list(parts), compatibility, machines,
        current_inventory, horizon_df
    )

    # Duplicate check
    part_counts = {}
    for row in plan:
        part_counts[row["Part"]] = part_counts.get(row["Part"], 0) + 1
    dupes = {p: c for p, c in part_counts.items() if c > 1}
    if dupes:
        print(f"  WARNING: duplicate parts: {dupes}")
    else:
        print(f"    No duplicate parts — each part appears exactly once  ✓")

    # Stagger
    stagger_changeovers(plan, machines, changeover_dict)

    # ── Inventory health ──────────────────────────────────────
    inv_rows = []
    for p in parts:
        inv_b    = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        monthly  = indent_monthly.get(p, 0)
        produced = sum(r["Production_Qty"] for r in plan if r["Part"] == p)
        inv_after = inv_b + produced
        days_cov  = inv_after / daily if daily > 0 else 0
        inv_rows.append({
            "Part":            p,
            "Monthly_Indent":  round(monthly, 0),
            "Daily_Indent":    round(daily, 2),
            "Inv_Before":      round(inv_b, 0),
            "Produced_Today":  round(produced, 0),
            "Inv_After_Today": round(inv_after, 0),
            "Days_Coverage":   round(days_cov, 2),
            "Status":          ("OK"       if days_cov >= TARGET_DAYS_INV
                                else "LOW"      if days_cov >= 1
                                else "CRITICAL"),
        })

    # ── Machine utilization ───────────────────────────────────
    mach_rows = []
    for m in machines:
        used      = machine_hours.get(m, 0)
        parts_run = [r["Part"] for r in plan if r["Machine"] == m]
        co_count  = sum(1 for r in plan if r["Machine"] == m and r.get("Changeover") == "Yes")
        util_pct  = round(used / AVAILABLE_HOURS * 100, 1)
        util_status = ("FULL"     if used >= AVAILABLE_HOURS - 0.5 else
                       "GOOD"     if used >= AVAILABLE_HOURS * 0.85 else
                       "PARTIAL"  if used >= AVAILABLE_HOURS * 0.5 else
                       "UNDERUSED")
        mach_rows.append({
            "Machine":              m,
            "Total_Available_Hrs":  AVAILABLE_HOURS,
            "Used_Hours":           round(used, 2),
            "Unused_Hours":         round(AVAILABLE_HOURS - used, 2),
            "Utilization_%":        util_pct,
            "Status":               util_status,
            "Parts_Planned":        len(parts_run),
            "Changeovers":          co_count,
            "Last_Part_Run":        machine_last_part.get(m) or "—",
            "All_Parts_On_Machine": ", ".join(parts_run) if parts_run else "— idle —",
        })

    plan_df     = pd.DataFrame(plan)         if plan         else pd.DataFrame()
    def_df      = pd.DataFrame(deferred)     if deferred     else pd.DataFrame()
    not_df      = pd.DataFrame(not_planned)  if not_planned  else pd.DataFrame()
    skip_df     = pd.DataFrame(skipped_log)  if skipped_log  else pd.DataFrame()
    mach_df     = pd.DataFrame(mach_rows)
    inv_df      = pd.DataFrame(inv_rows)

    if not plan_df.empty:
        plan_df["Category"] = plan_df["Part"].map(
            lambda p: part_category.get(p, "Stranger"))
        plan_df.insert(0, "Planning_Date", str(PLANNING_DATE))
        plan_df.insert(1, "Scenario",      scenario_desc)
        plan_df.insert(2, "Working_Days",  WORKING_DAYS)

    return plan_df, def_df, not_df, skip_df, mach_df, inv_df, machine_last_part, horizon_df

# =============================================================
# SECTION 16 — RUN VT SCHEDULER
# =============================================================

vt_parts = data[data["Material"].isin(vt_matrix["Part"])]["Material"].unique()

(vt_plan, vt_def, vt_not, vt_skip,
 vt_mach, vt_inv, vt_state, vt_horizon) = schedule(
    vt_parts, vt_compat, vt_machines, vt_changeover, "VT Machines"
)

save_machine_state(vt_state)

# =============================================================
# SECTION 17 — SAVE OUTPUT
# =============================================================

from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment
from openpyxl.utils import get_column_letter

HEADER_COLORS = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
}

STATUS_FILLS = {
    "FULL":               PatternFill("solid", fgColor="C6EFCE"),
    "GOOD":               PatternFill("solid", fgColor="DDEBF7"),
    "PARTIAL":            PatternFill("solid", fgColor="FFEB9C"),
    "UNDERUSED":          PatternFill("solid", fgColor="FFC7CE"),
    "OK":                 PatternFill("solid", fgColor="C6EFCE"),
    "LOW":                PatternFill("solid", fgColor="FFEB9C"),
    "CRITICAL":           PatternFill("solid", fgColor="FFC7CE"),
    "PRODUCTION NEEDED":  PatternFill("solid", fgColor="FFC7CE"),
    "ZERO INV — FORCED":  PatternFill("solid", fgColor="FFD7D7"),
    "INV SUFFICIENT":     PatternFill("solid", fgColor="C6EFCE"),
    "SKIPPED":            PatternFill("solid", fgColor="EDEDED"),
    "NO INDENT":          PatternFill("solid", fgColor="EDEDED"),
}

def style_sheet(ws, header_hex):
    hf = PatternFill("solid", fgColor=header_hex)
    for cell in ws[1]:
        cell.fill      = PatternFill("solid", fgColor=header_hex)
        cell.font      = Font(bold=True, color="FFFFFF", size=11)
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 32
    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value is not None), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(50, max_len + 3))
    headers = [cell.value for cell in ws[1]]
    for col_idx, col_name in enumerate(headers, start=1):
        if col_name and ("Status" in str(col_name) or "Indent_Status" in str(col_name)):
            for row in ws.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
                for cell in row:
                    fill = STATUS_FILLS.get(str(cell.value))
                    if fill:
                        cell.fill = fill
    ws.freeze_panes = "A2"


def build_machine_wise_plan(plan_df, machines):
    """
    Build the machine-wise sequenced plan with Rate_Per_Hour column included.
    One row per part per machine, plus a summary footer row per machine.
    """
    if plan_df.empty:
        return pd.DataFrame()

    def safe_float(val, default=0.0):
        try:
            v = float(val)
            return v if not np.isnan(v) else default
        except (TypeError, ValueError):
            return default

    # Use the global _fmt_h helper (defined alongside stagger_changeovers)
    fmt_time = _fmt_h

    rows = []
    for m in machines:
        machine_rows = plan_df[plan_df["Machine"] == m].copy()
        if machine_rows.empty:
            continue

        cumulative_hrs = 0.0
        seq            = 1

        for _, pr in machine_rows.iterrows():
            part    = pr.get("Part", "—")
            run_h   = safe_float(pr.get("Run_Hours", 0))
            co_h    = safe_float(pr.get("Changeover_Hrs", 0))
            r_val   = safe_float(pr.get("Rate_Per_Hour", 0))
            co_mins = round(co_h * 60, 1)
            start_h = cumulative_hrs + co_h
            end_h   = start_h + run_h

            rows.append({
                "Machine":                m,
                "Seq":                    seq,
                "Part":                   part,
                "Category":               part_category.get(part, "Stranger"),
                "Rate_Per_Hour":          round(r_val, 2),          # ← added
                "Changeover_Before_Mins": co_mins,
                "Run_Hours":              round(run_h, 2),
                "Start_Time":             fmt_time(cumulative_hrs),
                "Start_After_CO":         fmt_time(start_h),
                "End_Time":               fmt_time(end_h),
                "Cumulative_Hrs":         round(end_h, 2),
                "Production_Qty":         safe_float(pr.get("Production_Qty", 0)),
                "Monthly_Indent":         safe_float(pr.get("Monthly_Indent", 0)),
                "Daily_Indent":           safe_float(pr.get("Daily_Indent", 0)),
                "Today_Target":           safe_float(pr.get("Today_Target", 0)),
                "Changeover":             pr.get("Changeover", "No") or "No",
                "Type":                   pr.get("Type", "Primary") or "Primary",
                "Runner_Lock":            pr.get("Runner_Lock", "No") or "No",
                "Row_Type":               "Part",
            })
            cumulative_hrs = end_h
            seq           += 1

        # Summary footer
        total_used     = round(cumulative_hrs, 2)
        co_hrs_series  = machine_rows["Changeover_Hrs"].apply(lambda x: safe_float(x, 0))
        total_co_mins  = round(co_hrs_series.sum() * 60, 1)
        total_prod_hrs = round(total_used - co_hrs_series.sum(), 2)
        total_qty      = machine_rows["Production_Qty"].apply(lambda x: safe_float(x, 0)).sum()
        co_count       = int(machine_rows["Changeover"].eq("Yes").sum())

        rows.append({
            "Machine":                m,
            "Seq":                    "—",
            "Part":                   f"TOTAL — {m}",
            "Category":               "—",
            "Rate_Per_Hour":          "—",
            "Changeover_Before_Mins": total_co_mins,
            "Run_Hours":              total_prod_hrs,
            "Start_Time":             "00:00",
            "Start_After_CO":         "—",
            "End_Time":               fmt_time(total_used),
            "Cumulative_Hrs":         total_used,
            "Production_Qty":         round(total_qty, 0),
            "Monthly_Indent":         "—",
            "Daily_Indent":           "—",
            "Today_Target":           "—",
            "Changeover":             f"{co_count} changeovers",
            "Type":                   f"Used {total_used}h / {AVAILABLE_HOURS}h  |  Unused {round(AVAILABLE_HOURS-total_used,2)}h",
            "Runner_Lock":            "—",
            "Row_Type":               "Summary",
        })
        rows.append({k: "" for k in rows[-1].keys()})

    return pd.DataFrame(rows)


def style_machine_wise_sheet(ws):
    header_fill  = PatternFill("solid", fgColor="1F4E79")
    header_font  = Font(bold=True, color="FFFFFF", size=11)
    summary_fill = PatternFill("solid", fgColor="0D9488")
    summary_font = Font(bold=True, color="FFFFFF", size=11)
    part_fills   = [
        PatternFill("solid", fgColor="EFF6FF"),
        PatternFill("solid", fgColor="F0FDF4"),
    ]
    co_fill = PatternFill("solid", fgColor="FEF9C3")

    for cell in ws[1]:
        cell.fill      = header_fill
        cell.font      = header_font
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 30

    headers      = [cell.value for cell in ws[1]]
    row_type_col = headers.index("Row_Type")  + 1 if "Row_Type"  in headers else None
    co_col       = headers.index("Changeover") + 1 if "Changeover" in headers else None
    machine_col  = headers.index("Machine")   + 1 if "Machine"   in headers else None

    machine_color_idx = 0
    current_machine   = None

    for row in ws.iter_rows(min_row=2):
        row_type = row[row_type_col - 1].value if row_type_col else ""
        machine  = row[machine_col  - 1].value if machine_col  else ""
        if machine and machine != current_machine:
            current_machine   = machine
            machine_color_idx = (machine_color_idx + 1) % 2
        if row_type == "Summary":
            for cell in row:
                cell.fill = summary_fill
                cell.font = summary_font
                cell.alignment = Alignment(horizontal="center", vertical="center")
        elif row_type == "Part":
            bg = part_fills[machine_color_idx]
            for cell in row:
                cell.fill      = bg
                cell.alignment = Alignment(vertical="center")
            if co_col and row[co_col - 1].value == "Yes":
                row[co_col - 1].fill = co_fill

    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(40, max_len + 3))
    ws.freeze_panes = "C2"


# =============================================================
# SECTION 17A — WRITE EXCEL
# =============================================================

print(f"\nWriting → {output_path}")

vt_mw = build_machine_wise_plan(vt_plan, vt_machines)

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    vt_mw.to_excel(writer,      sheet_name="VT_Plan_By_Machine",    index=False)
    vt_plan.to_excel(writer,    sheet_name="VT_Plan",               index=False)
    vt_mach.to_excel(writer,    sheet_name="VT_Machine_Util",       index=False)
    vt_not.to_excel(writer,     sheet_name="VT_Not_Planned",        index=False)
    vt_def.to_excel(writer,     sheet_name="VT_Not_Required_Today", index=False)
    vt_skip.to_excel(writer,    sheet_name="VT_Skipped_Parts",      index=False)
    vt_inv.to_excel(writer,     sheet_name="VT_Inventory_Health",   index=False)
    vt_horizon.to_excel(writer, sheet_name="VT_Indent_Horizon",     index=False)

wb = load_workbook(output_path)

if "VT_Plan_By_Machine" in wb.sheetnames:
    style_machine_wise_sheet(wb["VT_Plan_By_Machine"])

for sheet_name, header_hex in HEADER_COLORS.items():
    if sheet_name in wb.sheetnames and sheet_name != "VT_Plan_By_Machine":
        style_sheet(wb[sheet_name], header_hex)

tab_colors = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
}
for name, color in tab_colors.items():
    if name in wb.sheetnames:
        wb[name].sheet_properties.tabColor = color

wb.save(output_path)
print(f"  Formatting applied  ✓")

# =============================================================
# SECTION 18 — SUMMARY PRINT
# =============================================================

print(f"\n{'='*62}")
print(f"  Smart APS V6 Complete  —  VT Only  —  {PLANNING_DATE}")
print(f"  Indent month  : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Working days  : {WORKING_DAYS}  ({TOTAL_DAYS} days − {SUNDAY_COUNT} Sundays)")
print(f"{'='*62}")
print(f"  planned            = {len(vt_plan):>4}")
print(f"  not_required_today = {len(vt_def):>4}  (inv covers daily indent)")
print(f"  skipped            = {len(vt_skip):>4}  (indent < {MIN_MONTHLY_INDENT} qty  OR  whole indent ≤ {MIN_INDENT_HOURS}h)")
print(f"  not_planned        = {len(vt_not):>4}  (needed but no machine capacity)")
print(f"\n  Output  → {output_path}")
print(f"  State   → {MACHINE_STATE_FILE}")
print(f"\n  NOTE: Update SECTION 1 each morning:")
print(f"        PLANNING_DATE = date(2026, 3, 15)")
print(f"        INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over")
# Out:
# ==============================================================
#   Smart APS V6  —  VT-Only Indent-Based Planning
#   Planning date  : 2026-03-18
#   Indent month   : March 2026
#   Total days     : 31
#   Sundays        : 5
#   Working days   : 26  (used as divisor)
#   Daily target   : monthly_indent / 26
#   Today target   : max(0, daily_indent - inventory)
#   Skip rule 1    : monthly_indent < 150 qty
#   Skip rule 2    : monthly_indent / rate  ≤ 4.0h (trivial run)
#   Zero-inv rule  : inventory=0 parts always forced into plan
# ==============================================================
#
# Loading data...
#   VT parts after merge with stats: 103
#
# Reading indent data from VT sheet...
#   Book1 'VT' — Part col: 'Part'  Indent col: 'Indent'
#
#   Indent summary:
#     Total VT parts with indent data : 142
#     Parts skipped (low/trivial)     : 30
#     Parts with zero inventory       : 71  (forced into plan regardless)
#     SKIP  S31740-008A0X                   Whole monthly indent takes only 2.09h ≤ 4.0h threshold
#     SKIP  S31838-004A0X                   Whole monthly indent takes only 4.00h ≤ 4.0h threshold
#     SKIP  S31135-011A0X                   Whole monthly indent takes only 0.89h ≤ 4.0h threshold
#     SKIP  S31868-005A0X                   Whole monthly indent takes only 1.40h ≤ 4.0h threshold
#     SKIP  S12113-001A0X                   Monthly indent 46 < 150 (threshold)
#     SKIP  S12094-001A0X                   Monthly indent 30 < 150 (threshold)
#     SKIP  S13081-004A0X                   Monthly indent 6 < 150 (threshold)
#     SKIP  S41356-017A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S41222-022                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22085-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22063-003A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250068-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S01100-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250069-001                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21175-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S12087-004                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11436-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11340-008A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11122-015A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S13092-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S310966-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21021-021A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11358-028A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S21009-009A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S311010-03                      Monthly indent 0 < 150 (threshold)
#     SKIP  S31605-002A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S120197-005                     Monthly indent 0 < 150 (threshold)
#     SKIP  S110432-007                     Monthly indent 0 < 150 (threshold)
#     SKIP  14SW250069-00002X1              Monthly indent 0 < 150 (threshold)
#     SKIP  S03062-001A0X                   Monthly indent 0 < 150 (threshold)
#
#   VT changeover times loaded: 26 machines
#     JSW 1ST                   → 50 min (0.833 h)
#     M.P-01                    → 40 min (0.667 h)
#     M.P-03                    → 30 min (0.500 h)
#     M.P-04                    → 30 min (0.500 h)
#     M.P-05                    → 40 min (0.667 h)
#     M.P-07                    → 30 min (0.500 h)
#     M.P-08                    → 30 min (0.500 h)
#     M.P-09                    → 30 min (0.500 h)
#     M.P-10                    → 40 min (0.667 h)
#     M.P-11                    → 40 min (0.667 h)
#     M.P-12                    → 30 min (0.500 h)
#     M.P-13                    → 30 min (0.500 h)
#     M.P-14                    → 30 min (0.500 h)
#     M.P-15                    → 40 min (0.667 h)
#     M.P-16                    → 30 min (0.500 h)
#     M.P-17                    → 40 min (0.667 h)
#     TOYO 1ST                  → 50 min (0.833 h)
#     TOYO 2ND                  → 50 min (0.833 h)
#     TOYO 3RD                  → 50 min (0.833 h)
#     TOYO 4TH                  → 50 min (0.833 h)
#     TOYO 5TH                  → 50 min (0.833 h)
#     TOYO 6TH                  → 50 min (0.833 h)
#     TOYO 7TH                  → 50 min (0.833 h)
#     TOYO 80T 1ST              → 60 min (1.000 h)
#     TOYO 80T 2ND              → 60 min (1.000 h)
#     YUDEK 1ST                 → 30 min (0.500 h)
#   Book1 'VT' — Part col: 'Part'  Category col: 'Category'
#   Part categories — Runner: 17  Repeater: 3  Stranger: 122
#
#   Machine state loaded:
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S31851-002A0X
#     M.P-12                    last ran → S31842-004A0X
#     M.P-05                    last ran → S12104-006A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S31064-006A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S13114-003A0X
#     M.P-07                    last ran → S12106-001A0X
#     TOYO 6TH                  last ran → S01100-004A9X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13116-011A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S31068-005A0X
#     M.P-01                    last ran → S13120-001A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S11398-018A0X
#     M.P-13                    last ran → S03044-005A0X
#     M.P-15                    last ran → 14SW030082-00001X0
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#     TOYO 8TH                  last ran → S41356-017A0X
#     YUDEK 2ND                 last ran → S33045-010A0X
#
# ──────────────────────────────────────────────────────────────
#   VT Machines  |  103 parts  |  30 machines
# ──────────────────────────────────────────────────────────────
#   SCENARIO 1 — 76/95 parts critical (inv < 1 day indent)
#
#   Parts requiring production today (76):
#   Part                             Monthly    Daily       Inv    Target  Status
#   ──────────────────────────────  ────────  ───────  ────────  ────────  ────────────────────
#   14SW030081-00001X0                  8992   345.85         0       346  ZERO INV — FORCED
#   14SW030082-00001X0                  3167   121.81         0       122  ZERO INV — FORCED
#   14SW110487-00002X0                  1980    76.15         0        76  ZERO INV — FORCED
#   14SW210274-00008X0                260427  10016.42      6904      3112  PRODUCTION NEEDED
#   14SW210274-00013X0                115909  4458.04      2896      1562  PRODUCTION NEEDED
#   14SW210274-00016X0                115909  4458.04        30      4428  PRODUCTION NEEDED
#   14SW220197-00005X0                 22890   880.38         0       880  ZERO INV — FORCED
#   14SW220197-00010X0                 22890   880.38         8       872  PRODUCTION NEEDED
#   14SW220201-00005X0                  9959   383.04         0       383  ZERO INV — FORCED
#   14SW220201-00010X0                111888  4303.38         0      4303  ZERO INV — FORCED
#   14SW311082-00006X0                 68972  2652.77         2      2651  PRODUCTION NEEDED
#   14SW311082-00010X0                  5952   228.92       107       122  PRODUCTION NEEDED
#   14SW311083-00005X0                  5237   201.42       108        93  PRODUCTION NEEDED
#   14SW330127-00008X0                  8895   342.12        22       320  PRODUCTION NEEDED
#   14SW410464-00009X0                 19627   754.88         0       755  ZERO INV — FORCED
#   S01100-004A9X                      41737  1605.27         0      1605  ZERO INV — FORCED
#   S02020-010A0X                       3066   117.92         0       118  ZERO INV — FORCED
#   S03044-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S03046-005A0X                      20860   802.31         0       802  ZERO INV — FORCED
#   S03066-001A0X                       1622    62.38        14        48  PRODUCTION NEEDED
#   S11160-006A0X                         26     1.00         0         1  ZERO INV — FORCED
#   S11332-002A0X                         12     0.46         0         0  ZERO INV — FORCED
#   S11398-017A0X                       8036   309.08        92       217  PRODUCTION NEEDED
#   S11398-018A0X                       1707    65.65        10        56  PRODUCTION NEEDED
#   S11398-030A0X                       5696   219.08        36       183  PRODUCTION NEEDED
#   S12042-004A9X                      11806   454.08         0       454  ZERO INV — FORCED
#   S12052-003A0X                       7398   284.54         0       285  ZERO INV — FORCED
#   S12071-001A0X                        138     5.31         0         5  ZERO INV — FORCED
#   S12087-004A0X                      17336   666.77         0       667  ZERO INV — FORCED
#   S12089-001A0X                       6557   252.19         0       252  ZERO INV — FORCED
#   S12091-001A0X                       5697   219.12         0       219  ZERO INV — FORCED
#   S12094-003A0X                        246     9.46         0         9  ZERO INV — FORCED
#   S12095-003A0X                      25351   975.04       189       786  PRODUCTION NEEDED
#   S12095-004A0X                      17910   688.85         0       689  ZERO INV — FORCED
#   S12095-011A0X                      20941   805.42       443       362  PRODUCTION NEEDED
#   S12100-003A0X                      87393  3361.27         0      3361  ZERO INV — FORCED
#   S12102-001A0X                       2250    86.54         0        87  ZERO INV — FORCED
#   S12104-006A0X                      35975  1383.65         0      1384  ZERO INV — FORCED
#   S12106-001A0X                        216     8.31         0         8  ZERO INV — FORCED
#   S13071-012A0X                          6     0.23         0         0  ZERO INV — FORCED
#   S13080-004A0X                       1320    50.77         0        51  ZERO INV — FORCED
#   S13083-003A0X                      35277  1356.81       429       928  PRODUCTION NEEDED
#   S13083-011A0X                      21068   810.31         0       810  ZERO INV — FORCED
#   S13098-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S13108-002A0X                     173611  6677.35      1045      5632  PRODUCTION NEEDED
#   S13110-005A0X                      15629   601.12         0       601  ZERO INV — FORCED
#   S13112-006A0X                      29608  1138.77         0      1139  ZERO INV — FORCED
#   S13114-003A0X                        240     9.23         0         9  ZERO INV — FORCED
#   S13116-011A0X                       5322   204.69         0       205  ZERO INV — FORCED
#   S13120-001A0X                       2481    95.42         0        95  ZERO INV — FORCED
#   S13123-002A0X                       6760   260.00         0       260  ZERO INV — FORCED
#   S21021-012A0X                       7490   288.08         0       288  ZERO INV — FORCED
#   S21021-016A0X                       6710   258.08       217        41  PRODUCTION NEEDED
#   S21174-012A0X                     313865  12071.73         0     12072  ZERO INV — FORCED
#   S22127-003A0X                     295580  11368.46         0     11368  ZERO INV — FORCED
#   S25026-003A0X                        750    28.85         0        29  ZERO INV — FORCED
#   S25038-001A0X                      79058  3040.69       935      2106  PRODUCTION NEEDED
#   S31064-006A0X                        324    12.46         0        12  ZERO INV — FORCED
#   S31068-005A0X                        180     6.92         0         7  ZERO INV — FORCED
#   S31121-012A0X                      92130  3543.46         0      3543  ZERO INV — FORCED
#   S31123-005A0X                       1884    72.46         8        64  PRODUCTION NEEDED
#   S31437-004A0X                      68309  2627.27         0      2627  ZERO INV — FORCED
#   S31741-005A0X                      63205  2430.96         0      2431  ZERO INV — FORCED
#   S31839-004A0X                        867    33.35         0        33  ZERO INV — FORCED
#   S31842-004A0X                        360    13.85         0        14  ZERO INV — FORCED
#   S31851-002A0X                         36     1.38         0         1  ZERO INV — FORCED
#   S31867-002A0X                       8208   315.69         0       316  ZERO INV — FORCED
#   S32168-007A0X                      13608   523.38       207       316  PRODUCTION NEEDED
#   S32197-006A0X                     183056  7040.62         0      7041  ZERO INV — FORCED
#   S33045-010A0X                         58     2.23         0         2  ZERO INV — FORCED
#   S33105-016A0X                      15120   581.54         0       582  ZERO INV — FORCED
#   S33105-017A0X                      24089   926.50       185       742  PRODUCTION NEEDED
#   S33106-009A0X                          2     0.08         0         0  ZERO INV — FORCED
#   S33107-005A0X                         36     1.38         0         1  ZERO INV — FORCED
#   S41354-011A0X                      18713   719.73         0       720  ZERO INV — FORCED
#   S41356-021A0X                       3570   137.31       116        21  PRODUCTION NEEDED
#
#   Priority order — sorted by daily_indent descending (76 active parts):
#   Part                              Daily       Inv    Target  Zero_Inv
#   ──────────────────────────────  ───────  ────────  ────────  ────────
#   S21174-012A0X                   12071.73         0     12072       YES
#   S22127-003A0X                   11368.46         0     11368       YES
#   14SW210274-00008X0              10016.42      6904      3112        No
#   S32197-006A0X                   7040.62         0      7041       YES
#   S13108-002A0X                   6677.35      1045      5632        No
#   14SW210274-00013X0              4458.04      2896      1562        No
#   14SW210274-00016X0              4458.04        30      4428        No
#   14SW220201-00010X0              4303.38         0      4303       YES
#   S31121-012A0X                   3543.46         0      3543       YES
#   S12100-003A0X                   3361.27         0      3361       YES
#   S25038-001A0X                   3040.69       935      2106        No
#   14SW311082-00006X0              2652.77         2      2651        No
#   S31437-004A0X                   2627.27         0      2627       YES
#   S31741-005A0X                   2430.96         0      2431       YES
#   S01100-004A9X                   1605.27         0      1605       YES
#   S12104-006A0X                   1383.65         0      1384       YES
#   S13083-003A0X                   1356.81       429       928        No
#   S13112-006A0X                   1138.77         0      1139       YES
#   S12095-003A0X                    975.04       189       786        No
#   S33105-017A0X                    926.50       185       742        No
#   14SW220197-00005X0               880.38         0       880       YES
#   14SW220197-00010X0               880.38         8       872        No
#   S13083-011A0X                    810.31         0       810       YES
#   S12095-011A0X                    805.42       443       362        No
#   S03046-005A0X                    802.31         0       802       YES
#   14SW410464-00009X0               754.88         0       755       YES
#   S41354-011A0X                    719.73         0       720       YES
#   S12095-004A0X                    688.85         0       689       YES
#   S12087-004A0X                    666.77         0       667       YES
#   S13110-005A0X                    601.12         0       601       YES
#   S33105-016A0X                    581.54         0       582       YES
#   S32168-007A0X                    523.38       207       316        No
#   S12042-004A9X                    454.08         0       454       YES
#   14SW220201-00005X0               383.04         0       383       YES
#   14SW030081-00001X0               345.85         0       346       YES
#   14SW330127-00008X0               342.12        22       320        No
#   S31867-002A0X                    315.69         0       316       YES
#   S11398-017A0X                    309.08        92       217        No
#   S21021-012A0X                    288.08         0       288       YES
#   S12052-003A0X                    284.54         0       285       YES
#   S13123-002A0X                    260.00         0       260       YES
#   S21021-016A0X                    258.08       217        41        No
#   S12089-001A0X                    252.19         0       252       YES
#   14SW311082-00010X0               228.92       107       122        No
#   S12091-001A0X                    219.12         0       219       YES
#   S11398-030A0X                    219.08        36       183        No
#   S13116-011A0X                    204.69         0       205       YES
#   14SW311083-00005X0               201.42       108        93        No
#   S41356-021A0X                    137.31       116        21        No
#   14SW030082-00001X0               121.81         0       122       YES
#   S02020-010A0X                    117.92         0       118       YES
#   S13120-001A0X                     95.42         0        95       YES
#   S12102-001A0X                     86.54         0        87       YES
#   14SW110487-00002X0                76.15         0        76       YES
#   S31123-005A0X                     72.46         8        64        No
#   S11398-018A0X                     65.65        10        56        No
#   S03066-001A0X                     62.38        14        48        No
#   S13080-004A0X                     50.77         0        51       YES
#   S31839-004A0X                     33.35         0        33       YES
#   S25026-003A0X                     28.85         0        29       YES
#   S31842-004A0X                     13.85         0        14       YES
#   S31064-006A0X                     12.46         0        12       YES
#   S12094-003A0X                      9.46         0         9       YES
#   S13114-003A0X                      9.23         0         9       YES
#   S12106-001A0X                      8.31         0         8       YES
#   S31068-005A0X                      6.92         0         7       YES
#   S12071-001A0X                      5.31         0         5       YES
#   S03044-005A0X                      2.31         0         2       YES
#   S13098-005A0X                      2.31         0         2       YES
#   S33045-010A0X                      2.23         0         2       YES
#   S31851-002A0X                      1.38         0         1       YES
#   S33107-005A0X                      1.38         0         1       YES
#   S11160-006A0X                      1.00         0         1       YES
#   S11332-002A0X                      0.46         0         0       YES
#   S13071-012A0X                      0.23         0         0       YES
#   S33106-009A0X                      0.08         0         0       YES
#
#   PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer):
#     ✓ S21174-012A0X                  [Runner  ] → JSW 1ST          22.00h  qty=   13200  CO=No  [DEDICATED]
#     ✓ S22127-003A0X                  [Runner  ] → TOYO 3RD         22.00h  qty=   12185  CO=No  [DEDICATED]
#     ✓ 14SW210274-00008X0             [Runner  ] → TOYO 1ST         22.00h  qty=   11314  CO=No  [DEDICATED]
#     ✗ S32197-006A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ S13108-002A0X                  [Runner  ] → M.P-17           22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ 14SW210274-00013X0             [Runner  ] → M.P-09           5.02h  qty=    6020  CO=No  [DEDICATED]
#     ✗ 14SW210274-00016X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ 14SW220201-00010X0             [Runner  ] → M.P-04           22.00h  qty=    6336  CO=No  [DEDICATED]
#     ✓ S31121-012A0X                  [Runner  ] → M.P-16           22.00h  qty=    2829  CO=No  [DEDICATED]
#     ✓ S12100-003A0X                  [Runner  ] → TOYO 80T 2ND     22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ S25038-001A0X                  [Runner  ] → TOYO 4TH         20.73h  qty=    5146  CO=No  [DEDICATED]
#     ✗ 14SW311082-00006X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31437-004A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31741-005A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ S01100-004A9X                  [Runner  ] → TOYO 6TH         7.13h  qty=    3211  CO=No  [DEDICATED]
#
#   Runner-dedicated machines: ['JSW 1ST', 'M.P-04', 'M.P-09', 'M.P-16', 'M.P-17', 'TOYO 1ST', 'TOYO 3RD', 'TOYO 4TH', 'TOYO 6TH', 'TOYO 80T 2ND']
#
#   PASS 2 — Repeaters + Strangers (Runner machines excluded):
#     ✓ S12104-006A0X                  [Repeater] → M.P-05           17.30h  qty=    1384  CO=No  [ZERO-INV FORCED]
#     ✓ S13083-003A0X                  [Repeater] → M.P-11           7.73h  qty=     928  CO=Yes (40min)
#     ✓ S13112-006A0X                  [Repeater] → YUDEK 1ST        4.74h  qty=    1139  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12095-003A0X                  [Stranger] → M.P-12           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S33105-017A0X                  [Stranger] → M.P-14           4.00h  qty=    6400  CO=Yes (30min)
#     ✓ 14SW220197-00005X0             [Stranger] → M.P-01           4.00h  qty=    1152  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW220197-00010X0             [Stranger] → M.P-03           4.00h  qty=    1516  CO=Yes (30min)
#     ✓ S13083-011A0X                  [Stranger] → M.P-07           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12095-011A0X                  [Stranger] → M.P-08           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S03046-005A0X                  [Stranger] → TOYO 5TH         4.00h  qty=    2400  CO=No  [ZERO-INV FORCED]
#     ✓ 14SW410464-00009X0             [Stranger] → M.P-13           4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S41354-011A0X                  [Stranger] → M.P-10           9.60h  qty=     720  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12095-004A0X                  [Stranger] → M.P-15           8.61h  qty=     689  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12087-004A0X                  [Stranger] → TOYO 80T 1ST     7.04h  qty=     667  CO=Yes (60min)  [ZERO-INV FORCED]
#     ✓ S13110-005A0X                  [Stranger] → TOYO 2ND         4.00h  qty=    2400  CO=No  [ZERO-INV FORCED]
#     ✓ S33105-016A0X                  [Stranger] → TOYO 80T 1ST     4.00h  qty=     960  CO=Yes (60min)  [ZERO-INV FORCED]
#     ✓ S32168-007A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=    1920  CO=Yes (40min)
#     ✓ S12042-004A9X                  [Stranger] → M.P-12           4.00h  qty=    2057  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW220201-00005X0             [Stranger] → M.P-01           4.00h  qty=     800  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW030081-00001X0             [Stranger] → M.P-11           4.00h  qty=     640  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW330127-00008X0             [Stranger] → TOYO 80T 1ST     4.00h  qty=     720  CO=Yes (60min)
#     ✓ S31867-002A0X                  [Stranger] → M.P-14           4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11398-017A0X                  [Stranger] → M.P-03           4.00h  qty=    1920  CO=Yes (30min)
#     ✓ S21021-012A0X                  [Stranger] → M.P-15           4.00h  qty=     360  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12052-003A0X                  [Stranger] → M.P-07           4.00h  qty=     514  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S13123-002A0X                  [Stranger] → M.P-08           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S21021-016A0X                  [Stranger] → M.P-01           4.00h  qty=    1152  CO=Yes (40min)
#     ✓ S12089-001A0X                  [Stranger] → M.P-13           4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW311082-00010X0             [Stranger] → YUDEK 2ND        4.00h  qty=     720  CO=Yes (40min)
#     ✓ S12091-001A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11398-030A0X                  [Stranger] → M.P-10           4.00h  qty=     480  CO=Yes (40min)
#     ✓ S13116-011A0X                  [Stranger] → M.P-11           4.00h  qty=     450  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ 14SW311083-00005X0             [Stranger] → M.P-12           4.00h  qty=    1029  CO=Yes (30min)
#     ✓ S41356-021A0X                  [Stranger] → M.P-14           4.00h  qty=     180  CO=Yes (30min)
#     ✓ 14SW030082-00001X0             [Stranger] → M.P-15           4.00h  qty=     640  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S02020-010A0X                  [Stranger] → M.P-03           4.00h  qty=    1600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S13120-001A0X                  [Stranger] → M.P-01           4.00h  qty=     480  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12102-001A0X                  [Stranger] → M.P-07           4.00h  qty=    1920  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ 14SW110487-00002X0             [Stranger] → M.P-08           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31123-005A0X                  [Stranger] → M.P-13           4.00h  qty=    1440  CO=Yes (30min)
#     ✓ S11398-018A0X                  [Stranger] → M.P-10           4.00h  qty=     640  CO=Yes (40min)
#     ✓ S03066-001A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=    1309  CO=Yes (40min)
#     ✓ S13080-004A0X                  [Stranger] → M.P-05           4.00h  qty=    1252  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S31839-004A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=     800  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S25026-003A0X                  [Stranger] → TOYO 7TH         4.00h  qty=     670  CO=No  [ZERO-INV FORCED]
#     ✓ S31842-004A0X                  [Stranger] → M.P-12           4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31064-006A0X                  [Stranger] → M.P-14           4.00h  qty=     600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S12094-003A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=0.04h, M.
#     ✓ S13114-003A0X                  [Stranger] → M.P-03           4.00h  qty=    1440  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12106-001A0X                  [Stranger] → M.P-07           4.00h  qty=     960  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31068-005A0X                  [Stranger] → M.P-08           4.00h  qty=     480  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S12071-001A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=0.04h, M.
#     ✓ S03044-005A0X                  [Stranger] → M.P-13           4.00h  qty=     720  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S13098-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=0.04h, M.
#     ✓ S33045-010A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=    6400  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S31851-002A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=    1600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✗ S33107-005A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: M.P-05=0.04h, M.
#     ✗ S11160-006A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S11332-002A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S13071-012A0X                  [Stranger]  NOT PLANNED — Remaining hrs < MIN after changeover. Free: YUDEK 1ST=3.26h,
#     ✗ S33106-009A0X                  [Stranger]  NOT PLANNED — All compatible machines full. Free: TOYO 80T 1ST=3.96h
#
#   22-hour filler:
#     ↑ S13112-006A0X                  → YUDEK 1ST        +3.26h merged  qty+=782  [EXTEND]
#     ↑ S12095-003A0X                  → M.P-12           +4.00h merged  qty+=960  [EXTEND]
#     ↑ S12104-006A0X                  → M.P-05           +0.04h merged  qty+=3  [EXTEND]
#     ↑ S33105-017A0X                  → M.P-14           +4.00h merged  qty+=6400  [EXTEND]
#     ↑ S12087-004A0X                  → TOYO 80T 1ST     +3.96h merged  qty+=375  [EXTEND]
#     ↑ S13110-005A0X                  → TOYO 2ND         +18.00h merged  qty+=10800  [EXTEND]
#     ↑ 14SW220197-00010X0             → M.P-03           +4.00h merged  qty+=1516  [EXTEND]
#     ↑ S13083-011A0X                  → M.P-07           +4.00h merged  qty+=1440  [EXTEND]
#     ↑ S01100-004A9X                  → TOYO 6TH         +14.87h merged  qty+=6692  [EXTEND]
#     ↑ S25026-003A0X                  → TOYO 7TH         +18.00h merged  qty+=3014  [EXTEND]
#     ↑ S13083-003A0X                  → M.P-11           +4.27h merged  qty+=512  [EXTEND]
#     ↑ 14SW210274-00013X0             → M.P-09           +16.98h merged  qty+=20376  [EXTEND]
#     ↑ S12095-011A0X                  → M.P-08           +4.00h merged  qty+=960  [EXTEND]
#     ↑ 14SW220197-00005X0             → M.P-01           +3.33h merged  qty+=959  [EXTEND]
#     ↑ S41354-011A0X                  → M.P-10           +2.40h merged  qty+=180  [EXTEND]
#     ↑ 14SW410464-00009X0             → M.P-13           +4.00h merged  qty+=1920  [EXTEND]
#     ↑ S12095-004A0X                  → M.P-15           +3.39h merged  qty+=271  [EXTEND]
#     ↑ S25038-001A0X                  → TOYO 4TH         +1.27h merged  qty+=315  [EXTEND]
#     ↑ S03046-005A0X                  → TOYO 5TH         +18.00h merged  qty+=10800  [EXTEND]
#     + S41356-017A0X                  → TOYO 8TH         22.00h  qty=6336  [Filler]  CO=No
#     ↑ S32168-007A0X                  → YUDEK 2ND        +3.33h merged  qty+=1598  [EXTEND]
#     No duplicate parts — each part appears exactly once  ✓
#
#   ==========================================================
#   TOOL-CHANGER GLOBAL STAGGER  (single tool changer — all VT)
#   ==========================================================
#   Total CO events across all VT machines: 36
#
#   Machine            Part Before            Part After              CO Dur  Natural   Actual   Delay Spare Used
#   ────────────────── ────────────────────── ────────────────────── ─────── ──────── ──────── ─────── ──────────
#   M.P-01             14SW220197-00005X0     14SW220201-00005X0       40.0m    08:00    08:00    none          —
#   YUDEK 2ND          S32168-007A0X          14SW311082-00010X0       40.0m    08:00    08:00 +0.1min     +1 pcs
#   M.P-03             14SW220197-00010X0     S11398-017A0X            30.0m    08:30    08:30    none          —
#   M.P-07             S13083-011A0X          S12052-003A0X            30.0m    08:30    08:30    none          —
#   M.P-08             S12095-011A0X          S13123-002A0X            30.0m    08:30    08:30    none          —
#   M.P-12             S12095-003A0X          S12042-004A9X            30.0m    08:30    08:30    none          —
#   M.P-13             14SW410464-00009X0     S12089-001A0X            30.0m    08:30    08:30    none          —
#   M.P-14             S33105-017A0X          S31867-002A0X            30.0m    08:30    08:30    none          —
#   YUDEK 1ST          S13112-006A0X          S12091-001A0X            30.0m    08:30    08:30    none          —
#   TOYO 80T 1ST       S12087-004A0X          S33105-016A0X            60.0m    12:00    12:00    none          —
#   M.P-01             14SW220201-00005X0     S21021-016A0X            40.0m    12:40    12:40 +0.1min     +0 pcs
#   YUDEK 2ND          14SW311082-00010X0     S03066-001A0X            40.0m    12:40    12:40    none          —
#   M.P-10             S41354-011A0X          S11398-030A0X            40.0m    12:40    12:40    none          —
#   M.P-11             S13083-003A0X          14SW030081-00001X0       40.0m    12:40    12:40    none          —
#   M.P-15             S12095-004A0X          S21021-012A0X            40.0m    12:40    12:40    none          —
#   M.P-03             S11398-017A0X          S02020-010A0X            30.0m    13:00    13:00    none          —
#   M.P-07             S12052-003A0X          S12102-001A0X            30.0m    13:00    13:00    none          —
#   M.P-08             S13123-002A0X          14SW110487-00002X0       30.0m    13:00    13:00    none          —
#   M.P-12             S12042-004A9X          14SW311083-00005X0       30.0m    13:00    13:00    none          —
#   M.P-13             S12089-001A0X          S31123-005A0X            30.0m    13:00    13:00    none          —
#   M.P-14             S31867-002A0X          S41356-021A0X            30.0m    13:00    13:00    none          —
#   YUDEK 1ST          S12091-001A0X          S31839-004A0X            30.0m    13:00    13:00    none          —
#   TOYO 80T 1ST       S33105-016A0X          14SW330127-00008X0       60.0m    17:00    17:00    none          —
#   M.P-01             S21021-016A0X          S13120-001A0X            40.0m    17:20    17:20    none          —
#   YUDEK 2ND          S03066-001A0X          S33045-010A0X            40.0m    17:20    17:20    none          —
#   M.P-10             S11398-030A0X          S11398-018A0X            40.0m    17:20    17:20    none          —
#   M.P-11             14SW030081-00001X0     S13116-011A0X            40.0m    17:20    17:20    none          —
#   M.P-15             S21021-012A0X          14SW030082-00001X0       40.0m    17:20    17:20    none          —
#   M.P-05             S12104-006A0X          S13080-004A0X            40.0m    17:20    17:20    none          —
#   M.P-03             S02020-010A0X          S13114-003A0X            30.0m    17:30    17:30    none          —
#   M.P-07             S12102-001A0X          S12106-001A0X            30.0m    17:30    17:30    none          —
#   M.P-08             14SW110487-00002X0     S31068-005A0X            30.0m    17:30    17:30    none          —
#   M.P-12             14SW311083-00005X0     S31842-004A0X            30.0m    17:30    17:30    none          —
#   M.P-13             S31123-005A0X          S03044-005A0X            30.0m    17:30    17:30    none          —
#   M.P-14             S41356-021A0X          S31064-006A0X            30.0m    17:30    17:30    none          —
#   YUDEK 1ST          S31839-004A0X          S31851-002A0X            30.0m    17:30    17:30    none          —
#
#   ──────────────────────────────────────────────────────────
#   Tool-changer queue complete:
#     Total CO events    : 36
#     Events delayed     : 2
#     Total delay time   : 0.2 min
#     Unresolvable (22h) : 33  ← review manually
#     Tool changer free  : 18:00  (last CO ends at 18:00)
#
#   Serialized tool-changer queue (final):
#   #    Machine               Start      End Part After
#   ──── ────────────────── ──────── ──────── ──────────────────────
#   1    M.P-01                08:00    08:40 14SW220201-00005X0
#   2    YUDEK 2ND             08:00    08:40 14SW311082-00010X0
#   3    M.P-03                08:30    09:00 S11398-017A0X
#   4    M.P-07                08:30    09:00 S12052-003A0X
#   5    M.P-08                08:30    09:00 S13123-002A0X
#   6    M.P-12                08:30    09:00 S12042-004A9X
#   7    M.P-13                08:30    09:00 S12089-001A0X
#   8    M.P-14                08:30    09:00 S31867-002A0X
#   9    YUDEK 1ST             08:30    09:00 S12091-001A0X
#   10   TOYO 80T 1ST          12:00    13:00 S33105-016A0X
#   11   M.P-01                12:40    13:20 S21021-016A0X
#   12   YUDEK 2ND             12:40    13:20 S03066-001A0X
#   13   M.P-10                12:40    13:20 S11398-030A0X
#   14   M.P-11                12:40    13:20 14SW030081-00001X0
#   15   M.P-15                12:40    13:20 S21021-012A0X
#   16   M.P-03                13:00    13:30 S02020-010A0X
#   17   M.P-07                13:00    13:30 S12102-001A0X
#   18   M.P-08                13:00    13:30 14SW110487-00002X0
#   19   M.P-12                13:00    13:30 14SW311083-00005X0
#   20   M.P-13                13:00    13:30 S31123-005A0X
#   21   M.P-14                13:00    13:30 S41356-021A0X
#   22   YUDEK 1ST             13:00    13:30 S31839-004A0X
#   23   TOYO 80T 1ST          17:00    18:00 14SW330127-00008X0
#   24   M.P-01                17:20    18:00 S13120-001A0X
#   25   YUDEK 2ND             17:20    18:00 S33045-010A0X
#   26   M.P-10                17:20    18:00 S11398-018A0X
#   27   M.P-11                17:20    18:00 S13116-011A0X
#   28   M.P-15                17:20    18:00 14SW030082-00001X0
#   29   M.P-05                17:20    18:00 S13080-004A0X
#   30   M.P-03                17:30    18:00 S13114-003A0X
#   31   M.P-07                17:30    18:00 S12106-001A0X
#   32   M.P-08                17:30    18:00 S31068-005A0X
#   33   M.P-12                17:30    18:00 S31842-004A0X
#   34   M.P-13                17:30    18:00 S03044-005A0X
#   35   M.P-14                17:30    18:00 S31064-006A0X
#   36   YUDEK 1ST             17:30    18:00 S31851-002A0X
#   ==========================================================
#
#   Machine state saved → machine_state.json
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S31851-002A0X
#     M.P-12                    last ran → S31842-004A0X
#     M.P-05                    last ran → S13080-004A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S31064-006A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S13114-003A0X
#     M.P-07                    last ran → S12106-001A0X
#     TOYO 6TH                  last ran → S01100-004A9X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13116-011A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S31068-005A0X
#     M.P-01                    last ran → S13120-001A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S11398-018A0X
#     M.P-13                    last ran → S03044-005A0X
#     M.P-15                    last ran → 14SW030082-00001X0
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#     TOYO 8TH                  last ran → S41356-017A0X
#     YUDEK 2ND                 last ran → S33045-010A0X
#
# Writing → 1Smart_APS_Plan_20260318Indent.xlsx
#   Formatting applied  ✓
#
# ==============================================================
#   Smart APS V6 Complete  —  VT Only  —  2026-03-18
#   Indent month  : March 2026
#   Working days  : 26  (31 days − 5 Sundays)
# ==============================================================
#   planned            =   64
#   not_required_today =    0  (inv covers daily indent)
#   skipped            =    7  (indent < 150 qty  OR  whole indent ≤ 4.0h)
#   not_planned        =   13  (needed but no machine capacity)
#
#   Output  → 1Smart_APS_Plan_20260318Indent.xlsx
#   State   → machine_state.json
#
#   NOTE: Update SECTION 1 each morning:
#         PLANNING_DATE = date(2026, 3, 15)
#         INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over

# %%
import pandas as pd
import numpy as np
import json
import os
import calendar
from datetime import datetime, date

# =============================================================
# ██████╗  █████╗ ██████╗  █████╗ ███╗   ███╗███████╗
# ██╔══██╗██╔══██╗██╔══██╗██╔══██╗████╗ ████║██╔════╝
# ██████╔╝███████║██████╔╝███████║██╔████╔██║███████╗
# ██╔═══╝ ██╔══██║██╔══██╗██╔══██║██║╚██╔╝██║╚════██║
# ██║     ██║  ██║██║  ██║██║  ██║██║ ╚═╝ ██║███████║
# ╚═╝     ╚═╝  ╚═╝╚═╝  ╚═╝╚═╝  ╚═╝╚═╝     ╚═╝╚══════╝
#
#  Smart APS V6  —  VT-Only Indent-Based Planning
#
#  Planning logic:
#    daily_indent  = monthly_indent / working_days
#    today_target  = max(0, daily_indent − inventory)
#    working_days  = calendar days in month − number of Sundays
#
#  Skip rules (part excluded from planning entirely):
#    • monthly_indent < 100
#    • monthly_indent / rate  ≤ 2 hours  (whole indent is trivial)
#
#  Zero-inventory rule:
#    If inventory = 0, part is FORCED into plan regardless of
#    skip rules. Parts sorted by highest daily_indent first
#    (greedy fill) so most critical parts always get time.
# =============================================================

# =============================================================
# SECTION 1 — DAILY SETTINGS  (change these every morning)
# -------------------------------------------------------------
# Only two lines to update each day:
#   PLANNING_DATE  : today
#   INDENT_MONTH   : only change when the month rolls over
# =============================================================

PLANNING_DATE = date(2026, 3, 18)   # ← change daily
INDENT_MONTH  = date(2026, 3,  1)   # ← change when month rolls over

# =============================================================
# SECTION 2 — PARAMETERS
# =============================================================

AVAILABLE_HOURS    = 22        # machine hours available per shift
MIN_RUN_HOURS      = 4         # minimum run block per part
TARGET_DAYS_INV    = 3         # ideal inventory buffer (days)
MACHINE_STATE_FILE = "machine_state.json"

# Skip thresholds
MIN_MONTHLY_INDENT = 150       # skip if monthly indent < this
MIN_INDENT_HOURS   = 4.0       # skip if whole monthly indent takes ≤ this many hours
                               # (monthly_indent / rate ≤ MIN_INDENT_HOURS)
                               # EXCEPTION: zero-inventory parts are never skipped

# Priority: parts are sorted purely by daily_indent descending.
# Highest daily indent = most critical = planned first.
# Within same daily_indent, zero-inventory parts rank above others.

# =============================================================
# SECTION 3 — FILE PATHS
# =============================================================

book_path       = "C:/Users/Ex0164/Book1.xlsx"
matrix_path     = "C:/Users/Ex0164/Important codes/compatibility_matrix.xlsx"
changeover_path = "D:/Tushar/TOOL FIX/Unique_Machines_vt.xlsx"
output_path     = f"1Smart_APS_Plan_{PLANNING_DATE.strftime('%Y%m%d')}Indent.xlsx"

# =============================================================
# SECTION 4 — WORKING DAYS CALCULATION
# -------------------------------------------------------------
# working_days = calendar days in INDENT_MONTH − Sundays
# Example: March 2026 → 31 days, 5 Sundays → 26 working days
# =============================================================

def compute_working_days(ref_date):
    year  = ref_date.year
    month = ref_date.month
    total = calendar.monthrange(year, month)[1]
    sundays = sum(
        1 for d in range(1, total + 1)
        if date(year, month, d).weekday() == 6
    )
    return total - sundays, total, sundays

WORKING_DAYS, TOTAL_DAYS, SUNDAY_COUNT = compute_working_days(INDENT_MONTH)

print(f"\n{'='*62}")
print(f"  Smart APS V6  —  VT-Only Indent-Based Planning")
print(f"  Planning date  : {PLANNING_DATE}")
print(f"  Indent month   : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Total days     : {TOTAL_DAYS}")
print(f"  Sundays        : {SUNDAY_COUNT}")
print(f"  Working days   : {WORKING_DAYS}  (used as divisor)")
print(f"  Daily target   : monthly_indent / {WORKING_DAYS}")
print(f"  Today target   : max(0, daily_indent - inventory)")
print(f"  Skip rule 1    : monthly_indent < {MIN_MONTHLY_INDENT} qty")
print(f"  Skip rule 2    : monthly_indent / rate  ≤ {MIN_INDENT_HOURS}h (trivial run)")
print(f"  Zero-inv rule  : inventory=0 parts always forced into plan")
print(f"{'='*62}\n")

# =============================================================
# SECTION 5 — LOAD DATA  (VT sheet is the single source of truth)
# =============================================================

print("Loading data...")
vt_parts_raw = pd.read_excel(book_path,       sheet_name="VT")
vt_matrix    = pd.read_excel(matrix_path,     sheet_name="VT_Matrix")
vt_co_raw    = pd.read_excel(changeover_path, sheet_name="VT_Changeover")

# =============================================================
# SECTION 6 — READ ALL DATA FROM VT SHEET
# -------------------------------------------------------------
# VT sheet is the single source of truth. It must contain:
#   • Part          — part code
#   • Cycle time    — cycle time in seconds
#   • Cavity        — number of cavities
#   • Inventory     — current stock
#   • Indent        — monthly indent quantity
#   • Category      — Runner / Repeater / Stranger
#
# Rate (units/hour) = (3600 / cycle_time_seconds) × cavity_count
#
# All columns are matched case-insensitively.
# A clear error is raised if any required column is missing.
# =============================================================

def find_col(df, name, sheet):
    """Case-insensitive column finder. Raises clear error if missing."""
    match = next((c for c in df.columns if str(c).strip().lower() == name.lower()), None)
    if match is None:
        raise ValueError(
            f"Column '{name}' not found in sheet '{sheet}'.\n"
            f"Available columns: {list(df.columns)}"
        )
    return match

# Locate every required column in VT sheet
vt_col_part      = find_col(vt_parts_raw, "Part",       "VT")
vt_col_cycletime = find_col(vt_parts_raw, "Cycle time", "VT")
vt_col_cavity    = find_col(vt_parts_raw, "Cavity",     "VT")
vt_col_inventory = find_col(vt_parts_raw, "Inventory",  "VT")
vt_col_indent    = find_col(vt_parts_raw, "Indent",     "VT")

print(f"  VT sheet columns found:")
print(f"    Part       → '{vt_col_part}'")
print(f"    Cycle time → '{vt_col_cycletime}'")
print(f"    Cavity     → '{vt_col_cavity}'")
print(f"    Inventory  → '{vt_col_inventory}'")
print(f"    Indent     → '{vt_col_indent}'")

# Drop blank part rows, deduplicate
data = vt_parts_raw[
    vt_parts_raw[vt_col_part].notna() &
    (vt_parts_raw[vt_col_part].astype(str).str.strip() != "")
].copy()
data = data.drop_duplicates(subset=vt_col_part).copy()
data["Material"] = data[vt_col_part].astype(str).str.strip()

# Rate formula:
#   cycle_time = time per piece per cavity (seconds)
#   For N cavities: shot takes cycle_time × N seconds, produces N pieces
#   → Rate = (3600 / (cycle_time × cavity)) × cavity = 3600 / cycle_time
#   Cavities cancel — rate depends only on cycle_time.
#   Example: cycle_time=15s, cavity=2 → shot=30s, 2 pcs → 240 pcs/hr = 3600/15
data["_ct"] = pd.to_numeric(data[vt_col_cycletime], errors="coerce").replace(0, np.nan)
data["_cv"] = pd.to_numeric(data[vt_col_cavity],    errors="coerce").replace(0, np.nan)
data["Rate"] = 3600 / data["_ct"]   # cavities cancel — see formula above

# Parts with valid rate (cycle time present and non-zero)
# Cavity is retained for reference but does NOT affect rate.
data_valid     = data[data["Rate"].notna()].copy()
data_zero_rate = data[data["Rate"].isna()].copy()   # only zero/missing cycle time

print(f"\n  VT parts in sheet            : {len(data)}")
print(f"  Parts with valid rate        : {len(data_valid)}")
if len(data_zero_rate) > 0:
    print(f"  Parts with zero/missing cycle time : {len(data_zero_rate)}")
    for _, r in data_zero_rate.iterrows():
        ct = r[vt_col_cycletime]
        print(f"    {str(r['Material']):30s}  cycle_time={ct}  (cavity={r[vt_col_cavity]} — not used in rate)")

# =============================================================
# SECTION 7 — BUILD LOOKUP DICTIONARIES  (all from VT sheet)
# =============================================================

def safe_dict_from_df(df, key_col, val_col, default=0.0):
    return {
        str(k).strip(): (default if pd.isna(v) else float(v))
        for k, v in zip(df[key_col], df[val_col])
        if pd.notna(k) and str(k).strip() != ""
    }

# Use data_valid for rate (only parts with computable rate)
# Use full data for inventory and indent (available for all parts)
inventory = safe_dict_from_df(data,       "Material", vt_col_inventory)
rate      = safe_dict_from_df(data_valid, "Material", "Rate")

# =============================================================
# SECTION 7A — INDENT DICTIONARIES  (read from VT sheet)
# -------------------------------------------------------------
# indent_monthly   : {part → monthly indent qty}
# indent_daily     : {part → monthly / working_days}
# today_target_qty : {part → max(0, daily_indent − inventory)}
# =============================================================

print("\nReading indent data from VT sheet...")
indent_monthly = safe_dict_from_df(data, "Material", vt_col_indent)

indent_daily = {
    p: round(qty / WORKING_DAYS, 4)
    for p, qty in indent_monthly.items()
}

today_target_qty = {
    p: max(0.0, indent_daily.get(p, 0.0) - inventory.get(p, 0.0))
    for p in indent_monthly
}

# ── Skip flags ───────────────────────────────────────────────
# A part is skipped ONLY when BOTH conditions below are true:
#   condition met  AND  inventory > 0
# If inventory == 0, part is NEVER skipped — it must be made.

def should_skip(part):
    """
    Returns (skip: bool, reason: str).
    Zero-inventory parts are never skipped.
    """
    inv     = inventory.get(part, 0.0)
    monthly = indent_monthly.get(part, 0.0)
    r       = rate.get(part, 1.0)

    # Zero inventory → always force into plan
    if inv == 0.0 and monthly > 0:
        return False, ""

    if monthly < MIN_MONTHLY_INDENT:
        return True, (f"Monthly indent {monthly:.0f} < {MIN_MONTHLY_INDENT} "
                      f"(threshold)")

    indent_hrs = monthly / r if r > 0 else 0.0
    if indent_hrs <= MIN_INDENT_HOURS:
        return True, (f"Whole monthly indent takes only {indent_hrs:.2f}h "
                      f"≤ {MIN_INDENT_HOURS}h threshold")

    return False, ""

# Print skip summary
skipped_parts = {p: should_skip(p) for p in indent_monthly}
n_skip  = sum(1 for skip, _ in skipped_parts.values() if skip)
n_force = sum(1 for p in indent_monthly
              if inventory.get(p, 0) == 0 and indent_monthly.get(p, 0) > 0)
print(f"\n  Indent summary:")
print(f"    Total VT parts with indent data : {len(indent_monthly)}")
print(f"    Parts skipped (low/trivial)     : {n_skip}")
print(f"    Parts with zero inventory       : {n_force}  (forced into plan regardless)")

for p, (skip, reason) in skipped_parts.items():
    if skip:
        print(f"    SKIP  {p:30s}  {reason}")

# =============================================================
# SECTION 7B — CHANGEOVER TIMES  (VT only)
# =============================================================

def build_changeover_dict(co_df):
    co_dict = {}
    for _, row in co_df.iterrows():
        machine = str(row["Unique Machines"]).strip()
        minutes = row["Changeover time"]
        if pd.notna(minutes) and machine:
            co_dict[machine] = float(minutes) / 60.0
    return co_dict

vt_changeover = build_changeover_dict(vt_co_raw)
DEFAULT_CHANGEOVER_HRS = 40 / 60.0

print(f"\n  VT changeover times loaded: {len(vt_changeover)} machines")
for m, h in vt_changeover.items():
    print(f"    {m:25s} → {h*60:.0f} min ({h:.3f} h)")

# =============================================================
# SECTION 7C — PART CATEGORY  (Runner / Repeater / Stranger)
# =============================================================

def build_category_from_sheet(df, sheet_name):
    cat     = {}
    part_col = next((c for c in df.columns if str(c).strip().lower() == "part"),     None)
    cat_col  = next((c for c in df.columns if str(c).strip().lower() == "category"), None)
    if part_col is None:
        print(f"  WARNING: 'Part' column not found in '{sheet_name}'")
        return cat
    if cat_col is None:
        print(f"  WARNING: 'Category' column not found in '{sheet_name}' — all parts set to Stranger")
        # Default all parts to Stranger if column missing
        for _, row in df.iterrows():
            p = row[part_col]
            if pd.notna(p) and str(p).strip():
                cat[str(p).strip()] = "Stranger"
        return cat
    for _, row in df.iterrows():
        part = row[part_col]
        val  = str(row[cat_col]).strip() if pd.notna(row[cat_col]) else "Stranger"
        if pd.isna(part) or str(part).strip() == "":
            continue
        if val.lower() in ("runner", "repeater", "stranger"):
            val = val.capitalize()
        cat[str(part).strip()] = val
    return cat

part_category  = build_category_from_sheet(vt_parts_raw, "VT")
runner_count   = sum(1 for v in part_category.values() if v == "Runner")
repeater_count = sum(1 for v in part_category.values() if v == "Repeater")
stranger_count = sum(1 for v in part_category.values() if v == "Stranger")
print(f"  Part categories — Runner: {runner_count}  "
      f"Repeater: {repeater_count}  Stranger: {stranger_count}")

# =============================================================
# SECTION 8 — MACHINE STATE
# =============================================================

def load_machine_state():
    if os.path.exists(MACHINE_STATE_FILE):
        with open(MACHINE_STATE_FILE) as f:
            state = json.load(f)
        print(f"\n  Machine state loaded:")
        for m, p in state.items():
            print(f"    {m:25s} last ran → {p}")
        return state
    print("\n  Machine state: FIRST RUN — no previous state. "
          f"State will be saved to '{MACHINE_STATE_FILE}' after this run.")
    return {}

def save_machine_state(vt_state):
    combined = {m: p for m, p in vt_state.items() if p is not None}
    with open(MACHINE_STATE_FILE, "w") as f:
        json.dump(combined, f, indent=2)
    print(f"\n  Machine state saved → {MACHINE_STATE_FILE}")
    for m, p in combined.items():
        print(f"    {m:25s} last ran → {p}")

machine_state = load_machine_state()

# =============================================================
# SECTION 9 — COMPATIBILITY MATRIX  (VT only)
# =============================================================

def build_compatibility(matrix):
    machines = matrix.columns[1:].tolist()
    compat   = {}
    for _, row in matrix.iterrows():
        part = row["Part"]
        for m in machines:
            if row[m] == 1:
                compat.setdefault(part, []).append(m)
    return compat, machines

vt_compat, vt_machines = build_compatibility(vt_matrix)

# =============================================================
# SECTION 10 — INDENT HORIZON TABLE
# -------------------------------------------------------------
# Shows per-part planning numbers and skip/force status.
# =============================================================

def compute_indent_horizon(parts):
    rows = []
    for p in parts:
        inv     = inventory.get(p, 0.0)
        monthly = indent_monthly.get(p, 0.0)
        daily   = indent_daily.get(p, 0.0)
        target  = today_target_qty.get(p, 0.0)
        r       = rate.get(p, 1.0)
        skip, skip_reason = should_skip(p)
        indent_hrs = monthly / r if r > 0 else 0.0

        if inv == 0.0 and monthly > 0:
            status = "ZERO INV — FORCED"
        elif skip:
            status = "SKIPPED"
        elif target > 0:
            status = "PRODUCTION NEEDED"
        elif monthly == 0:
            status = "NO INDENT"
        else:
            status = "INV SUFFICIENT"

        rows.append({
            "Part":              p,
            "Monthly_Indent":    round(monthly, 0),
            "Indent_Hrs_Total":  round(indent_hrs, 2),
            "Working_Days":      WORKING_DAYS,
            "Daily_Indent":      round(daily, 2),
            "Inventory_Now":     round(inv, 0),
            "Today_Target_Qty":  round(target, 0),
            "Today_Target_Hrs":  round(target / r if r > 0 else 0, 2),
            "Rate_Per_Hr":       round(r, 2),
            "Indent_Status":     status,
            "Skip_Reason":       skip_reason,
        })
    return pd.DataFrame(rows)

# =============================================================
# SECTION 11 — SCENARIO CLASSIFIER
# =============================================================

def classify_scenario(parts):
    coverage = []
    for p in parts:
        inv   = inventory.get(p, 0)
        daily = indent_daily.get(p, 0)
        skip, _ = should_skip(p)
        if skip:
            continue
        if daily == 0:
            continue
        coverage.append(inv / daily)

    if not coverage:
        return 3, "SCENARIO 3 — All active parts have zero indent today"

    n        = len(coverage)
    critical = sum(1 for c in coverage if c < 1)
    low      = sum(1 for c in coverage if c < TARGET_DAYS_INV)

    if critical == n:
        return 0, "SCENARIO 0 — ALL parts critical (inv < 1 day indent)"
    elif critical > 0:
        return 1, f"SCENARIO 1 — {critical}/{n} parts critical (inv < 1 day indent)"
    elif low > 0:
        return 2, f"SCENARIO 2 — {low}/{n} parts below {TARGET_DAYS_INV}-day buffer"
    else:
        return 3, f"SCENARIO 3 — All parts healthy (≥{TARGET_DAYS_INV} days inv)"

# =============================================================
# SECTION 12 — PRIORITY ORDERING
# -------------------------------------------------------------
# Parts are ranked purely by daily_indent descending.
# Highest daily indent = largest requirement = planned first.
# This ensures big parts always get machine time before small ones.
#
# Tie-break: zero-inventory parts rank above parts with some stock
# at the same daily_indent level (inv=0 → sort key slightly higher).
#
# "Inventory sufficient" parts (inv >= daily_indent) are excluded
# from the active list before this function is called.
# =============================================================

def compute_priority(parts, horizon_df):
    horizon = horizon_df.set_index("Part")
    rows    = []
    for p in parts:
        inv      = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        days_cov = inv / daily if daily > 0 else 999
        target   = horizon.loc[p, "Today_Target_Qty"] if p in horizon.index else 0

        # Sort key: daily_indent descending.
        # Zero-inventory parts get a tiny tie-break boost (+0.0001)
        # so they edge out same-daily_indent parts that have some stock.
        sort_key = daily + (0.0001 if inv == 0 else 0.0)

        rows.append({
            "Part":           p,
            "Days_Coverage":  round(days_cov, 2),
            "Inv_Now":        round(inv, 0),
            "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
            "Daily_Indent":   round(daily, 2),
            "Today_Target":   round(target, 0),
            "Sort_Key":       sort_key,
            "Zero_Inv":       "YES" if inv == 0 else "No",
        })

    return (pd.DataFrame(rows)
              .sort_values("Sort_Key", ascending=False)
              .drop(columns=["Sort_Key"])
              .reset_index(drop=True))

# =============================================================
# SECTION 13 — MACHINE RANKER
# =============================================================

def rank_machines(part, machines, compatibility, machine_hours,
                  machine_last_part, changeover_dict, inv_days):
    category    = part_category.get(part, "Stranger")
    is_runner   = (category == "Runner")
    runner_lock = is_runner and inv_days <= 1.0

    ranked = []
    for m in machines:
        if m not in compatibility.get(part, []):
            continue
        used = machine_hours.get(m, 0)
        free = AVAILABLE_HOURS - used
        if free < MIN_RUN_HOURS:
            continue
        last   = machine_last_part.get(m)
        if runner_lock and last != part:
            continue
        co_hrs = 0.0 if last == part else changeover_dict.get(m, DEFAULT_CHANGEOVER_HRS)
        effective_free = free - co_hrs
        if effective_free < MIN_RUN_HOURS:
            continue
        cost = co_hrs / AVAILABLE_HOURS + (used / AVAILABLE_HOURS)
        ranked.append((m, cost, effective_free, co_hrs))

    ranked.sort(key=lambda x: x[1])
    return ranked, runner_lock

# =============================================================
# SECTION 14 — SINGLE TOOL-CHANGER GLOBAL STAGGER
# -------------------------------------------------------------
# There is ONE tool changer shared across ALL VT machines.
# No two changeovers can overlap anywhere in the VT section.
#
# Algorithm — runs in a single deterministic pass:
#
#   STEP 1 — COLLECT
#     Walk every machine's plan rows in sequence, computing each
#     CO's natural start time (= cumulative hrs before that row).
#     Build a flat list of all CO events across all 30 machines,
#     each carrying a reference to the plan row it belongs to.
#
#   STEP 2 — SORT & SERIALIZE (single pass, no iteration needed)
#     Sort all CO events by their natural start time.
#     Walk the sorted list and maintain tool_changer_free_at.
#     For each event:
#       • If natural_start >= tool_changer_free_at → no conflict,
#         accept as-is, update tool_changer_free_at.
#       • If natural_start < tool_changer_free_at → CONFLICT.
#         The CO must be DELAYED to tool_changer_free_at.
#         delay = tool_changer_free_at - natural_start
#         To push this CO later we extend the run of the part
#         BEFORE this CO on that machine by `delay` hours.
#         → extra_qty  = delay × rate   (free production gained)
#         → If machine has insufficient spare capacity for the
#           full delay, use only the available spare and flag
#           the remainder as unresolvable (rare edge case).
#
#   STEP 3 — PROPAGATE
#     After delaying a CO on machine M, all SUBSEQUENT COs on M
#     are also pushed by the same delay (their start times
#     shift forward too). The tool_changer_free_at advances
#     correctly because we process events in time order.
#
#   WHY EXTEND (not reduce)?
#     Delaying a CO means the part before it runs LONGER — we
#     gain production, never lose it. Reducing would lose qty.
#     The only constraint is the machine's 22h ceiling.
#
#   OUTPUT
#     - Plan rows updated in-place (Run_Hours, Production_Qty,
#       Total_Hrs_Used, Stagger_Adjusted).
#     - Printed log shows every CO event, its machine, natural
#       start, actual start, and delay applied.
#     - A summary table is printed at the end showing the final
#       serialized tool-changer queue.
# =============================================================

def stagger_changeovers(plan, machines, changeover_dict):
    print(f"\n  {'='*58}")
    print(f"  TOOL-CHANGER GLOBAL STAGGER  (single tool changer — all VT)")
    print(f"  {'='*58}")

    # ── STEP 1: collect all CO events across every machine ───
    def collect_co_events(plan, machines):
        """
        Build flat list of all CO events across all machines.
        Each event carries the plan row reference so we can
        modify Run_Hours / Production_Qty in-place.
        natural_start = cumulative hours on that machine before
                        the CO begins (ignoring any previous delays).
        """
        events = []
        for m in machines:
            m_rows = [r for r in plan if r["Machine"] == m]
            if len(m_rows) < 2:
                continue   # only one part on this machine → no CO
            cursor = 0.0
            for i, row in enumerate(m_rows):
                co_h  = float(row.get("Changeover_Hrs") or 0.0)
                run_h = float(row.get("Run_Hours")       or 0.0)
                if co_h > 0 and i > 0:
                    events.append({
                        "machine":       m,
                        "seq_on_machine": i,          # position in machine sequence
                        "part_before":   m_rows[i-1]["Part"],
                        "part_after":    row["Part"],
                        "co_duration":   co_h,
                        "natural_start": cursor,      # when CO would start without stagger
                        "actual_start":  cursor,      # will be updated in Step 2
                        "delay_applied": 0.0,         # hours of delay pushed onto prev run
                        "row_before":    m_rows[i-1], # plan row to extend if delayed
                        "row_after":     row,
                    })
                cursor += co_h + run_h
        # Sort by natural start time so the tool changer handles
        # earliest requests first — fair and deterministic.
        events.sort(key=lambda e: (e["natural_start"], e["machine"]))
        return events

    events = collect_co_events(plan, machines)

    if not events:
        print("  No changeovers found in plan — tool changer is idle all shift  ✓")
        return

    print(f"  Total CO events across all VT machines: {len(events)}")
    print(f"\n  {'Machine':<18} {'Part Before':<22} {'Part After':<22} "
          f"{'CO Dur':>7} {'Natural':>8} {'Actual':>8} {'Delay':>7} {'Spare Used':>10}")
    print(f"  {'─'*18} {'─'*22} {'─'*22} {'─'*7} {'─'*8} {'─'*8} {'─'*7} {'─'*10}")

    # ── STEP 2: serialize — one pass, no iteration ───────────
    tool_changer_free_at = 0.0   # when the tool changer finishes its current job
    # Track cumulative delay per machine so subsequent COs on
    # the same machine are pushed forward correctly.
    machine_delay = {m: 0.0 for m in machines}

    for ev in events:
        m             = ev["machine"]
        co_h          = ev["co_duration"]
        row_before    = ev["row_before"]
        row_after     = ev["row_after"]

        # Natural start already accounts for previous delays on
        # this machine because we stored the row references and
        # updated Run_Hours in-place during previous iterations.
        # Recompute actual natural start from the (possibly already
        # extended) row_before run hours.
        # natural_start = sum of all (co_h + run_h) before this CO on m
        m_rows  = [r for r in plan if r["Machine"] == m]
        cursor  = 0.0
        for r in m_rows:
            if r is row_after:
                break
            cursor += float(r.get("Changeover_Hrs") or 0) + float(r.get("Run_Hours") or 0)
        natural_start = cursor   # time at which this CO would start right now

        if natural_start >= tool_changer_free_at:
            # ── No conflict — tool changer is free ───────────
            actual_start  = natural_start
            delay_applied = 0.0
        else:
            # ── Conflict — must delay this CO ────────────────
            # Extend the run of the part BEFORE this CO so the
            # CO shifts to tool_changer_free_at.
            delay_applied = tool_changer_free_at - natural_start

            # How much spare capacity does this machine have?
            total_used_now = sum(
                float(r.get("Changeover_Hrs") or 0) + float(r.get("Run_Hours") or 0)
                for r in m_rows
            )
            spare = AVAILABLE_HOURS - total_used_now

            if spare >= delay_applied - 0.001:
                # Full delay fits within 22h — extend row_before
                r_val     = rate.get(row_before["Part"], 1.0)
                extra_qty = round(delay_applied * r_val, 0)

                row_before["Run_Hours"]      = round(
                    float(row_before.get("Run_Hours") or 0) + delay_applied, 3)
                row_before["Production_Qty"] = round(
                    float(row_before.get("Production_Qty") or 0) + extra_qty, 0)
                row_before["Total_Hrs_Used"] = round(
                    float(row_before.get("Changeover_Hrs") or 0)
                    + float(row_before["Run_Hours"]), 3)
                row_before["Stagger_Adjusted"] = (
                    f"Extended +{round(delay_applied*60,1)}min "
                    f"(TC queue: tool changer busy until "
                    f"{round(tool_changer_free_at,3):.3f}h)")

                actual_start = tool_changer_free_at

            else:
                # ── Partial fit — machine at ceiling ─────────
                # Extend only as much as spare allows; flag remainder.
                usable_delay = max(spare, 0.0)
                shortfall    = delay_applied - usable_delay

                if usable_delay > 0:
                    r_val     = rate.get(row_before["Part"], 1.0)
                    extra_qty = round(usable_delay * r_val, 0)
                    row_before["Run_Hours"]      = round(
                        float(row_before.get("Run_Hours") or 0) + usable_delay, 3)
                    row_before["Production_Qty"] = round(
                        float(row_before.get("Production_Qty") or 0) + extra_qty, 0)
                    row_before["Total_Hrs_Used"] = round(
                        float(row_before.get("Changeover_Hrs") or 0)
                        + float(row_before["Run_Hours"]), 3)

                actual_start = natural_start + usable_delay
                row_before["Stagger_Adjusted"] = (
                    f"Extended +{round(usable_delay*60,1)}min  "
                    f"⚠ {round(shortfall*60,1)}min unresolvable "
                    f"(machine at 22h ceiling)")
                delay_applied = usable_delay   # actual delay achieved

        ev["actual_start"]  = actual_start
        ev["delay_applied"] = delay_applied

        # Advance tool changer free time
        tool_changer_free_at = actual_start + co_h

        # ── Print this event ──────────────────────────────────
        delay_str = (f"+{round(delay_applied*60,1)}min"
                     if delay_applied > 0.001 else "none")
        spare_str = (f"+{round(delay_applied * rate.get(ev['part_before'],1),0):.0f} pcs"
                     if delay_applied > 0.001 else "—")
        print(f"  {m:<18} {ev['part_before']:<22} {ev['part_after']:<22} "
              f"{round(co_h*60,1):>6.1f}m "
              f"{_fmt_h(natural_start):>8} "
              f"{_fmt_h(actual_start):>8} "
              f"{delay_str:>7} "
              f"{spare_str:>10}")

    # ── STEP 3: summary ───────────────────────────────────────
    total_delays   = sum(1 for e in events if e["delay_applied"] > 0.001)
    total_delay_h  = sum(e["delay_applied"] for e in events)
    unresolvable   = sum(1 for e in events
                         if "unresolvable" in str(e["row_before"].get("Stagger_Adjusted", "")))

    print(f"\n  {'─'*58}")
    print(f"  Tool-changer queue complete:")
    print(f"    Total CO events    : {len(events)}")
    print(f"    Events delayed     : {total_delays}")
    print(f"    Total delay time   : {round(total_delay_h*60,1)} min")
    print(f"    Unresolvable (22h) : {unresolvable}"
          + ("  ← review manually" if unresolvable else "  ✓"))
    print(f"    Tool changer free  : {_fmt_h(tool_changer_free_at)}  "
          f"(last CO ends at {_fmt_h(tool_changer_free_at)})")

    # Final serialized CO queue
    print(f"\n  Serialized tool-changer queue (final):")
    print(f"  {'#':<4} {'Machine':<18} {'Start':>8} {'End':>8} {'Part After':<22}")
    print(f"  {'─'*4} {'─'*18} {'─'*8} {'─'*8} {'─'*22}")
    for idx, ev in enumerate(events, 1):
        print(f"  {idx:<4} {ev['machine']:<18} "
              f"{_fmt_h(ev['actual_start']):>8} "
              f"{_fmt_h(ev['actual_start'] + ev['co_duration']):>8} "
              f"{ev['part_after']:<22}")
    print(f"  {'='*58}")


def _fmt_h(h):
    """Convert decimal hours to HH:MM string."""
    try:
        total_min = int(round(float(h) * 60))
        return f"{total_min // 60:02d}:{total_min % 60:02d}"
    except Exception:
        return "??"

# =============================================================
# SECTION 14B — 22-HOUR FILLER
# =============================================================

def fill_remaining_hours(plan, machine_hours, machine_last_part,
                         parts, compatibility, machines,
                         current_inventory, horizon_df):
    already_planned = {row["Part"] for row in plan}

    for m in machines:
        remaining = round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
        if remaining <= 0:
            continue

        on_machine = [row["Part"] for row in plan if row["Machine"] == m]

        # Option A — extend existing part: pick the one with highest daily_indent
        # (most critical part on this machine gets the extra time)
        best_part, best_daily = None, -1
        for p in on_machine:
            d = indent_daily.get(p, 0)
            if d > best_daily:
                best_daily, best_part = d, p

        if best_part and best_daily > 0:
            p         = best_part
            r_val     = rate.get(p, 1)
            extra_qty = round(remaining * r_val, 0)
            for row in plan:
                if row["Part"] == p and row["Machine"] == m:
                    row["Run_Hours"]      = round(row["Run_Hours"] + remaining, 2)
                    row["Production_Qty"] = round(row["Production_Qty"] + extra_qty, 0)
                    row["Total_Hrs_Used"] = round(
                        row.get("Total_Hrs_Used", row["Run_Hours"]) + remaining, 2)
                    row["Type"] = "Primary+Extended"
                    break
            machine_hours[m]    += remaining
            current_inventory[p] = current_inventory.get(p, 0) + extra_qty
            print(f"    ↑ {p:30s} → {m:15s}  +{remaining:.2f}h merged  "
                  f"qty+={extra_qty:.0f}  [EXTEND]")
            continue

        # Option B — add a new part (≥ MIN_RUN_HOURS required)
        if remaining < MIN_RUN_HOURS:
            continue

        candidates = []
        for p in parts:
            if p in already_planned:
                continue
            if m not in compatibility.get(p, []):
                continue
            daily   = indent_daily.get(p, 0)
            inv_now  = current_inventory.get(p, 0)
            # Skip if inventory already sufficient
            if inv_now >= daily > 0:
                continue
            candidates.append((p, daily))

        # Sort by daily_indent descending — biggest parts fill first
        candidates.sort(key=lambda x: -x[1])

        for p, daily_val in candidates:
            last    = machine_last_part.get(m)
            co_hrs  = 0.0 if last == p else vt_changeover.get(m, DEFAULT_CHANGEOVER_HRS)
            eff_run = remaining - co_hrs
            if eff_run < MIN_RUN_HOURS:
                continue
            r_val = rate.get(p, 1)
            qty   = round(eff_run * r_val, 0)
            machine_hours[m]    += (co_hrs + eff_run)
            current_inventory[p] = current_inventory.get(p, 0) + qty
            machine_last_part[m] = p
            already_planned.add(p)
            plan.append({
                "Part":             p,
                "Category":         part_category.get(p, "Stranger"),
                "Machine":          m,
                "Run_Hours":        round(eff_run, 2),
                "Changeover_Hrs":   round(co_hrs, 3),
                "Total_Hrs_Used":   round(co_hrs + eff_run, 2),
                "Rate_Per_Hour":    round(r_val, 2),
                "Production_Qty":   qty,
                "Monthly_Indent":   round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":     round(indent_daily.get(p, 0), 2),
                "Today_Target":     round(today_target_qty.get(p, 0), 0),
                "Changeover":       "No" if co_hrs == 0 else "Yes",
                "Type":             "New — filler",
                "Runner_Lock":      "No",
                "Priority_Score":   0,
                "Stagger_Adjusted": "No",
            })
            print(f"    + {p:30s} → {m:15s}  {eff_run:.2f}h  qty={qty:.0f}  "
                  f"[Filler]  CO={'Yes' if co_hrs > 0 else 'No'}")
            break

# =============================================================
# SECTION 15 — MAIN SCHEDULER
# =============================================================

def schedule(parts, compatibility, machines, changeover_dict, label=""):

    print(f"\n{'─'*62}")
    print(f"  {label}  |  {len(parts)} parts  |  {len(machines)} machines")
    print(f"{'─'*62}")

    scenario, scenario_desc = classify_scenario(parts)
    print(f"  {scenario_desc}")

    horizon_df = compute_indent_horizon(parts)

    # Print what needs production
    prod_needed = horizon_df[
        horizon_df["Indent_Status"].isin(["PRODUCTION NEEDED", "ZERO INV — FORCED"])
    ]
    if not prod_needed.empty:
        print(f"\n  Parts requiring production today ({len(prod_needed)}):")
        print(f"  {'Part':<30}  {'Monthly':>8}  {'Daily':>7}  {'Inv':>8}  "
              f"{'Target':>8}  {'Status'}")
        print(f"  {'─'*30}  {'─'*8}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*20}")
        for _, r in prod_needed.iterrows():
            print(f"  {r['Part']:<30}  "
                  f"{r['Monthly_Indent']:>8.0f}  "
                  f"{r['Daily_Indent']:>7.2f}  "
                  f"{r['Inventory_Now']:>8.0f}  "
                  f"{r['Today_Target_Qty']:>8.0f}  "
                  f"{r['Indent_Status']}")
    else:
        print("  No production needed — inventory covers all active parts today")

    machine_hours     = {m: 0.0 for m in machines}
    machine_last_part = {m: machine_state.get(m) for m in machines}
    current_inventory = inventory.copy()

    plan, deferred, not_planned, skipped_log = [], [], [], []

    # Active parts = not skipped OR zero-inventory (always forced)
    # Inventory-sufficient parts are excluded here — not in priority list at all.
    active_parts = [
        p for p in parts
        if (not should_skip(p)[0] or inventory.get(p, 0) == 0)
        and indent_monthly.get(p, 0) > 0
        and not (inventory.get(p, 0) >= indent_daily.get(p, 0) > 0)
    ]

    priority_df = compute_priority(active_parts, horizon_df)

    print(f"\n  Priority order — sorted by daily_indent descending "
          f"({len(priority_df)} active parts):")
    print(f"  {'Part':<30}  {'Daily':>7}  {'Inv':>8}  {'Target':>8}  {'Zero_Inv':>8}")
    print(f"  {'─'*30}  {'─'*7}  {'─'*8}  {'─'*8}  {'─'*8}")
    for _, r in priority_df.iterrows():
        print(f"  {r['Part']:<30}  "
              f"{r['Daily_Indent']:>7.2f}  "
              f"{r['Inv_Now']:>8.0f}  "
              f"{r['Today_Target']:>8.0f}  "
              f"{r['Zero_Inv']:>8}")

    runner_dedicated_machines = set()

    # ── Log skipped parts (not zero-inv) ─────────────────────
    for p in parts:
        skip, reason = should_skip(p)
        inv_now = inventory.get(p, 0)
        if skip and inv_now > 0:
            skipped_log.append({
                "Part":           p,
                "Category":       part_category.get(p, "Stranger"),
                "Monthly_Indent": round(indent_monthly.get(p, 0), 0),
                "Daily_Indent":   round(indent_daily.get(p, 0), 2),
                "Inventory_Now":  round(inv_now, 0),
                "Skip_Reason":    reason,
            })

    def run_assignment(parts_subset, pass_label, exclude_machines=None):
        if exclude_machines is None:
            exclude_machines = set()
        print(f"\n  {pass_label}:")

        for _, row in priority_df[priority_df["Part"].isin(parts_subset)].iterrows():
            part     = row["Part"]

            if any(r["Part"] == part for r in plan):
                print(f"    ~ {part:30s}  ALREADY PLANNED — skipped")
                continue

            inv_now  = current_inventory.get(part, 0)
            daily    = indent_daily.get(part, 0)
            monthly  = indent_monthly.get(part, 0)
            r_val    = rate.get(part, 1)
            category = part_category.get(part, "Stranger")
            inv_days = inv_now / daily if daily > 0 else 999
            target   = today_target_qty.get(part, 0)

            compatible_mch = compatibility.get(part, [])

            # ── Zero indent ───────────────────────────────────
            if monthly == 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": 0,
                    "Daily_Indent":   0,
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Monthly indent is zero",
                    "Next_Action":    "Re-evaluate when indent is set",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED — indent = 0")
                continue

            # ── Inventory sufficient (and not zero-inv forced) ─
            if target == 0 and inv_now > 0:
                deferred.append({
                    "Part":           part,
                    "Category":       category,
                    "Inventory_Now":  round(inv_now, 0),
                    "Monthly_Indent": round(monthly, 0),
                    "Daily_Indent":   round(daily, 2),
                    "Today_Target":   0,
                    "Days_Coverage":  round(inv_days, 2),
                    "Reason":         "Inventory covers daily indent — no production needed",
                    "Next_Action":    "Re-evaluate tomorrow",
                })
                print(f"    - {part:30s} [{category:8s}]  DEFERRED  "
                      f"inv={inv_now:.0f} ≥ daily={daily:.2f}")
                continue

            # ── Target hours ──────────────────────────────────
            # For zero-inventory forced parts: use daily_indent as minimum
            # run target so we at least build one day's worth.
            effective_target = max(target, daily) if inv_now == 0 else target

            if category == "Runner":
                target_hrs = min(
                    (effective_target / r_val if r_val > 0 else MIN_RUN_HOURS)
                    + (daily / r_val if r_val > 0 else 0),
                    AVAILABLE_HOURS
                )
                target_hrs = max(target_hrs, MIN_RUN_HOURS)
            else:
                target_hrs = max(
                    MIN_RUN_HOURS,
                    effective_target / r_val if r_val > 0 else MIN_RUN_HOURS
                )

            # ── No compatible machines ────────────────────────
            if not compatible_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": "NONE DEFINED",
                    "Reason":              "Part has no compatible machines in VT matrix",
                    "Action_Needed":       "Add part to VT_Matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — not in matrix")
                continue

            available_mch = [m for m in compatible_mch if m not in exclude_machines]
            if not available_mch:
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              "All compatible machines dedicated to Runners",
                    "Action_Needed":       "Add more compatible machines in matrix",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — machines Runner-dedicated")
                continue

            ranked, runner_lock = rank_machines(
                part, available_mch, compatibility,
                machine_hours, machine_last_part,
                changeover_dict, inv_days
            )

            if not ranked:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                if runner_lock:
                    last_m = next(
                        (m for m in available_mch if machine_last_part.get(m) == part), None)
                    free_l = round(AVAILABLE_HOURS - machine_hours.get(last_m, 0), 2) if last_m else 0
                    reason = (f"RUNNER (inv≤1d) — must stay on {last_m}, "
                              f"only {free_l}h free") if last_m else \
                             "RUNNER — no machine state (first run)"
                    action = f"Free capacity on {last_m}" if last_m else \
                             "Machine state saves after this run"
                elif all(h < MIN_RUN_HOURS for h in free_map.values()):
                    reason = ("All compatible machines full. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Reduce lower-priority part hours or plan tomorrow"
                else:
                    reason = ("Remaining hrs < MIN after changeover. Free: "
                              + ", ".join(f"{m}={h}h" for m, h in free_map.items()))
                    action = "Check Inventory_Health sheet"

                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              reason,
                    "Action_Needed":       action,
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — {reason[:60]}")
                continue

            # ── Assign ────────────────────────────────────────
            assigned = False
            for m, cost, effective_free, co_hrs in ranked:
                run_h = min(target_hrs, effective_free)
                run_h = max(run_h, MIN_RUN_HOURS)
                run_h = min(run_h, effective_free)
                qty   = round(run_h * r_val, 0)

                machine_hours[m]        += (co_hrs + run_h)
                current_inventory[part]  = current_inventory.get(part, 0) + qty
                machine_last_part[m]     = part

                if category == "Runner":
                    runner_dedicated_machines.add(m)

                forced_tag = "ZERO-INV-FORCED" if inv_now == 0 else "Primary"
                plan.append({
                    "Part":              part,
                    "Category":          category,
                    "Machine":           m,
                    "Run_Hours":         round(run_h, 2),
                    "Changeover_Hrs":    round(co_hrs, 3),
                    "Total_Hrs_Used":    round(co_hrs + run_h, 2),
                    "Rate_Per_Hour":     round(r_val, 2),
                    "Production_Qty":    qty,
                    "Monthly_Indent":    round(monthly, 0),
                    "Daily_Indent":      round(daily, 2),
                    "Today_Target":      round(target, 0),
                    "Changeover":        "No" if co_hrs == 0 else "Yes",
                    "Type":              forced_tag,
                    "Runner_Lock":       "YES" if runner_lock else "No",
                    "Priority_Score":    round(indent_daily.get(part, 0), 2),
                    "Stagger_Adjusted":  "No",
                })
                co_str = "No" if co_hrs == 0 else f"Yes ({co_hrs*60:.0f}min)"
                tag    = "  [DEDICATED]" if category == "Runner" else \
                         "  [ZERO-INV FORCED]" if inv_now == 0 else ""
                print(f"    ✓ {part:30s} [{category:8s}] → {m:15s}  "
                      f"{run_h:.2f}h  qty={qty:>8.0f}  CO={co_str}{tag}")
                assigned = True
                break

            if not assigned:
                free_map = {m: round(AVAILABLE_HOURS - machine_hours.get(m, 0), 2)
                            for m in available_mch if m in machine_hours}
                not_planned.append({
                    "Part":                part,
                    "Category":            category,
                    "Monthly_Indent":      round(monthly, 0),
                    "Daily_Indent":        round(daily, 2),
                    "Inventory_Now":       round(inv_now, 0),
                    "Inv_Days_Coverage":   round(inv_days, 2),
                    "Today_Target":        round(target, 0),
                    "Compatible_Machines": ", ".join(compatible_mch),
                    "Reason":              (
                        f"No single machine has {round(target_hrs,2)}h free after CO. "
                        + "Free: " + ", ".join(f"{m}={h}h" for m, h in free_map.items())
                    ),
                    "Action_Needed": "Reduce lower-priority hours or verify inventory covers gap",
                })
                print(f"    ✗ {part:30s} [{category:8s}]  NOT PLANNED — "
                      f"no machine has {round(target_hrs,2)}h free")

    # PASS 1 — Runners
    runner_parts     = [p for p in parts
                        if part_category.get(p, "Stranger") == "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]
    non_runner_parts = [p for p in parts
                        if part_category.get(p, "Stranger") != "Runner"
                        and (not should_skip(p)[0] or inventory.get(p, 0) == 0)]

    run_assignment(runner_parts,
                   "PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer)")
    print(f"\n  Runner-dedicated machines: "
          f"{sorted(runner_dedicated_machines) if runner_dedicated_machines else 'none'}")

    # PASS 2 — Repeaters + Strangers
    run_assignment(non_runner_parts,
                   "PASS 2 — Repeaters + Strangers (Runner machines excluded)",
                   exclude_machines=runner_dedicated_machines)

    # 22-hour filler
    print(f"\n  22-hour filler:")
    fill_remaining_hours(
        plan, machine_hours, machine_last_part,
        list(parts), compatibility, machines,
        current_inventory, horizon_df
    )

    # Duplicate check
    part_counts = {}
    for row in plan:
        part_counts[row["Part"]] = part_counts.get(row["Part"], 0) + 1
    dupes = {p: c for p, c in part_counts.items() if c > 1}
    if dupes:
        print(f"  WARNING: duplicate parts: {dupes}")
    else:
        print(f"    No duplicate parts — each part appears exactly once  ✓")

    # Stagger
    stagger_changeovers(plan, machines, changeover_dict)

    # ── Inventory health ──────────────────────────────────────
    inv_rows = []
    for p in parts:
        inv_b    = inventory.get(p, 0)
        daily    = indent_daily.get(p, 0)
        monthly  = indent_monthly.get(p, 0)
        produced = sum(r["Production_Qty"] for r in plan if r["Part"] == p)
        inv_after = inv_b + produced
        days_cov  = inv_after / daily if daily > 0 else 0
        inv_rows.append({
            "Part":            p,
            "Monthly_Indent":  round(monthly, 0),
            "Daily_Indent":    round(daily, 2),
            "Inv_Before":      round(inv_b, 0),
            "Produced_Today":  round(produced, 0),
            "Inv_After_Today": round(inv_after, 0),
            "Days_Coverage":   round(days_cov, 2),
            "Status":          ("OK"       if days_cov >= TARGET_DAYS_INV
                                else "LOW"      if days_cov >= 1
                                else "CRITICAL"),
        })

    # ── Machine utilization ───────────────────────────────────
    mach_rows = []
    for m in machines:
        used      = machine_hours.get(m, 0)
        parts_run = [r["Part"] for r in plan if r["Machine"] == m]
        co_count  = sum(1 for r in plan if r["Machine"] == m and r.get("Changeover") == "Yes")
        util_pct  = round(used / AVAILABLE_HOURS * 100, 1)
        util_status = ("FULL"     if used >= AVAILABLE_HOURS - 0.5 else
                       "GOOD"     if used >= AVAILABLE_HOURS * 0.85 else
                       "PARTIAL"  if used >= AVAILABLE_HOURS * 0.5 else
                       "UNDERUSED")
        mach_rows.append({
            "Machine":              m,
            "Total_Available_Hrs":  AVAILABLE_HOURS,
            "Used_Hours":           round(used, 2),
            "Unused_Hours":         round(AVAILABLE_HOURS - used, 2),
            "Utilization_%":        util_pct,
            "Status":               util_status,
            "Parts_Planned":        len(parts_run),
            "Changeovers":          co_count,
            "Last_Part_Run":        machine_last_part.get(m) or "—",
            "All_Parts_On_Machine": ", ".join(parts_run) if parts_run else "— idle —",
        })

    plan_df     = pd.DataFrame(plan)         if plan         else pd.DataFrame()
    def_df      = pd.DataFrame(deferred)     if deferred     else pd.DataFrame()
    not_df      = pd.DataFrame(not_planned)  if not_planned  else pd.DataFrame()
    skip_df     = pd.DataFrame(skipped_log)  if skipped_log  else pd.DataFrame()
    mach_df     = pd.DataFrame(mach_rows)
    inv_df      = pd.DataFrame(inv_rows)

    if not plan_df.empty:
        plan_df["Category"] = plan_df["Part"].map(
            lambda p: part_category.get(p, "Stranger"))
        plan_df.insert(0, "Planning_Date", str(PLANNING_DATE))
        plan_df.insert(1, "Scenario",      scenario_desc)
        plan_df.insert(2, "Working_Days",  WORKING_DAYS)

    return plan_df, def_df, not_df, skip_df, mach_df, inv_df, machine_last_part, horizon_df

# =============================================================
# SECTION 16 — RUN VT SCHEDULER
# =============================================================

vt_parts = data_valid[
    data_valid["Material"].isin(vt_matrix["Part"])
]["Material"].unique()

# =============================================================
# SECTION 16A — FULL PART AUDIT  (accounts for all VT parts)
# -------------------------------------------------------------
# Every part in the VT sheet is traced through every filter gate.
# Since VT sheet is now the single source of truth, gates are:
#
# GATE 1 — Cycle time / Cavity valid
#   Both must be present and non-zero to compute a rate.
#   Missing/zero → "Zero or missing Cycle time or Cavity in VT sheet"
#
# GATE 2 — In VT_Matrix
#   Part must appear in VT_Matrix with ≥1 machine assigned.
#   Missing → "Not in VT_Matrix — no compatible machine assigned"
#
# GATE 3 — Indent present
#   Monthly indent must be > 0.
#   Missing/zero → "Zero or missing Indent in VT sheet"
#
# GATE 4 — Skip rules  (bypassed when inventory = 0)
#   indent < 150  OR  indent / rate ≤ 4h → "Skipped"
#
# GATE 5 — Inventory sufficient
#   inventory ≥ daily_indent → "Not required today"
#
# PASSES ALL GATES → "ENTERS SCHEDULER"
#   Scheduler then decides: Planned / Not Planned (capacity)
# =============================================================

print(f"\n{'='*70}")
print(f"  PART AUDIT — tracing all {len(data)} VT parts through every filter gate")
print(f"{'='*70}")

# All parts from VT sheet (including those with missing rate)
all_vt_parts_raw = list(data["Material"].unique())
matrix_parts     = set(str(p).strip() for p in vt_matrix["Part"] if pd.notna(p))
zero_rate_set    = set(data_zero_rate["Material"].unique())

audit_rows = []

for part in all_vt_parts_raw:
    inv     = inventory.get(part, 0.0)
    r_val   = rate.get(part, None)        # None if rate not computable
    monthly = indent_monthly.get(part, 0.0)
    daily   = indent_daily.get(part, 0.0)

    # Retrieve raw cycle time and cavity for display
    row_data = data[data["Material"] == part]
    ct_raw   = row_data[vt_col_cycletime].values[0] if len(row_data) else "—"
    cv_raw   = row_data[vt_col_cavity].values[0]    if len(row_data) else "—"

    # ── GATE 1: cycle time valid? ─────────────────────────────
    # Cavity no longer affects rate (cavities cancel in formula).
    # Only cycle time must be present and non-zero.
    if part in zero_rate_set or r_val is None:
        audit_rows.append({
            "Part":           part,
            "Gate_Failed":    "GATE 1",
            "Reason":         (
                f"Cycle time={ct_raw} — zero or missing in VT sheet "
                f"→ rate cannot be computed  (Cavity={cv_raw} — not used in rate)"
            ),
            "Monthly_Indent": round(monthly, 0),
            "Daily_Indent":   round(daily, 2),
            "Inventory":      round(inv, 0),
            "Rate_Per_Hr":    "—",
            "Cycle_Time":     ct_raw,
            "Cavity":         cv_raw,
            "Status":         "ZERO/MISSING CYCLE TIME",
        })
        continue

    # ── GATE 2: in VT_Matrix? ─────────────────────────────────
    if part not in matrix_parts:
        audit_rows.append({
            "Part":           part,
            "Gate_Failed":    "GATE 2",
            "Reason":         "Part not in VT_Matrix — no compatible machine assigned",
            "Monthly_Indent": round(monthly, 0),
            "Daily_Indent":   round(daily, 2),
            "Inventory":      round(inv, 0),
            "Rate_Per_Hr":    round(r_val, 2),
            "Cycle_Time":     ct_raw,
            "Cavity":         cv_raw,
            "Status":         "NOT IN VT_MATRIX",
        })
        continue

    # ── GATE 3: indent present? ───────────────────────────────
    if monthly == 0:
        audit_rows.append({
            "Part":           part,
            "Gate_Failed":    "GATE 3",
            "Reason":         "Monthly indent is zero or blank in VT sheet",
            "Monthly_Indent": 0,
            "Daily_Indent":   0,
            "Inventory":      round(inv, 0),
            "Rate_Per_Hr":    round(r_val, 2),
            "Cycle_Time":     ct_raw,
            "Cavity":         cv_raw,
            "Status":         "ZERO/MISSING INDENT",
        })
        continue

    # ── GATE 4: skip rules (bypassed when inv = 0) ───────────
    skip, skip_reason = should_skip(part)
    if skip and inv > 0:
        audit_rows.append({
            "Part":           part,
            "Gate_Failed":    "GATE 4",
            "Reason":         skip_reason,
            "Monthly_Indent": round(monthly, 0),
            "Daily_Indent":   round(daily, 2),
            "Inventory":      round(inv, 0),
            "Rate_Per_Hr":    round(r_val, 2),
            "Cycle_Time":     ct_raw,
            "Cavity":         cv_raw,
            "Status":         "SKIPPED (LOW INDENT / TRIVIAL RUN)",
        })
        continue

    # ── GATE 5: inventory sufficient? ────────────────────────
    if daily > 0 and inv >= daily:
        audit_rows.append({
            "Part":           part,
            "Gate_Failed":    "GATE 5",
            "Reason":         (
                f"Inventory ({round(inv,0):.0f}) >= "
                f"daily_indent ({round(daily,2):.2f}) — no production needed today"
            ),
            "Monthly_Indent": round(monthly, 0),
            "Daily_Indent":   round(daily, 2),
            "Inventory":      round(inv, 0),
            "Rate_Per_Hr":    round(r_val, 2),
            "Cycle_Time":     ct_raw,
            "Cavity":         cv_raw,
            "Status":         "NOT REQUIRED — INV SUFFICIENT",
        })
        continue

    # ── PASSED ALL GATES ─────────────────────────────────────
    audit_rows.append({
        "Part":           part,
        "Gate_Failed":    "—",
        "Reason":         "Passed all gates — enters scheduler",
        "Monthly_Indent": round(monthly, 0),
        "Daily_Indent":   round(daily, 2),
        "Inventory":      round(inv, 0),
        "Rate_Per_Hr":    round(r_val, 2),
        "Cycle_Time":     ct_raw,
        "Cavity":         cv_raw,
        "Status":         "ENTERS SCHEDULER",
    })

audit_df = pd.DataFrame(audit_rows)

# ── Print gate-level summary ──────────────────────────────────
gate_counts = audit_df["Status"].value_counts()
print(f"\n  Gate breakdown ({len(all_vt_parts_raw)} total parts):")
for status, count in gate_counts.items():
    marker = "✓" if status == "ENTERS SCHEDULER" else "✗"
    print(f"    {marker}  {status:<42} : {count:>4} parts")

# ── Print each dropped part with reason ──────────────────────
non_planned_audit = audit_df[audit_df["Gate_Failed"] != "—"]
if not non_planned_audit.empty:
    print(f"\n  Detail — {len(non_planned_audit)} parts dropped before scheduler:")
    print(f"  {'Part':<30}  {'Gate':<8}  {'Reason'}")
    print(f"  {'─'*30}  {'─'*8}  {'─'*55}")
    for _, r in non_planned_audit.sort_values("Gate_Failed").iterrows():
        print(f"  {r['Part']:<30}  {r['Gate_Failed']:<8}  {str(r['Reason'])[:55]}")

print(f"{'='*70}\n")

(vt_plan, vt_def, vt_not, vt_skip,
 vt_mach, vt_inv, vt_state, vt_horizon) = schedule(
    vt_parts, vt_compat, vt_machines, vt_changeover, "VT Machines"
)

save_machine_state(vt_state)

# =============================================================
# SECTION 17 — SAVE OUTPUT
# =============================================================

from openpyxl import load_workbook
from openpyxl.styles import PatternFill, Font, Alignment
from openpyxl.utils import get_column_letter

HEADER_COLORS = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
    "VT_Part_Audit":         "1C3557",
}

STATUS_FILLS = {
    "FULL":                              PatternFill("solid", fgColor="C6EFCE"),
    "GOOD":                              PatternFill("solid", fgColor="DDEBF7"),
    "PARTIAL":                           PatternFill("solid", fgColor="FFEB9C"),
    "UNDERUSED":                         PatternFill("solid", fgColor="FFC7CE"),
    "OK":                                PatternFill("solid", fgColor="C6EFCE"),
    "LOW":                               PatternFill("solid", fgColor="FFEB9C"),
    "CRITICAL":                          PatternFill("solid", fgColor="FFC7CE"),
    "PRODUCTION NEEDED":                 PatternFill("solid", fgColor="FFC7CE"),
    "ZERO INV — FORCED":                 PatternFill("solid", fgColor="FFD7D7"),
    "INV SUFFICIENT":                    PatternFill("solid", fgColor="C6EFCE"),
    "SKIPPED":                           PatternFill("solid", fgColor="EDEDED"),
    "NO INDENT":                         PatternFill("solid", fgColor="EDEDED"),
    # Audit statuses
    "ENTERS SCHEDULER":                  PatternFill("solid", fgColor="C6EFCE"),
    "NOT REQUIRED — INV SUFFICIENT":     PatternFill("solid", fgColor="DDEBF7"),
    "SKIPPED (LOW INDENT / TRIVIAL RUN)":PatternFill("solid", fgColor="EDEDED"),
    "ZERO/MISSING CYCLE TIME":           PatternFill("solid", fgColor="FFC7CE"),
    "ZERO/MISSING CYCLE TIME OR CAVITY": PatternFill("solid", fgColor="FFC7CE"),  # legacy
    "NOT IN VT_MATRIX":                  PatternFill("solid", fgColor="FFEB9C"),
    "ZERO/MISSING INDENT":               PatternFill("solid", fgColor="FFEB9C"),
}

def style_sheet(ws, header_hex):
    hf = PatternFill("solid", fgColor=header_hex)
    for cell in ws[1]:
        cell.fill      = PatternFill("solid", fgColor=header_hex)
        cell.font      = Font(bold=True, color="FFFFFF", size=11)
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 32
    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value is not None), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(50, max_len + 3))
    headers = [cell.value for cell in ws[1]]
    for col_idx, col_name in enumerate(headers, start=1):
        if col_name and ("Status" in str(col_name) or "Indent_Status" in str(col_name)):
            for row in ws.iter_rows(min_row=2, min_col=col_idx, max_col=col_idx):
                for cell in row:
                    fill = STATUS_FILLS.get(str(cell.value))
                    if fill:
                        cell.fill = fill
    ws.freeze_panes = "A2"


def build_machine_wise_plan(plan_df, machines):
    """
    Build the machine-wise sequenced plan with Rate_Per_Hour column included.
    One row per part per machine, plus a summary footer row per machine.
    """
    if plan_df.empty:
        return pd.DataFrame()

    def safe_float(val, default=0.0):
        try:
            v = float(val)
            return v if not np.isnan(v) else default
        except (TypeError, ValueError):
            return default

    # Use the global _fmt_h helper (defined alongside stagger_changeovers)
    fmt_time = _fmt_h

    rows = []
    for m in machines:
        machine_rows = plan_df[plan_df["Machine"] == m].copy()
        if machine_rows.empty:
            continue

        cumulative_hrs = 0.0
        seq            = 1

        for _, pr in machine_rows.iterrows():
            part    = pr.get("Part", "—")
            run_h   = safe_float(pr.get("Run_Hours", 0))
            co_h    = safe_float(pr.get("Changeover_Hrs", 0))
            r_val   = safe_float(pr.get("Rate_Per_Hour", 0))
            co_mins = round(co_h * 60, 1)
            start_h = cumulative_hrs + co_h
            end_h   = start_h + run_h

            rows.append({
                "Machine":                m,
                "Seq":                    seq,
                "Part":                   part,
                "Category":               part_category.get(part, "Stranger"),
                "Rate_Per_Hour":          round(r_val, 2),          # ← added
                "Changeover_Before_Mins": co_mins,
                "Run_Hours":              round(run_h, 2),
                "Start_Time":             fmt_time(cumulative_hrs),
                "Start_After_CO":         fmt_time(start_h),
                "End_Time":               fmt_time(end_h),
                "Cumulative_Hrs":         round(end_h, 2),
                "Production_Qty":         safe_float(pr.get("Production_Qty", 0)),
                "Monthly_Indent":         safe_float(pr.get("Monthly_Indent", 0)),
                "Daily_Indent":           safe_float(pr.get("Daily_Indent", 0)),
                "Today_Target":           safe_float(pr.get("Today_Target", 0)),
                "Changeover":             pr.get("Changeover", "No") or "No",
                "Type":                   pr.get("Type", "Primary") or "Primary",
                "Runner_Lock":            pr.get("Runner_Lock", "No") or "No",
                "Row_Type":               "Part",
            })
            cumulative_hrs = end_h
            seq           += 1

        # Summary footer
        total_used     = round(cumulative_hrs, 2)
        co_hrs_series  = machine_rows["Changeover_Hrs"].apply(lambda x: safe_float(x, 0))
        total_co_mins  = round(co_hrs_series.sum() * 60, 1)
        total_prod_hrs = round(total_used - co_hrs_series.sum(), 2)
        total_qty      = machine_rows["Production_Qty"].apply(lambda x: safe_float(x, 0)).sum()
        co_count       = int(machine_rows["Changeover"].eq("Yes").sum())

        rows.append({
            "Machine":                m,
            "Seq":                    "—",
            "Part":                   f"TOTAL — {m}",
            "Category":               "—",
            "Rate_Per_Hour":          "—",
            "Changeover_Before_Mins": total_co_mins,
            "Run_Hours":              total_prod_hrs,
            "Start_Time":             "00:00",
            "Start_After_CO":         "—",
            "End_Time":               fmt_time(total_used),
            "Cumulative_Hrs":         total_used,
            "Production_Qty":         round(total_qty, 0),
            "Monthly_Indent":         "—",
            "Daily_Indent":           "—",
            "Today_Target":           "—",
            "Changeover":             f"{co_count} changeovers",
            "Type":                   f"Used {total_used}h / {AVAILABLE_HOURS}h  |  Unused {round(AVAILABLE_HOURS-total_used,2)}h",
            "Runner_Lock":            "—",
            "Row_Type":               "Summary",
        })
        rows.append({k: "" for k in rows[-1].keys()})

    return pd.DataFrame(rows)


def style_machine_wise_sheet(ws):
    header_fill  = PatternFill("solid", fgColor="1F4E79")
    header_font  = Font(bold=True, color="FFFFFF", size=11)
    summary_fill = PatternFill("solid", fgColor="0D9488")
    summary_font = Font(bold=True, color="FFFFFF", size=11)
    part_fills   = [
        PatternFill("solid", fgColor="EFF6FF"),
        PatternFill("solid", fgColor="F0FDF4"),
    ]
    co_fill = PatternFill("solid", fgColor="FEF9C3")

    for cell in ws[1]:
        cell.fill      = header_fill
        cell.font      = header_font
        cell.alignment = Alignment(horizontal="center", vertical="center", wrap_text=True)
    ws.row_dimensions[1].height = 30

    headers      = [cell.value for cell in ws[1]]
    row_type_col = headers.index("Row_Type")  + 1 if "Row_Type"  in headers else None
    co_col       = headers.index("Changeover") + 1 if "Changeover" in headers else None
    machine_col  = headers.index("Machine")   + 1 if "Machine"   in headers else None

    machine_color_idx = 0
    current_machine   = None

    for row in ws.iter_rows(min_row=2):
        row_type = row[row_type_col - 1].value if row_type_col else ""
        machine  = row[machine_col  - 1].value if machine_col  else ""
        if machine and machine != current_machine:
            current_machine   = machine
            machine_color_idx = (machine_color_idx + 1) % 2
        if row_type == "Summary":
            for cell in row:
                cell.fill = summary_fill
                cell.font = summary_font
                cell.alignment = Alignment(horizontal="center", vertical="center")
        elif row_type == "Part":
            bg = part_fills[machine_color_idx]
            for cell in row:
                cell.fill      = bg
                cell.alignment = Alignment(vertical="center")
            if co_col and row[co_col - 1].value == "Yes":
                row[co_col - 1].fill = co_fill

    for col in ws.columns:
        col_letter = get_column_letter(col[0].column)
        max_len    = max((len(str(c.value)) for c in col if c.value), default=8)
        ws.column_dimensions[col_letter].width = max(10, min(40, max_len + 3))
    ws.freeze_panes = "C2"


# =============================================================
# SECTION 17A — WRITE EXCEL
# =============================================================

print(f"\nWriting → {output_path}")

vt_mw = build_machine_wise_plan(vt_plan, vt_machines)

with pd.ExcelWriter(output_path, engine="openpyxl") as writer:
    vt_mw.to_excel(writer,      sheet_name="VT_Plan_By_Machine",    index=False)
    vt_plan.to_excel(writer,    sheet_name="VT_Plan",               index=False)
    vt_mach.to_excel(writer,    sheet_name="VT_Machine_Util",       index=False)
    vt_not.to_excel(writer,     sheet_name="VT_Not_Planned",        index=False)
    vt_def.to_excel(writer,     sheet_name="VT_Not_Required_Today", index=False)
    vt_skip.to_excel(writer,    sheet_name="VT_Skipped_Parts",      index=False)
    vt_inv.to_excel(writer,     sheet_name="VT_Inventory_Health",   index=False)
    vt_horizon.to_excel(writer, sheet_name="VT_Indent_Horizon",     index=False)
    audit_df.to_excel(writer,   sheet_name="VT_Part_Audit",         index=False)

wb = load_workbook(output_path)

if "VT_Plan_By_Machine" in wb.sheetnames:
    style_machine_wise_sheet(wb["VT_Plan_By_Machine"])

for sheet_name, header_hex in HEADER_COLORS.items():
    if sheet_name in wb.sheetnames and sheet_name != "VT_Plan_By_Machine":
        style_sheet(wb[sheet_name], header_hex)

tab_colors = {
    "VT_Plan_By_Machine":    "0D6E6E",
    "VT_Plan":               "1F4E79",
    "VT_Machine_Util":       "375623",
    "VT_Not_Planned":        "7B2C2C",
    "VT_Not_Required_Today": "7F6000",
    "VT_Skipped_Parts":      "5C3D2E",
    "VT_Inventory_Health":   "4A235A",
    "VT_Indent_Horizon":     "154360",
    "VT_Part_Audit":         "1C3557",
}
for name, color in tab_colors.items():
    if name in wb.sheetnames:
        wb[name].sheet_properties.tabColor = color

wb.save(output_path)
print(f"  Formatting applied  ✓")

# =============================================================
# SECTION 18 — SUMMARY PRINT
# =============================================================

print(f"\n{'='*62}")
print(f"  Smart APS V6 Complete  —  VT Only  —  {PLANNING_DATE}")
print(f"  Indent month  : {INDENT_MONTH.strftime('%B %Y')}")
print(f"  Working days  : {WORKING_DAYS}  ({TOTAL_DAYS} days − {SUNDAY_COUNT} Sundays)")
print(f"{'='*62}")
print(f"  Total parts in VT sheet    : {len(all_vt_parts_raw)}")
print(f"  ─────────────────────────────────────────────────────")
for status, count in audit_df["Status"].value_counts().items():
    marker = "✓" if status == "ENTERS SCHEDULER" else "·"
    print(f"  {marker} {status:<42}: {count:>4}")
print(f"  ─────────────────────────────────────────────────────")
print(f"  planned            = {len(vt_plan):>4}  (of parts that entered scheduler)")
print(f"  not_required_today = {len(vt_def):>4}  (inv covers daily indent)")
print(f"  not_planned        = {len(vt_not):>4}  (needed but no machine capacity)")
print(f"\n  Output  → {output_path}")
print(f"  State   → {MACHINE_STATE_FILE}")
print(f"\n  NOTE: Update SECTION 1 each morning:")
print(f"        PLANNING_DATE = date(2026, 3, 15)")
print(f"        INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over")
# Out:
# ==============================================================
#   Smart APS V6  —  VT-Only Indent-Based Planning
#   Planning date  : 2026-03-18
#   Indent month   : March 2026
#   Total days     : 31
#   Sundays        : 5
#   Working days   : 26  (used as divisor)
#   Daily target   : monthly_indent / 26
#   Today target   : max(0, daily_indent - inventory)
#   Skip rule 1    : monthly_indent < 150 qty
#   Skip rule 2    : monthly_indent / rate  ≤ 4.0h (trivial run)
#   Zero-inv rule  : inventory=0 parts always forced into plan
# ==============================================================
#
# Loading data...
#   VT sheet columns found:
#     Part       → 'Part'
#     Cycle time → 'Cycle time'
#     Cavity     → 'Cavity'
#     Inventory  → 'Inventory'
#     Indent     → 'Indent'
#
#   VT parts in sheet            : 142
#   Parts with valid rate        : 116
#   Parts with zero/missing cycle time : 26
#     14SW220207-00003X0              cycle_time=nan  (cavity=nan — not used in rate)
#     14SW311144-00003X0              cycle_time=nan  (cavity=nan — not used in rate)
#     S21174-014A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S03080-004A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S33045-009A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S41222-022                      cycle_time=nan  (cavity=nan — not used in rate)
#     S22085-002                      cycle_time=nan  (cavity=nan — not used in rate)
#     S22063-003A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S250068-002                     cycle_time=nan  (cavity=nan — not used in rate)
#     S01100-004A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S250069-001                     cycle_time=nan  (cavity=nan — not used in rate)
#     S21175-002                      cycle_time=nan  (cavity=nan — not used in rate)
#     S12087-004                      cycle_time=nan  (cavity=nan — not used in rate)
#     S11436-002                      cycle_time=nan  (cavity=nan — not used in rate)
#     S11340-008A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S11122-015A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S13092-004A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S310966-002                     cycle_time=nan  (cavity=nan — not used in rate)
#     S21021-021A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S11358-028A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S21009-009A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S311010-03                      cycle_time=nan  (cavity=nan — not used in rate)
#     S31605-002A0X                   cycle_time=nan  (cavity=nan — not used in rate)
#     S120197-005                     cycle_time=nan  (cavity=nan — not used in rate)
#     S110432-007                     cycle_time=nan  (cavity=nan — not used in rate)
#     14SW250069-00002X1              cycle_time=nan  (cavity=nan — not used in rate)
#
# Reading indent data from VT sheet...
#
#   Indent summary:
#     Total VT parts with indent data : 142
#     Parts skipped (low/trivial)     : 33
#     Parts with zero inventory       : 16  (forced into plan regardless)
#     SKIP  S31135-011A0X                   Whole monthly indent takes only 1.77h ≤ 4.0h threshold
#     SKIP  S31842-004A0X                   Whole monthly indent takes only 3.00h ≤ 4.0h threshold
#     SKIP  S31868-005A0X                   Whole monthly indent takes only 2.80h ≤ 4.0h threshold
#     SKIP  S12071-001A0X                   Monthly indent 138 < 150 (threshold)
#     SKIP  S03080-004A0X                   Monthly indent 72 < 150 (threshold)
#     SKIP  S12113-001A0X                   Monthly indent 46 < 150 (threshold)
#     SKIP  S33107-005A0X                   Monthly indent 36 < 150 (threshold)
#     SKIP  S12094-001A0X                   Monthly indent 30 < 150 (threshold)
#     SKIP  S13081-004A0X                   Monthly indent 6 < 150 (threshold)
#     SKIP  S33106-009A0X                   Monthly indent 2 < 150 (threshold)
#     SKIP  S41356-017A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S41222-022                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22085-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S22063-003A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250068-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S01100-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S250069-001                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21175-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S12087-004                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11436-002                      Monthly indent 0 < 150 (threshold)
#     SKIP  S11340-008A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11122-015A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S13092-004A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S310966-002                     Monthly indent 0 < 150 (threshold)
#     SKIP  S21021-021A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S11358-028A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S21009-009A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S311010-03                      Monthly indent 0 < 150 (threshold)
#     SKIP  S31605-002A0X                   Monthly indent 0 < 150 (threshold)
#     SKIP  S120197-005                     Monthly indent 0 < 150 (threshold)
#     SKIP  S110432-007                     Monthly indent 0 < 150 (threshold)
#     SKIP  14SW250069-00002X1              Monthly indent 0 < 150 (threshold)
#     SKIP  S03062-001A0X                   Monthly indent 0 < 150 (threshold)
#
#   VT changeover times loaded: 26 machines
#     JSW 1ST                   → 50 min (0.833 h)
#     M.P-01                    → 40 min (0.667 h)
#     M.P-03                    → 30 min (0.500 h)
#     M.P-04                    → 30 min (0.500 h)
#     M.P-05                    → 40 min (0.667 h)
#     M.P-07                    → 30 min (0.500 h)
#     M.P-08                    → 30 min (0.500 h)
#     M.P-09                    → 30 min (0.500 h)
#     M.P-10                    → 40 min (0.667 h)
#     M.P-11                    → 40 min (0.667 h)
#     M.P-12                    → 30 min (0.500 h)
#     M.P-13                    → 30 min (0.500 h)
#     M.P-14                    → 30 min (0.500 h)
#     M.P-15                    → 40 min (0.667 h)
#     M.P-16                    → 30 min (0.500 h)
#     M.P-17                    → 40 min (0.667 h)
#     TOYO 1ST                  → 50 min (0.833 h)
#     TOYO 2ND                  → 50 min (0.833 h)
#     TOYO 3RD                  → 50 min (0.833 h)
#     TOYO 4TH                  → 50 min (0.833 h)
#     TOYO 5TH                  → 50 min (0.833 h)
#     TOYO 6TH                  → 50 min (0.833 h)
#     TOYO 7TH                  → 50 min (0.833 h)
#     TOYO 80T 1ST              → 60 min (1.000 h)
#     TOYO 80T 2ND              → 60 min (1.000 h)
#     YUDEK 1ST                 → 30 min (0.500 h)
#   Part categories — Runner: 17  Repeater: 3  Stranger: 122
#
#   Machine state loaded:
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S12106-001A0X
#     M.P-12                    last ran → S31068-005A0X
#     M.P-05                    last ran → S13080-004A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S03044-005A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S33045-010A0X
#     M.P-07                    last ran → S31851-002A0X
#     TOYO 6TH                  last ran → S41356-017A0X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13098-005A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S11160-006A0X
#     M.P-01                    last ran → S12094-003A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S21114-005A0X
#     M.P-13                    last ran → S11332-002A0X
#     M.P-15                    last ran → S11398-018A0X
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#     TOYO 8TH                  last ran → S41356-017A0X
#     YUDEK 2ND                 last ran → S13071-012A0X
#
# ======================================================================
#   PART AUDIT — tracing all 142 VT parts through every filter gate
# ======================================================================
#
#   Gate breakdown (142 total parts):
#     ✓  ENTERS SCHEDULER                           :   67 parts
#     ✗  NOT REQUIRED — INV SUFFICIENT              :   38 parts
#     ✗  ZERO/MISSING CYCLE TIME                    :   26 parts
#     ✗  SKIPPED (LOW INDENT / TRIVIAL RUN)         :    9 parts
#     ✗  ZERO/MISSING INDENT                        :    2 parts
#
#   Detail — 75 parts dropped before scheduler:
#   Part                            Gate      Reason
#   ──────────────────────────────  ────────  ───────────────────────────────────────────────────────
#   14SW220207-00003X0              GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S33045-009A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S21174-014A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   14SW311144-00003X0              GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S41222-022                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S22085-002                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S22063-003A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S250068-002                     GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S01100-004A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S250069-001                     GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S21175-002                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S03080-004A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S12087-004                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S11340-008A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S11122-015A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S13092-004A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S310966-002                     GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S21021-021A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S11358-028A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S21009-009A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S311010-03                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S31605-002A0X                   GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S120197-005                     GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S110432-007                     GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S11436-002                      GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   14SW250069-00002X1              GATE 1    Cycle time=nan — zero or missing in VT sheet → rate can
#   S41356-017A0X                   GATE 3    Monthly indent is zero or blank in VT sheet
#   S03062-001A0X                   GATE 3    Monthly indent is zero or blank in VT sheet
#   S33106-009A0X                   GATE 4    Monthly indent 2 < 150 (threshold)
#   S13081-004A0X                   GATE 4    Monthly indent 6 < 150 (threshold)
#   S12094-001A0X                   GATE 4    Monthly indent 30 < 150 (threshold)
#   S33107-005A0X                   GATE 4    Monthly indent 36 < 150 (threshold)
#   S12113-001A0X                   GATE 4    Monthly indent 46 < 150 (threshold)
#   S12071-001A0X                   GATE 4    Monthly indent 138 < 150 (threshold)
#   S31868-005A0X                   GATE 4    Whole monthly indent takes only 2.80h ≤ 4.0h threshold
#   S31135-011A0X                   GATE 4    Whole monthly indent takes only 1.77h ≤ 4.0h threshold
#   S31842-004A0X                   GATE 4    Whole monthly indent takes only 3.00h ≤ 4.0h threshold
#   S31777-003A0X                   GATE 5    Inventory (378) >= daily_indent (325.38) — no productio
#   14SW030081-00001X0              GATE 5    Inventory (1650) >= daily_indent (345.85) — no producti
#   14SW220201-00005X0              GATE 5    Inventory (772) >= daily_indent (383.04) — no productio
#   14SW250069-00001X0              GATE 5    Inventory (497) >= daily_indent (496.15) — no productio
#   S11398-016A0X                   GATE 5    Inventory (2137) >= daily_indent (616.85) — no producti
#   S41354-011A0X                   GATE 5    Inventory (892) >= daily_indent (719.73) — no productio
#   14SW410464-00009X0              GATE 5    Inventory (761) >= daily_indent (754.88) — no productio
#   14SW311155-00003X0              GATE 5    Inventory (1333) >= daily_indent (790.92) — no producti
#   S12095-011A0X                   GATE 5    Inventory (854) >= daily_indent (805.42) — no productio
#   S13083-011A0X                   GATE 5    Inventory (887) >= daily_indent (810.31) — no productio
#   M41224-022A0X                   GATE 5    Inventory (1674) >= daily_indent (875.27) — no producti
#   14SW250068-00003X0              GATE 5    Inventory (1075) >= daily_indent (884.31) — no producti
#   S33105-017A0X                   GATE 5    Inventory (4614) >= daily_indent (926.50) — no producti
#   S13112-006A0X                   GATE 5    Inventory (1610) >= daily_indent (1138.77) — no product
#   S12104-006A0X                   GATE 5    Inventory (2512) >= daily_indent (1383.65) — no product
#   S01100-004A9X                   GATE 5    Inventory (1969) >= daily_indent (1605.27) — no product
#   S11398-017A0X                   GATE 5    Inventory (572) >= daily_indent (309.08) — no productio
#   14SW311156-00002X0              GATE 5    Inventory (522) >= daily_indent (306.54) — no productio
#   14SW030082-00001X0              GATE 5    Inventory (474) >= daily_indent (121.81) — no productio
#   S12052-003A0X                   GATE 5    Inventory (1231) >= daily_indent (284.54) — no producti
#   S11026-054A0X                   GATE 5    Inventory (172) >= daily_indent (104.31) — no productio
#   S22166-013A0X                   GATE 5    Inventory (203) >= daily_indent (87.23) — no production
#   S12102-001A0X                   GATE 5    Inventory (831) >= daily_indent (86.54) — no production
#   14SW110487-00002X0              GATE 5    Inventory (325) >= daily_indent (76.15) — no production
#   14SW110487-00009X0              GATE 5    Inventory (301) >= daily_indent (76.15) — no production
#   S31839-004A0X                   GATE 5    Inventory (92) >= daily_indent (33.35) — no production
#   S03077-001A0X                   GATE 5    Inventory (95) >= daily_indent (30.77) — no production
#   S21021-012A0X                   GATE 5    Inventory (907) >= daily_indent (288.08) — no productio
#   S31740-008A0X                   GATE 5    Inventory (278) >= daily_indent (28.96) — no production
#   S31838-004A0X                   GATE 5    Inventory (319) >= daily_indent (27.69) — no production
#   S13094-014A0X                   GATE 5    Inventory (81) >= daily_indent (11.54) — no production
#   S13088-007A0X                   GATE 5    Inventory (83) >= daily_indent (10.27) — no production
#   14SW311083-00005X0              GATE 5    Inventory (498) >= daily_indent (201.42) — no productio
#   S13116-011A0X                   GATE 5    Inventory (306) >= daily_indent (204.69) — no productio
#   S41356-021A0X                   GATE 5    Inventory (233) >= daily_indent (137.31) — no productio
#   S12091-001A0X                   GATE 5    Inventory (287) >= daily_indent (219.12) — no productio
#   S07023-002A0X                   GATE 5    Inventory (1516) >= daily_indent (189.23) — no producti
#   S25026-003A0X                   GATE 5    Inventory (60) >= daily_indent (28.85) — no production
# ======================================================================
#
#
# ──────────────────────────────────────────────────────────────
#   VT Machines  |  116 parts  |  30 machines
# ──────────────────────────────────────────────────────────────
#   SCENARIO 1 — 67/105 parts critical (inv < 1 day indent)
#
#   Parts requiring production today (67):
#   Part                             Monthly    Daily       Inv    Target  Status
#   ──────────────────────────────  ────────  ───────  ────────  ────────  ────────────────────
#   S21174-012A0X                     313865  12071.73      9712      2360  PRODUCTION NEEDED
#   S22127-003A0X                     295580  11368.46      3209      8159  PRODUCTION NEEDED
#   14SW210274-00008X0                260427  10016.42      3678      6338  PRODUCTION NEEDED
#   S03058-002A0X                     188014  7231.31      2275      4956  PRODUCTION NEEDED
#   S32197-006A0X                     183056  7040.62      6211       830  PRODUCTION NEEDED
#   S13108-002A0X                     173611  6677.35       924      5753  PRODUCTION NEEDED
#   14SW210274-00013X0                115909  4458.04      1043      3415  PRODUCTION NEEDED
#   14SW210274-00016X0                115909  4458.04      1145      3313  PRODUCTION NEEDED
#   14SW220201-00010X0                111888  4303.38        15      4288  PRODUCTION NEEDED
#   S31121-012A0X                      92130  3543.46      2410      1133  PRODUCTION NEEDED
#   S12100-003A0X                      87393  3361.27       984      2377  PRODUCTION NEEDED
#   S25038-001A0X                      79058  3040.69      1200      1841  PRODUCTION NEEDED
#   14SW311082-00006X0                 68972  2652.77      1093      1560  PRODUCTION NEEDED
#   S31437-004A0X                      68309  2627.27      2172       455  PRODUCTION NEEDED
#   S31741-005A0X                      63205  2430.96       575      1856  PRODUCTION NEEDED
#   S13083-003A0X                      35277  1356.81       209      1148  PRODUCTION NEEDED
#   S12095-003A0X                      25351   975.04       388       587  PRODUCTION NEEDED
#   14SW220197-00005X0                 22890   880.38       650       230  PRODUCTION NEEDED
#   14SW220197-00010X0                 22890   880.38       495       385  PRODUCTION NEEDED
#   S03046-005A0X                      20860   802.31       554       248  PRODUCTION NEEDED
#   S12095-004A0X                      17910   688.85       244       445  PRODUCTION NEEDED
#   S12087-004A0X                      17336   666.77       583        84  PRODUCTION NEEDED
#   S13110-005A0X                      15629   601.12       246       355  PRODUCTION NEEDED
#   S33105-016A0X                      15120   581.54       134       448  PRODUCTION NEEDED
#   S12089-004A0X                      14634   562.85       433       130  PRODUCTION NEEDED
#   S32168-007A0X                      13608   523.38       234       289  PRODUCTION NEEDED
#   14SW311038-00005X0                 12852   494.31       284       210  PRODUCTION NEEDED
#   14SW311011-00003X0                 12816   492.92       113       380  PRODUCTION NEEDED
#   S12042-004A9X                      11806   454.08       290       164  PRODUCTION NEEDED
#   14SW330127-00008X0                  8895   342.12        73       269  PRODUCTION NEEDED
#   S31841-008A0X                       8352   321.23        43       278  PRODUCTION NEEDED
#   S31867-002A0X                       8208   315.69        53       263  PRODUCTION NEEDED
#   S21077-008A0X                       8060   310.00        13       297  PRODUCTION NEEDED
#   S32073-012A0X                       7698   296.08       117       179  PRODUCTION NEEDED
#   S13123-002A0X                       6760   260.00       102       158  PRODUCTION NEEDED
#   S21021-016A0X                       6710   258.08        57       201  PRODUCTION NEEDED
#   S12089-001A0X                       6557   252.19       163        89  PRODUCTION NEEDED
#   S11434-002A0X                       6329   243.42       163        80  PRODUCTION NEEDED
#   14SW311082-00010X0                  5952   228.92       222         7  PRODUCTION NEEDED
#   S11398-030A0X                       5696   219.08        95       124  PRODUCTION NEEDED
#   S13052-005A0X                       5280   203.08         0       203  ZERO INV — FORCED
#   S02020-010A0X                       3066   117.92         0       118  ZERO INV — FORCED
#   S13120-001A0X                       2481    95.42         9        86  PRODUCTION NEEDED
#   14SW311101-00003X0                  2450    94.23        40        54  PRODUCTION NEEDED
#   S22166-016A0X                       2268    87.23         7        80  PRODUCTION NEEDED
#   S21028-002A0X                       2010    77.31        65        12  PRODUCTION NEEDED
#   S21114-005A0X                       1896    72.92        72         1  PRODUCTION NEEDED
#   S31123-005A0X                       1884    72.46         0        72  ZERO INV — FORCED
#   S11398-018A0X                       1707    65.65        19        47  PRODUCTION NEEDED
#   S21007-038A0X                       1700    65.38         2        63  PRODUCTION NEEDED
#   S03066-001A0X                       1622    62.38        14        48  PRODUCTION NEEDED
#   S13080-004A0X                       1320    50.77         7        44  PRODUCTION NEEDED
#   M41035-032A0X                       1181    45.42         7        38  PRODUCTION NEEDED
#   S11038-029A0X                        983    37.81         5        33  PRODUCTION NEEDED
#   S03066-008A0X                        822    31.62        16        16  PRODUCTION NEEDED
#   S31064-006A0X                        324    12.46         0        12  ZERO INV — FORCED
#   S12094-003A0X                        246     9.46         0         9  ZERO INV — FORCED
#   S13114-003A0X                        240     9.23         0         9  ZERO INV — FORCED
#   S12106-001A0X                        216     8.31         0         8  ZERO INV — FORCED
#   S31068-005A0X                        180     6.92         0         7  ZERO INV — FORCED
#   S13098-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S03044-005A0X                         60     2.31         0         2  ZERO INV — FORCED
#   S33045-010A0X                         58     2.23         0         2  ZERO INV — FORCED
#   S31851-002A0X                         36     1.38         0         1  ZERO INV — FORCED
#   S11160-006A0X                         26     1.00         0         1  ZERO INV — FORCED
#   S11332-002A0X                         12     0.46         0         0  ZERO INV — FORCED
#   S13071-012A0X                          6     0.23         0         0  ZERO INV — FORCED
#
#   Priority order — sorted by daily_indent descending (67 active parts):
#   Part                              Daily       Inv    Target  Zero_Inv
#   ──────────────────────────────  ───────  ────────  ────────  ────────
#   S21174-012A0X                   12071.73      9712      2360        No
#   S22127-003A0X                   11368.46      3209      8159        No
#   14SW210274-00008X0              10016.42      3678      6338        No
#   S03058-002A0X                   7231.31      2275      4956        No
#   S32197-006A0X                   7040.62      6211       830        No
#   S13108-002A0X                   6677.35       924      5753        No
#   14SW210274-00013X0              4458.04      1043      3415        No
#   14SW210274-00016X0              4458.04      1145      3313        No
#   14SW220201-00010X0              4303.38        15      4288        No
#   S31121-012A0X                   3543.46      2410      1133        No
#   S12100-003A0X                   3361.27       984      2377        No
#   S25038-001A0X                   3040.69      1200      1841        No
#   14SW311082-00006X0              2652.77      1093      1560        No
#   S31437-004A0X                   2627.27      2172       455        No
#   S31741-005A0X                   2430.96       575      1856        No
#   S13083-003A0X                   1356.81       209      1148        No
#   S12095-003A0X                    975.04       388       587        No
#   14SW220197-00005X0               880.38       650       230        No
#   14SW220197-00010X0               880.38       495       385        No
#   S03046-005A0X                    802.31       554       248        No
#   S12095-004A0X                    688.85       244       445        No
#   S12087-004A0X                    666.77       583        84        No
#   S13110-005A0X                    601.12       246       355        No
#   S33105-016A0X                    581.54       134       448        No
#   S12089-004A0X                    562.85       433       130        No
#   S32168-007A0X                    523.38       234       289        No
#   14SW311038-00005X0               494.31       284       210        No
#   14SW311011-00003X0               492.92       113       380        No
#   S12042-004A9X                    454.08       290       164        No
#   14SW330127-00008X0               342.12        73       269        No
#   S31841-008A0X                    321.23        43       278        No
#   S31867-002A0X                    315.69        53       263        No
#   S21077-008A0X                    310.00        13       297        No
#   S32073-012A0X                    296.08       117       179        No
#   S13123-002A0X                    260.00       102       158        No
#   S21021-016A0X                    258.08        57       201        No
#   S12089-001A0X                    252.19       163        89        No
#   S11434-002A0X                    243.42       163        80        No
#   14SW311082-00010X0               228.92       222         7        No
#   S11398-030A0X                    219.08        95       124        No
#   S13052-005A0X                    203.08         0       203       YES
#   S02020-010A0X                    117.92         0       118       YES
#   S13120-001A0X                     95.42         9        86        No
#   14SW311101-00003X0                94.23        40        54        No
#   S22166-016A0X                     87.23         7        80        No
#   S21028-002A0X                     77.31        65        12        No
#   S21114-005A0X                     72.92        72         1        No
#   S31123-005A0X                     72.46         0        72       YES
#   S11398-018A0X                     65.65        19        47        No
#   S21007-038A0X                     65.38         2        63        No
#   S03066-001A0X                     62.38        14        48        No
#   S13080-004A0X                     50.77         7        44        No
#   M41035-032A0X                     45.42         7        38        No
#   S11038-029A0X                     37.81         5        33        No
#   S03066-008A0X                     31.62        16        16        No
#   S31064-006A0X                     12.46         0        12       YES
#   S12094-003A0X                      9.46         0         9       YES
#   S13114-003A0X                      9.23         0         9       YES
#   S12106-001A0X                      8.31         0         8       YES
#   S31068-005A0X                      6.92         0         7       YES
#   S13098-005A0X                      2.31         0         2       YES
#   S03044-005A0X                      2.31         0         2       YES
#   S33045-010A0X                      2.23         0         2       YES
#   S31851-002A0X                      1.38         0         1       YES
#   S11160-006A0X                      1.00         0         1       YES
#   S11332-002A0X                      0.46         0         0       YES
#   S13071-012A0X                      0.23         0         0       YES
#
#   PASS 1 — Runners (dedicated machine, cap = target + 1-day buffer):
#     ✓ S21174-012A0X                  [Runner  ] → JSW 1ST          22.00h  qty=    6600  CO=No  [DEDICATED]
#     ✓ S22127-003A0X                  [Runner  ] → TOYO 3RD         22.00h  qty=    6092  CO=No  [DEDICATED]
#     ✓ 14SW210274-00008X0             [Runner  ] → TOYO 1ST         22.00h  qty=    5657  CO=No  [DEDICATED]
#     ✗ S03058-002A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S32197-006A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ S13108-002A0X                  [Runner  ] → M.P-17           22.00h  qty=    3300  CO=No  [DEDICATED]
#     ✓ 14SW210274-00013X0             [Runner  ] → M.P-09           22.00h  qty=    6600  CO=No  [DEDICATED]
#     ✗ 14SW210274-00016X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✓ 14SW220201-00010X0             [Runner  ] → M.P-04           22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ S31121-012A0X                  [Runner  ] → M.P-16           22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ S12100-003A0X                  [Runner  ] → TOYO 80T 2ND     22.00h  qty=    3168  CO=No  [DEDICATED]
#     ✓ S25038-001A0X                  [Runner  ] → TOYO 4TH         22.00h  qty=    2731  CO=No  [DEDICATED]
#     ✗ 14SW311082-00006X0             [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31437-004A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#     ✗ S31741-005A0X                  [Runner  ]  NOT PLANNED — RUNNER — no machine state (first run)
#
#   Runner-dedicated machines: ['JSW 1ST', 'M.P-04', 'M.P-09', 'M.P-16', 'M.P-17', 'TOYO 1ST', 'TOYO 3RD', 'TOYO 4TH', 'TOYO 80T 2ND']
#
#   PASS 2 — Repeaters + Strangers (Runner machines excluded):
#     ✓ S13083-003A0X                  [Repeater] → M.P-05           9.57h  qty=    1148  CO=Yes (40min)
#     ✓ S12095-003A0X                  [Stranger] → YUDEK 1ST        4.89h  qty=     587  CO=Yes (30min)
#     ✓ 14SW220197-00005X0             [Stranger] → M.P-11           4.00h  qty=     576  CO=Yes (40min)
#     ✓ 14SW220197-00010X0             [Stranger] → M.P-12           4.00h  qty=     758  CO=Yes (30min)
#     ✓ S03046-005A0X                  [Stranger] → TOYO 5TH         4.00h  qty=    1200  CO=No
#     ✓ S12095-004A0X                  [Stranger] → M.P-01           5.56h  qty=     445  CO=Yes (40min)
#     ✓ S12087-004A0X                  [Stranger] → TOYO 80T 1ST     4.00h  qty=     379  CO=Yes (60min)
#     ✓ S13110-005A0X                  [Stranger] → TOYO 2ND         4.00h  qty=    1200  CO=No
#     ✓ S33105-016A0X                  [Stranger] → TOYO 80T 1ST     4.00h  qty=     480  CO=Yes (60min)
#     ✓ S12089-004A0X                  [Stranger] → M.P-14           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S32168-007A0X                  [Stranger] → M.P-03           4.00h  qty=     960  CO=Yes (30min)
#     ✓ 14SW311038-00005X0             [Stranger] → M.P-07           4.00h  qty=     480  CO=Yes (30min)
#     ✓ 14SW311011-00003X0             [Stranger] → M.P-08           4.22h  qty=     380  CO=Yes (30min)
#     ✓ S12042-004A9X                  [Stranger] → M.P-13           4.00h  qty=    1029  CO=Yes (30min)
#     ✓ 14SW330127-00008X0             [Stranger] → TOYO 80T 1ST     4.00h  qty=     360  CO=Yes (60min)
#     ✓ S31841-008A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=    1600  CO=Yes (40min)
#     ✓ S31867-002A0X                  [Stranger] → M.P-12           4.00h  qty=     524  CO=Yes (30min)
#     ✓ S21077-008A0X                  [Stranger] → M.P-10           4.00h  qty=     360  CO=Yes (40min)
#     ✓ S32073-012A0X                  [Stranger] → M.P-14           4.00h  qty=    1800  CO=Yes (30min)
#     ✓ S13123-002A0X                  [Stranger] → M.P-03           4.00h  qty=     720  CO=Yes (30min)
#     ✓ S21021-016A0X                  [Stranger] → M.P-15           4.00h  qty=     576  CO=Yes (40min)
#     ✓ S12089-001A0X                  [Stranger] → M.P-07           4.00h  qty=     960  CO=Yes (30min)
#     ✓ S11434-002A0X                  [Stranger] → M.P-11           4.00h  qty=     320  CO=Yes (40min)
#     ✓ 14SW311082-00010X0             [Stranger] → M.P-13           4.00h  qty=     480  CO=Yes (30min)
#     ✓ S11398-030A0X                  [Stranger] → M.P-10           4.00h  qty=     480  CO=Yes (40min)
#     ✓ S13052-005A0X                  [Stranger] → M.P-08           4.00h  qty=     900  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S02020-010A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=     800  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S13120-001A0X                  [Stranger] → M.P-15           4.00h  qty=     240  CO=Yes (40min)
#     ✓ 14SW311101-00003X0             [Stranger] → YUDEK 1ST        4.00h  qty=     626  CO=Yes (30min)
#     ✓ S22166-016A0X                  [Stranger] → M.P-01           4.00h  qty=     343  CO=Yes (40min)
#     ✓ S21028-002A0X                  [Stranger] → M.P-11           4.00h  qty=     400  CO=Yes (40min)
#     ✓ S21114-005A0X                  [Stranger] → M.P-10           4.00h  qty=     600  CO=Yes (40min)
#     ✓ S31123-005A0X                  [Stranger] → M.P-12           4.00h  qty=     720  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11398-018A0X                  [Stranger] → M.P-15           4.00h  qty=     320  CO=Yes (40min)
#     ✓ S21007-038A0X                  [Stranger] → M.P-14           4.00h  qty=     626  CO=Yes (30min)
#     ✓ S03066-001A0X                  [Stranger] → M.P-03           4.00h  qty=     655  CO=Yes (30min)
#     ✓ S13080-004A0X                  [Stranger] → M.P-05           4.00h  qty=     626  CO=Yes (40min)
#     ✓ M41035-032A0X                  [Stranger] → M.P-07           4.00h  qty=     576  CO=Yes (30min)
#     ✓ S11038-029A0X                  [Stranger] → M.P-13           4.00h  qty=     400  CO=Yes (30min)
#     ✓ S03066-008A0X                  [Stranger] → M.P-08           4.00h  qty=     282  CO=Yes (30min)
#     ✓ S31064-006A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=     600  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S12094-003A0X                  [Stranger] → M.P-01           4.00h  qty=     300  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S13114-003A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=     720  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S12106-001A0X                  [Stranger] → M.P-12           4.00h  qty=     480  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31068-005A0X                  [Stranger] → M.P-14           4.00h  qty=     480  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S13098-005A0X                  [Stranger] → M.P-11           4.00h  qty=     240  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S03044-005A0X                  [Stranger] → M.P-03           4.00h  qty=     360  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S33045-010A0X                  [Stranger] → M.P-07           4.00h  qty=    1600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S31851-002A0X                  [Stranger] → M.P-13           4.00h  qty=    1600  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11160-006A0X                  [Stranger] → M.P-08           4.00h  qty=     720  CO=Yes (30min)  [ZERO-INV FORCED]
#     ✓ S11332-002A0X                  [Stranger] → YUDEK 2ND        4.00h  qty=     720  CO=Yes (40min)  [ZERO-INV FORCED]
#     ✓ S13071-012A0X                  [Stranger] → YUDEK 1ST        4.00h  qty=     800  CO=Yes (30min)  [ZERO-INV FORCED]
#
#   22-hour filler:
#     ↑ S12095-003A0X                  → YUDEK 1ST        +3.11h merged  qty+=373  [EXTEND]
#     ↑ 14SW220197-00010X0             → M.P-12           +4.00h merged  qty+=758  [EXTEND]
#     ↑ S13083-003A0X                  → M.P-05           +7.10h merged  qty+=852  [EXTEND]
#     ↑ S12089-004A0X                  → M.P-14           +4.00h merged  qty+=960  [EXTEND]
#     ↑ S12087-004A0X                  → TOYO 80T 1ST     +7.00h merged  qty+=663  [EXTEND]
#     ↑ S13110-005A0X                  → TOYO 2ND         +18.00h merged  qty+=5400  [EXTEND]
#     ↑ S32168-007A0X                  → M.P-03           +4.00h merged  qty+=960  [EXTEND]
#     ↑ 14SW311038-00005X0             → M.P-07           +4.00h merged  qty+=480  [EXTEND]
#     + S41356-017A0X                  → TOYO 6TH         22.00h  qty=3168  [Filler]  CO=No
#     ↑ 14SW220197-00005X0             → M.P-11           +3.33h merged  qty+=480  [EXTEND]
#     ↑ 14SW311011-00003X0             → M.P-08           +3.78h merged  qty+=340  [EXTEND]
#     ↑ S12095-004A0X                  → M.P-01           +6.44h merged  qty+=515  [EXTEND]
#     ↑ S21077-008A0X                  → M.P-10           +8.00h merged  qty+=720  [EXTEND]
#     ↑ S12042-004A9X                  → M.P-13           +4.00h merged  qty+=1029  [EXTEND]
#     ↑ S21021-016A0X                  → M.P-15           +8.00h merged  qty+=1152  [EXTEND]
#     ↑ S03046-005A0X                  → TOYO 5TH         +18.00h merged  qty+=5400  [EXTEND]
#     ↑ S31841-008A0X                  → YUDEK 2ND        +3.33h merged  qty+=1332  [EXTEND]
#     No duplicate parts — each part appears exactly once  ✓
#
#   ==========================================================
#   TOOL-CHANGER GLOBAL STAGGER  (single tool changer — all VT)
#   ==========================================================
#   Total CO events across all VT machines: 36
#
#   Machine            Part Before            Part After              CO Dur  Natural   Actual   Delay Spare Used
#   ────────────────── ────────────────────── ────────────────────── ─────── ──────── ──────── ─────── ──────────
#   M.P-11             14SW220197-00005X0     S11434-002A0X            40.0m    08:00    08:00    none          —
#   YUDEK 2ND          S31841-008A0X          S02020-010A0X            40.0m    08:00    08:00 +0.1min     +1 pcs
#   M.P-03             S32168-007A0X          S13123-002A0X            30.0m    08:30    08:30    none          —
#   M.P-07             14SW311038-00005X0     S12089-001A0X            30.0m    08:30    08:30    none          —
#   M.P-08             14SW311011-00003X0     S13052-005A0X            30.0m    08:30    08:30    none          —
#   M.P-12             14SW220197-00010X0     S31867-002A0X            30.0m    08:30    08:30    none          —
#   M.P-13             S12042-004A9X          14SW311082-00010X0       30.0m    08:30    08:30    none          —
#   M.P-14             S12089-004A0X          S32073-012A0X            30.0m    08:30    08:30    none          —
#   YUDEK 1ST          S12095-003A0X          14SW311101-00003X0       30.0m    08:30    08:30    none          —
#   TOYO 80T 1ST       S12087-004A0X          S33105-016A0X            60.0m    12:00    12:00    none          —
#   M.P-11             S11434-002A0X          S21028-002A0X            40.0m    12:40    12:40 +0.1min     +0 pcs
#   YUDEK 2ND          S02020-010A0X          S31064-006A0X            40.0m    12:40    12:40    none          —
#   M.P-01             S12095-004A0X          S22166-016A0X            40.0m    12:40    12:40    none          —
#   M.P-10             S21077-008A0X          S11398-030A0X            40.0m    12:40    12:40    none          —
#   M.P-15             S21021-016A0X          S13120-001A0X            40.0m    12:40    12:40    none          —
#   M.P-03             S13123-002A0X          S03066-001A0X            30.0m    13:00    13:00    none          —
#   M.P-07             S12089-001A0X          M41035-032A0X            30.0m    13:00    13:00    none          —
#   M.P-08             S13052-005A0X          S03066-008A0X            30.0m    13:00    13:00    none          —
#   M.P-12             S31867-002A0X          S31123-005A0X            30.0m    13:00    13:00    none          —
#   M.P-13             14SW311082-00010X0     S11038-029A0X            30.0m    13:00    13:00    none          —
#   M.P-14             S32073-012A0X          S21007-038A0X            30.0m    13:00    13:00    none          —
#   YUDEK 1ST          14SW311101-00003X0     S13114-003A0X            30.0m    13:00    13:00    none          —
#   TOYO 80T 1ST       S33105-016A0X          14SW330127-00008X0       60.0m    17:00    17:00    none          —
#   M.P-11             S21028-002A0X          S13098-005A0X            40.0m    17:20    17:20    none          —
#   YUDEK 2ND          S31064-006A0X          S11332-002A0X            40.0m    17:20    17:20    none          —
#   M.P-01             S22166-016A0X          S12094-003A0X            40.0m    17:20    17:20    none          —
#   M.P-10             S11398-030A0X          S21114-005A0X            40.0m    17:20    17:20    none          —
#   M.P-15             S13120-001A0X          S11398-018A0X            40.0m    17:20    17:20    none          —
#   M.P-05             S13083-003A0X          S13080-004A0X            40.0m    17:20    17:20    none          —
#   M.P-03             S03066-001A0X          S03044-005A0X            30.0m    17:30    17:30    none          —
#   M.P-07             M41035-032A0X          S33045-010A0X            30.0m    17:30    17:30    none          —
#   M.P-08             S03066-008A0X          S11160-006A0X            30.0m    17:30    17:30    none          —
#   M.P-12             S31123-005A0X          S12106-001A0X            30.0m    17:30    17:30    none          —
#   M.P-13             S11038-029A0X          S31851-002A0X            30.0m    17:30    17:30    none          —
#   M.P-14             S21007-038A0X          S31068-005A0X            30.0m    17:30    17:30    none          —
#   YUDEK 1ST          S13114-003A0X          S13071-012A0X            30.0m    17:30    17:30    none          —
#
#   ──────────────────────────────────────────────────────────
#   Tool-changer queue complete:
#     Total CO events    : 36
#     Events delayed     : 2
#     Total delay time   : 0.2 min
#     Unresolvable (22h) : 33  ← review manually
#     Tool changer free  : 18:00  (last CO ends at 18:00)
#
#   Serialized tool-changer queue (final):
#   #    Machine               Start      End Part After
#   ──── ────────────────── ──────── ──────── ──────────────────────
#   1    M.P-11                08:00    08:40 S11434-002A0X
#   2    YUDEK 2ND             08:00    08:40 S02020-010A0X
#   3    M.P-03                08:30    09:00 S13123-002A0X
#   4    M.P-07                08:30    09:00 S12089-001A0X
#   5    M.P-08                08:30    09:00 S13052-005A0X
#   6    M.P-12                08:30    09:00 S31867-002A0X
#   7    M.P-13                08:30    09:00 14SW311082-00010X0
#   8    M.P-14                08:30    09:00 S32073-012A0X
#   9    YUDEK 1ST             08:30    09:00 14SW311101-00003X0
#   10   TOYO 80T 1ST          12:00    13:00 S33105-016A0X
#   11   M.P-11                12:40    13:20 S21028-002A0X
#   12   YUDEK 2ND             12:40    13:20 S31064-006A0X
#   13   M.P-01                12:40    13:20 S22166-016A0X
#   14   M.P-10                12:40    13:20 S11398-030A0X
#   15   M.P-15                12:40    13:20 S13120-001A0X
#   16   M.P-03                13:00    13:30 S03066-001A0X
#   17   M.P-07                13:00    13:30 M41035-032A0X
#   18   M.P-08                13:00    13:30 S03066-008A0X
#   19   M.P-12                13:00    13:30 S31123-005A0X
#   20   M.P-13                13:00    13:30 S11038-029A0X
#   21   M.P-14                13:00    13:30 S21007-038A0X
#   22   YUDEK 1ST             13:00    13:30 S13114-003A0X
#   23   TOYO 80T 1ST          17:00    18:00 14SW330127-00008X0
#   24   M.P-11                17:20    18:00 S13098-005A0X
#   25   YUDEK 2ND             17:20    18:00 S11332-002A0X
#   26   M.P-01                17:20    18:00 S12094-003A0X
#   27   M.P-10                17:20    18:00 S21114-005A0X
#   28   M.P-15                17:20    18:00 S11398-018A0X
#   29   M.P-05                17:20    18:00 S13080-004A0X
#   30   M.P-03                17:30    18:00 S03044-005A0X
#   31   M.P-07                17:30    18:00 S33045-010A0X
#   32   M.P-08                17:30    18:00 S11160-006A0X
#   33   M.P-12                17:30    18:00 S12106-001A0X
#   34   M.P-13                17:30    18:00 S31851-002A0X
#   35   M.P-14                17:30    18:00 S31068-005A0X
#   36   YUDEK 1ST             17:30    18:00 S13071-012A0X
#   ==========================================================
#
#   Machine state saved → machine_state.json
#     TOYO 3RD                  last ran → S22127-003A0X
#     JSW 1ST                   last ran → S21174-012A0X
#     TOYO 1ST                  last ran → 14SW210274-00008X0
#     YUDEK 1ST                 last ran → S13071-012A0X
#     M.P-12                    last ran → S12106-001A0X
#     M.P-05                    last ran → S13080-004A0X
#     M.P-04                    last ran → 14SW220201-00010X0
#     M.P-14                    last ran → S31068-005A0X
#     M.P-16                    last ran → S31121-012A0X
#     TOYO 80T 1ST              last ran → 14SW330127-00008X0
#     TOYO 2ND                  last ran → S13110-005A0X
#     M.P-03                    last ran → S03044-005A0X
#     M.P-07                    last ran → S33045-010A0X
#     TOYO 6TH                  last ran → S41356-017A0X
#     TOYO 7TH                  last ran → S25026-003A0X
#     M.P-11                    last ran → S13098-005A0X
#     M.P-09                    last ran → 14SW210274-00013X0
#     M.P-08                    last ran → S11160-006A0X
#     M.P-01                    last ran → S12094-003A0X
#     TOYO 80T 2ND              last ran → S12100-003A0X
#     M.P-17                    last ran → S13108-002A0X
#     M.P-10                    last ran → S21114-005A0X
#     M.P-13                    last ran → S31851-002A0X
#     M.P-15                    last ran → S11398-018A0X
#     TOYO 4TH                  last ran → S25038-001A0X
#     TOYO 5TH                  last ran → S03046-005A0X
#     TOYO 8TH                  last ran → S41356-017A0X
#     YUDEK 2ND                 last ran → S11332-002A0X
#
# Writing → 1Smart_APS_Plan_20260318Indent.xlsx
#   Formatting applied  ✓
#
# ==============================================================
#   Smart APS V6 Complete  —  VT Only  —  2026-03-18
#   Indent month  : March 2026
#   Working days  : 26  (31 days − 5 Sundays)
# ==============================================================
#   Total parts in VT sheet    : 142
#   ─────────────────────────────────────────────────────
#   ✓ ENTERS SCHEDULER                          :   67
#   · NOT REQUIRED — INV SUFFICIENT             :   38
#   · ZERO/MISSING CYCLE TIME                   :   26
#   · SKIPPED (LOW INDENT / TRIVIAL RUN)        :    9
#   · ZERO/MISSING INDENT                       :    2
#   ─────────────────────────────────────────────────────
#   planned            =   62  (of parts that entered scheduler)
#   not_required_today =    0  (inv covers daily indent)
#   not_planned        =    6  (needed but no machine capacity)
#
#   Output  → 1Smart_APS_Plan_20260318Indent.xlsx
#   State   → machine_state.json
#
#   NOTE: Update SECTION 1 each morning:
#         PLANNING_DATE = date(2026, 3, 15)
#         INDENT_MONTH  = date(2026, 3,  1)   ← only change when month rolls over
