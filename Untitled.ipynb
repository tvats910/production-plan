# %%
import pandas as pd
import numpy as np

# =========================================
# LOAD FILE
# =========================================
file_path = "D:/Part Production Report/Coupled data.xlsx"
  # change path if needed

df = pd.read_excel(file_path, sheet_name="Sheet2", header=[0,1])

# =========================================
# FLATTEN MULTI-LEVEL HEADERS
# =========================================
df.columns = [' | '.join([str(c).strip() for c in col if pd.notna(c)])
              for col in df.columns]

# =========================================
# IDENTIFY PART / MATERIAL COLUMN
# =========================================
material_col = [col for col in df.columns if "Part" in col or "Material" in col][0]

materials = df[material_col]

# =========================================
# SELECT ONLY DEVIATION COLUMNS
# =========================================
deviation_cols = [col for col in df.columns if "Deviation" in col]

deviation_data = df[deviation_cols]

# =========================================
# ROW-WISE STATISTICS (same logic as yours)
# =========================================
mean_dev = deviation_data.mean(axis=1)
std_dev = deviation_data.std(axis=1, ddof=1)
count = deviation_data.count(axis=1)

std_error = std_dev / np.sqrt(count)

# 🔹 90% Confidence Interval
z = 1.645

lower_ci = mean_dev - z * std_error
upper_ci = mean_dev + z * std_error

# =========================================
# RESULT
# =========================================
result = pd.DataFrame({
    'Material': materials,
    'Mean_Deviation': mean_dev,
    'Std_Dev': std_dev,
    'Lower_90_CI': lower_ci,
    'Upper_90_CI': upper_ci
})

print(result)

# Optional save
result.to_excel("Deviation_Confidence_Output.xlsx", index=False)
# Out:
#                Material  Mean_Deviation      Std_Dev  Lower_90_CI  Upper_90_CI
# 0         S01113-000E00     -164.102564  4485.971536 -1345.755974  1017.550845
# 1         S22127-000E01      -48.820513  1529.213951  -451.632003   353.990977
# 2         C51019-000E00      -61.538462  1420.269690  -435.652855   312.575932
# 3         S01113-000E50      -41.025641   447.635865  -158.937768    76.886486
# 4    14MA410268-00701X0      351.179487  2202.054386  -228.865449   931.224423
# ..                  ...             ...          ...          ...          ...
# 674   14SW010135-0001S0       -1.282051     8.006408    -3.391026     0.826923
# 675   14SW210289-0001S0        3.846154    24.019223    -2.480769    10.173077
# 676       S41355-000S00        0.102564     0.640513    -0.066154     0.271282
# 677                 NaN        0.000000     0.000000     0.000000     0.000000
# 678                 NaN             NaN          NaN          NaN          NaN
#
# [679 rows x 5 columns]

# %%
import pandas as pd
import numpy as np

file_path = "D:/Part Production Report/Coupled data Updated.xlsx"

df = pd.read_excel(file_path, sheet_name="Sheet2")

# Identify columns
part_col = "Part"
actual_cols = [col for col in df.columns if "Actual" in col]

# Extract
parts = df[part_col]
actual_data = df[actual_cols]

# Statistics
mean_actual = actual_data.mean(axis=1)
std_actual = actual_data.std(axis=1, ddof=1)

# 90% CI
z = 1.645

lower_actual = mean_actual - z * std_actual
upper_actual = mean_actual + z * std_actual

# Result
result = pd.DataFrame({
    "Part": parts,
    "Mean_Actual": mean_actual,
    "Std_Actual": std_actual,
    "Lower_Actual_90": lower_actual,
    "Upper_Actual_90": upper_actual
})

print(result)

result.to_excel("Actual_90CI_Output.xlsx", index=False)
# Out:
#                    Part   Mean_Actual   Std_Actual  Lower_Actual_90  \
# 0         S01113-000E00  17328.205128  3299.278128     11900.892607
# 1         S22127-000E01   7066.051282  1200.507567      5091.216334
# 2         C51019-000E00   6646.153846  1198.649713      4674.375069
# 3         S01113-000E50   2984.615385   457.417500      2232.163597
# 4    14MA410268-00701X0   2426.256410  1690.363971      -354.392322
# ..                  ...           ...          ...              ...
# 674   14SW010135-0001S0      0.000000     0.000000         0.000000
# 675   14SW210289-0001S0      3.846154    24.019223       -35.665468
# 676       S41355-000S00      0.102564     0.640513        -0.951079
# 677                 NaN      0.000000     0.000000         0.000000
# 678                 NaN      0.000000          NaN              NaN
#
#      Upper_Actual_90
# 0       22755.517649
# 1        9040.886230
# 2        8617.932623
# 3        3737.067172
# 4        5206.905142
# ..               ...
# 674         0.000000
# 675        43.357776
# 676         1.156207
# 677         0.000000
# 678              NaN
#
# [679 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# ============================
# LOAD FILE
# ============================

file_path = "D:/Part Production Report/Coupled data Updated.xlsx"

df = pd.read_excel(file_path, sheet_name="Sheet2")

# ============================
# FIND ACTUAL COLUMNS
# ============================

actual_cols = [col for col in df.columns if "Actual" in col]

print("Actual columns detected:")
print(actual_cols)

# ============================
# SELECT PART (change index if needed)
# ============================

row_index = 0   # first part — change to analyze another part

values = df.loc[row_index, actual_cols].dropna()

print("\nValues used for histogram:")
print(values)

# ============================
# PLOT HISTOGRAM
# ============================

plt.figure(figsize=(8,5))
plt.hist(values, bins=10)
plt.title(f"Actual Distribution — Part: {df.loc[row_index, 'Part']}")
plt.xlabel("Actual Values")
plt.ylabel("Frequency")
plt.show()
# Out:
# Actual columns detected:
# ['6TH Jan Plan Actual', '7TH Jan Plan Actual', '8TH Jan Plan Actual', '9TH Jan Plan Actual', '10TH Jan Plan Actual', '12th Jan Plan Actual', '13th Jan Plan Actual', '14th Jan Plan Actual', '15th Jan Plan Actual', '16TH Jan Plan Actual', '17th Jan Plan Actual', '19th Jan Plan Actual', '20th Jan Plan Actual', '21st Jan Plan Actual', '22nd Jan Plan Actual', '23rd Jan Plan Actual', '24th Jan Plan Actual', '25th Jan Plan Actual', '27TH Jan Plan Actual', '28th Jan Plan Actual', '29th Jan Plan Actual', '30th Jan Plan Actual', '31st Jan Plan Actual', '2nd Feb Plan Actual', '3rd Feb Plan Actual', '4th Feb Plan Actual', '5th Feb Plan Actual', '6th Feb Plan Actual', '7th Feb Plan Actual', '9th Feb Plan Actual', '10th Feb Plan Actual', '11th Feb Plan Actual', '12th Feb Plan Actual', '13th Feb Plan Actual', '14th Feb Plan Actual', '16th Feb Plan Actual', '17th Feb Plan Actual', '18th Feb Plan Actual', '19th Feb Plan Actual']
#
# Values used for histogram:
# 6TH Jan Plan Actual     18600.0
# 7TH Jan Plan Actual     18600.0
# 8TH Jan Plan Actual     19000.0
# 9TH Jan Plan Actual     19000.0
# 10TH Jan Plan Actual    19000.0
# 12th Jan Plan Actual    19000.0
# 13th Jan Plan Actual    19800.0
# 14th Jan Plan Actual    19000.0
# 15th Jan Plan Actual    19000.0
# 16TH Jan Plan Actual    19000.0
# 17th Jan Plan Actual    19000.0
# 19th Jan Plan Actual    19000.0
# 20th Jan Plan Actual      600.0
# 21st Jan Plan Actual    19000.0
# 22nd Jan Plan Actual    19800.0
# 23rd Jan Plan Actual    19800.0
# 24th Jan Plan Actual    19800.0
# 25th Jan Plan Actual    19800.0
# 27TH Jan Plan Actual    19800.0
# 28th Jan Plan Actual    19800.0
# 29th Jan Plan Actual    19800.0
# 30th Jan Plan Actual    19800.0
# 31st Jan Plan Actual    14200.0
# 2nd Feb Plan Actual     16200.0
# 3rd Feb Plan Actual     13200.0
# 4th Feb Plan Actual     16200.0
# 5th Feb Plan Actual     16200.0
# 6th Feb Plan Actual     16200.0
# 7th Feb Plan Actual     16200.0
# 9th Feb Plan Actual     16200.0
# 10th Feb Plan Actual    15600.0
# 11th Feb Plan Actual    16200.0
# 12th Feb Plan Actual    16200.0
# 13th Feb Plan Actual    16200.0
# 14th Feb Plan Actual    16200.0
# 16th Feb Plan Actual    16200.0
# 17th Feb Plan Actual    16200.0
# 18th Feb Plan Actual    16200.0
# 19th Feb Plan Actual    16200.0
# Name: 0, dtype: object
